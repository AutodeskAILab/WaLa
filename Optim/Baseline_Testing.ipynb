# %% [markdown]
# ### Initialization

# %%
from pathlib import Path
import open3d as o3d
import os
import sys
from pathlib import Path

# Add the parent directory to sys.path so 'src' can be imported
sys.path.append(str(Path.cwd().parent))

from pytorch_lightning import seed_everything

from src.dataset_utils import (
    get_singleview_data_trt,
    get_singleview_data,
    get_multiview_data,
    get_voxel_data_json,
    get_image_transform_latent_model,
    get_pointcloud_data,
    get_mv_dm_data,
    get_sv_dm_data,
    get_sketch_data
)
from src.model_utils import Model
from src.mvdream_utils import load_mvdream_model
import argparse
from PIL import Image


from comet_ml import start
from comet_ml.integration.pytorch import log_model
from comet_ml.api import API

import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import pandas as pd

import time

import Optim_Utils
from Optim_Utils import Optim_Visualizations
import torch

import boto3
# Out:
# /home/rayhub-user/.conda/envs/wala/lib/python3.10/site-packages/spconv/pytorch/functional.py:47: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   _TORCH_CUSTOM_FWD = amp.custom_fwd(cast_inputs=torch.float16)
# /home/rayhub-user/.conda/envs/wala/lib/python3.10/site-packages/spconv/pytorch/functional.py:97: FutureWarning: `torch.cuda.amp.custom_bwd(args...)` is deprecated. Please use `torch.amp.custom_bwd(args..., device_type='cuda')` instead.
#   def backward(ctx, grad_output):
# /home/rayhub-user/.conda/envs/wala/lib/python3.10/site-packages/spconv/pytorch/functional.py:163: FutureWarning: `torch.cuda.amp.custom_bwd(args...)` is deprecated. Please use `torch.amp.custom_bwd(args..., device_type='cuda')` instead.
#   def backward(ctx, grad_output):
# /home/rayhub-user/.conda/envs/wala/lib/python3.10/site-packages/spconv/pytorch/functional.py:243: FutureWarning: `torch.cuda.amp.custom_bwd(args...)` is deprecated. Please use `torch.amp.custom_bwd(args..., device_type='cuda')` instead.
#   def backward(ctx, grad_output):
# /home/rayhub-user/.conda/envs/wala/lib/python3.10/site-packages/spconv/pytorch/functional.py:332: FutureWarning: `torch.cuda.amp.custom_bwd(args...)` is deprecated. Please use `torch.amp.custom_bwd(args..., device_type='cuda')` instead.
#   def backward(ctx, grad_output):
# /home/rayhub-user/.conda/envs/wala/lib/python3.10/site-packages/spconv/pytorch/functional.py:369: FutureWarning: `torch.cuda.amp.custom_bwd(args...)` is deprecated. Please use `torch.amp.custom_bwd(args..., device_type='cuda')` instead.
#   def backward(ctx, grad_output):
# /home/rayhub-user/.conda/envs/wala/lib/python3.10/site-packages/spconv/pytorch/functional.py:389: FutureWarning: `torch.cuda.amp.custom_bwd(args...)` is deprecated. Please use `torch.amp.custom_bwd(args..., device_type='cuda')` instead.
#   def backward(ctx, grad_output):
# /home/rayhub-user/.conda/envs/wala/lib/python3.10/site-packages/spconv/pytorch/functional.py:412: FutureWarning: `torch.cuda.amp.custom_bwd(args...)` is deprecated. Please use `torch.amp.custom_bwd(args..., device_type='cuda')` instead.
#   def backward(ctx, grad_output):

# %%
def simplify_mesh(obj_path, target_num_faces=1000):
    mesh = o3d.io.read_triangle_mesh(obj_path)
    simplified_mesh = mesh.simplify_quadric_decimation(target_num_faces)
    o3d.io.write_triangle_mesh(obj_path, simplified_mesh)


def generate_3d_object(
    model,
    data,
    data_idx,
    scale,
    diffusion_rescale_timestep,
    experiment,
    save_dir="examples",
    output_format="obj",
    target_num_faces=None,
    seed=42,
    
):
    # Set seed
    seed_everything(seed, workers=True)

    model.set_inference_fusion_params(scale, diffusion_rescale_timestep)
    low, high = model.forward(
        data, data_idx, experiment,  output_format=output_format
    )

    return low,high

# %%
os.environ["XFORMERS_DISABLED"] = "1"



model_name = 'ADSKAILab/WaLa-SV-1B'
images_path = Path('examples/single_view/')
single_image = ['examples/single_view/table.png']

output_dir = 'examples/Test_Gen'
output_format = 'obj'
target_num_faces = 25000
scale = 1.8
seed = 42
diffusion_rescale_timestep = 5

print(f"Loading model")


model = Model.from_pretrained(pretrained_model_name_or_path=model_name)
image_transform = get_image_transform_latent_model()
model.set_inference_fusion_params(
        scale, diffusion_rescale_timestep
    )
experiment = None

# %% [markdown]
# ### Test 1 - 3 images

# %%
def run_inference(image_path,save_dir,model,experiment= None):
    lh_dic = {}
    for idx, image_path in enumerate(image_path.iterdir()):  # Enumerate to get the index
        timer1 = time.time()
        print(f"Processing image: {image_path}")
        data = get_singleview_data(
            image_file=Path(image_path),
            image_transform=image_transform,
            device=model.device,
            image_over_white=False,
        )
        data_idx = 0
        save_dir = Path(output_dir) 
        base_name = os.path.basename(image_path)
        image_name = os.path.splitext(base_name)[0]  
        model.set_inference_fusion_params(
            scale, diffusion_rescale_timestep
        )
        low, high = generate_3d_object(
            model,
            data,
            data_idx,
            scale,
            diffusion_rescale_timestep,
            experiment,
            output_format,
            target_num_faces,
            seed,
        )
        delta = time.time() - timer1
        print('Total Inference time', delta)

        try:
            delta = time.time() - timer1
            experiment.log_metric("Default Delta", delta)
            print('Total Inference time', delta)
        except:
            pass
        
        lh_dic[image_name] = (low,high)

    return lh_dic
lh_dic = run_inference(images_path,output_dir,model)

# %% [markdown]
# ## Dataset Extraction and Utilization for Benchmarking

# %% [markdown]
# #### Utils

# %%
source_folder = os.path.expanduser('/Google_Dataset_Outputs')
check_folder = Path("/home/rayhub-user/Optim-WaLa/Benchmark_quality/Original")
destination_folder = Path("/home/rayhub-user/Optim-WaLa/Benchmark_quality/Tensor_RT")

Optim_Utils.find_and_move_matching_files(source_folder, check_folder, destination_folder, TRT = True)
# Out:
# [DEBUG] Files in check_folder (/home/rayhub-user/Optim-WaLa/Benchmark_quality/Original): 20 found
# [DEBUG] Files in source_folder (/Google_Dataset_Outputs): 999 found
# Moved: 2_of_Jenga_Classic_Game_trt.obj from /Google_Dataset_Outputs to /home/rayhub-user/Optim-WaLa/Benchmark_quality/Tensor_RT
# Moved: 50_BLOCKS_trt.obj from /Google_Dataset_Outputs to /home/rayhub-user/Optim-WaLa/Benchmark_quality/Tensor_RT
# Moved: 5_HTP_trt.obj from /Google_Dataset_Outputs to /home/rayhub-user/Optim-WaLa/Benchmark_quality/Tensor_RT
# [DEBUG] No match for: ASICS_GELAce_Pro_Pearl_WhitePink_trt.obj (match_name: ASICS_GELAce_Pro_Pearl_WhitePink.obj)
# [DEBUG] No match for: ASICS_GELBlur33_20_GS_BlackWhiteSafety_Orange_trt.obj (match_name: ASICS_GELBlur33_20_GS_BlackWhiteSafety_Orange.obj)
# [DEBUG] No match for: Asus_M5A78LMUSB3_Motherboard_Micro_ATX_Socket_AM3_trt.obj (match_name: Asus_M5A78LMUSB3_Motherboard_Micro_ATX_Socket_AM3.obj)
# [DEBUG] No match for: Asus_M5A99FX_PRO_R20_Motherboard_ATX_Socket_AM3_trt.obj (match_name: Asus_M5A99FX_PRO_R20_Motherboard_ATX_Socket_AM3.obj)
# [DEBUG] No match for: Asus_Sabertooth_990FX_20_Motherboard_ATX_Socket_AM3_trt.obj (match_name: Asus_Sabertooth_990FX_20_Motherboard_ATX_Socket_AM3.obj)
# [DEBUG] No match for: Asus_Sabertooth_Z97_MARK_1_Motherboard_ATX_LGA1150_Socket_trt.obj (match_name: Asus_Sabertooth_Z97_MARK_1_Motherboard_ATX_LGA1150_Socket.obj)
# [DEBUG] No match for: BlackBlack_Nintendo_3DSXL_trt.obj (match_name: BlackBlack_Nintendo_3DSXL.obj)
# [DEBUG] No match for: Black_Decker_Stainless_Steel_Toaster_4_Slice_trt.obj (match_name: Black_Decker_Stainless_Steel_Toaster_4_Slice.obj)
# [DEBUG] No match for: Black_Elderberry_Syrup_54_oz_Gaia_Herbs_trt.obj (match_name: Black_Elderberry_Syrup_54_oz_Gaia_Herbs.obj)
# [DEBUG] No match for: BlueBlack_Nintendo_3DSXL_trt.obj (match_name: BlueBlack_Nintendo_3DSXL.obj)
# [DEBUG] No match for: Blue_Jasmine_Includes_Digital_Copy_UltraViolet_DVD_trt.obj (match_name: Blue_Jasmine_Includes_Digital_Copy_UltraViolet_DVD.obj)
# [DEBUG] No match for: Cootie_Game_trt.obj (match_name: Cootie_Game.obj)
# [DEBUG] No match for: Dell_Series_9_Color_Ink_Cartridge_MK993_High_Yield_trt.obj (match_name: Dell_Series_9_Color_Ink_Cartridge_MK993_High_Yield.obj)
# [DEBUG] No match for: Frozen_Scrabble_Jr_trt.obj (match_name: Frozen_Scrabble_Jr.obj)
# [DEBUG] No match for: Google_Cardboard_Original_package_trt.obj (match_name: Google_Cardboard_Original_package.obj)
# [DEBUG] No match for: HP_Card_Invitation_Kit_trt.obj (match_name: HP_Card_Invitation_Kit.obj)
# [DEBUG] No match for: Hyaluronic_Acid_trt.obj (match_name: Hyaluronic_Acid.obj)
# [DEBUG] No match for: LEGO_Creationary_Game_trt.obj (match_name: LEGO_Creationary_Game.obj)
# [DEBUG] No match for: LEGO_Creationary_Game_ZJa163wlWp2_trt.obj (match_name: LEGO_Creationary_Game_ZJa163wlWp2.obj)
# [DEBUG] No match for: Lenovo_Yoga_2_11_trt.obj (match_name: Lenovo_Yoga_2_11.obj)
# [DEBUG] No match for: Logitech_Ultimate_Ears_Boom_Wireless_Speaker_Night_Black_trt.obj (match_name: Logitech_Ultimate_Ears_Boom_Wireless_Speaker_Night_Black.obj)
# [DEBUG] No match for: Lovestruck_Tieks_Glittery_Rose_Gold_Italian_Leather_Ballet_Flats_trt.obj (match_name: Lovestruck_Tieks_Glittery_Rose_Gold_Italian_Leather_Ballet_Flats.obj)
# [DEBUG] No match for: Luigis_Mansion_Dark_Moon_Nintendo_3DS_Game_trt.obj (match_name: Luigis_Mansion_Dark_Moon_Nintendo_3DS_Game.obj)
# [DEBUG] No match for: Mens_ASV_Billfish_Boat_Shoe_in_Dark_Brown_Leather_zdHVHXueI3w_trt.obj (match_name: Mens_ASV_Billfish_Boat_Shoe_in_Dark_Brown_Leather_zdHVHXueI3w.obj)
# [DEBUG] No match for: Mens_Authentic_Original_Boat_Shoe_in_Navy_Leather_xgoEcZtRNmH_trt.obj (match_name: Mens_Authentic_Original_Boat_Shoe_in_Navy_Leather_xgoEcZtRNmH.obj)
# [DEBUG] No match for: Mens_Striper_Sneaker_in_White_rnp8HUli59Y_trt.obj (match_name: Mens_Striper_Sneaker_in_White_rnp8HUli59Y.obj)
# [DEBUG] No match for: Womens_Audrey_Slip_On_Boat_Shoe_in_Graphite_Nubuck_xWVkCJ5vxZe_trt.obj (match_name: Womens_Audrey_Slip_On_Boat_Shoe_in_Graphite_Nubuck_xWVkCJ5vxZe.obj)
# [DEBUG] No match for: Womens_Betty_Chukka_Boot_in_Grey_Jersey_Sequin_trt.obj (match_name: Womens_Betty_Chukka_Boot_in_Grey_Jersey_Sequin.obj)
# [DEBUG] No match for: Womens_Betty_Chukka_Boot_in_Salt_Washed_Red_AL2YrOt9CRy_trt.obj (match_name: Womens_Betty_Chukka_Boot_in_Salt_Washed_Red_AL2YrOt9CRy.obj)
# [DEBUG] No match for: Womens_Bluefish_2Eye_Boat_Shoe_in_White_Tumbled_YG44xIePRHw_trt.obj (match_name: Womens_Bluefish_2Eye_Boat_Shoe_in_White_Tumbled_YG44xIePRHw.obj)
# Moved: 30_CONSTRUCTION_SET_trt.obj from /Google_Dataset_Outputs to /home/rayhub-user/Optim-WaLa/Benchmark_quality/Tensor_RT
# Moved: 3D_Dollhouse_Swing_trt.obj from /Google_Dataset_Outputs to /home/rayhub-user/Optim-WaLa/Benchmark_quality/Tensor_RT
# Moved: 3M_Antislip_Surfacing_Light_Duty_White_trt.obj from /Google_Dataset_Outputs to /home/rayhub-user/Optim-WaLa/Benchmark_quality/Tensor_RT
# Moved: 3M_Vinyl_Tape_Green_1_x_36_yd_trt.obj from /Google_Dataset_Outputs to /home/rayhub-user/Optim-WaLa/Benchmark_quality/Tensor_RT
# [DEBUG] No match for: Animal_Planet_Foam_2Headed_Dragon_trt.obj (match_name: Animal_Planet_Foam_2Headed_Dragon.obj)
# [DEBUG] No match for: Avengers_Thor_PLlrpYniaeB_trt.obj (match_name: Avengers_Thor_PLlrpYniaeB.obj)
# [DEBUG] No match for: BEDROOM_CLASSIC_trt.obj (match_name: BEDROOM_CLASSIC.obj)
# [DEBUG] No match for: BIA_Cordon_Bleu_White_Porcelain_Utensil_Holder_900028_trt.obj (match_name: BIA_Cordon_Bleu_White_Porcelain_Utensil_Holder_900028.obj)
# [DEBUG] No match for: CONE_SORTING_trt.obj (match_name: CONE_SORTING.obj)
# [DEBUG] No match for: Clorox_Premium_Choice_Gloves_SM_1_pair_trt.obj (match_name: Clorox_Premium_Choice_Gloves_SM_1_pair.obj)
# [DEBUG] No match for: Cole_Hardware_Deep_Bowl_Good_Earth_1075_trt.obj (match_name: Cole_Hardware_Deep_Bowl_Good_Earth_1075.obj)
# [DEBUG] No match for: Cole_Hardware_Dishtowel_BlueWhite_trt.obj (match_name: Cole_Hardware_Dishtowel_BlueWhite.obj)
# [DEBUG] No match for: Cole_Hardware_Hammer_Black_trt.obj (match_name: Cole_Hardware_Hammer_Black.obj)
# [DEBUG] No match for: Cole_Hardware_Mini_Honey_Dipper_trt.obj (match_name: Cole_Hardware_Mini_Honey_Dipper.obj)
# [DEBUG] No match for: Cole_Hardware_Plant_Saucer_Brown_125_trt.obj (match_name: Cole_Hardware_Plant_Saucer_Brown_125.obj)
# [DEBUG] No match for: Deskstar_Desk_Top_Hard_Drive_1_TB_trt.obj (match_name: Deskstar_Desk_Top_Hard_Drive_1_TB.obj)
# [DEBUG] No match for: Cole_Hardware_Saucer_Glazed_6_trt.obj (match_name: Cole_Hardware_Saucer_Glazed_6.obj)
# [DEBUG] No match for: Diet_Pepsi_Soda_Cola12_Pack_12_oz_Cans_trt.obj (match_name: Diet_Pepsi_Soda_Cola12_Pack_12_oz_Cans.obj)
# [DEBUG] No match for: Ecoforms_Cup_B4_SAN_trt.obj (match_name: Ecoforms_Cup_B4_SAN.obj)
# [DEBUG] No match for: Ecoforms_Plant_Container_B4_Har_trt.obj (match_name: Ecoforms_Plant_Container_B4_Har.obj)
# [DEBUG] No match for: Ecoforms_Plant_Container_GP16AMOCHA_trt.obj (match_name: Ecoforms_Plant_Container_GP16AMOCHA.obj)
# [DEBUG] No match for: Ecoforms_Plant_Container_GP16A_Coral_trt.obj (match_name: Ecoforms_Plant_Container_GP16A_Coral.obj)
# [DEBUG] No match for: Ecoforms_Plant_Container_QP6HARVEST_trt.obj (match_name: Ecoforms_Plant_Container_QP6HARVEST.obj)
# [DEBUG] No match for: Ecoforms_Plant_Container_URN_NAT_trt.obj (match_name: Ecoforms_Plant_Container_URN_NAT.obj)
# [DEBUG] No match for: Ecoforms_Plant_Container_Urn_55_Mocha_trt.obj (match_name: Ecoforms_Plant_Container_Urn_55_Mocha.obj)
# [DEBUG] No match for: Ecoforms_Plant_Pot_GP9_SAND_trt.obj (match_name: Ecoforms_Plant_Pot_GP9_SAND.obj)
# [DEBUG] No match for: Ecoforms_Plant_Saucer_S17MOCHA_trt.obj (match_name: Ecoforms_Plant_Saucer_S17MOCHA.obj)
# [DEBUG] No match for: Ecoforms_Planter_Bowl_Cole_Hardware_trt.obj (match_name: Ecoforms_Planter_Bowl_Cole_Hardware.obj)
# [DEBUG] No match for: Elephant_trt.obj (match_name: Elephant.obj)
# [DEBUG] No match for: Gigabyte_GAZ97XSLI_10_motherboard_ATX_LGA1150_Socket_Z97_trt.obj (match_name: Gigabyte_GAZ97XSLI_10_motherboard_ATX_LGA1150_Socket_Z97.obj)
# [DEBUG] No match for: Granimals_20_Wooden_ABC_Blocks_Wagon_trt.obj (match_name: Granimals_20_Wooden_ABC_Blocks_Wagon.obj)
# [DEBUG] No match for: Great_Dinos_Triceratops_Toy_trt.obj (match_name: Great_Dinos_Triceratops_Toy.obj)
# [DEBUG] No match for: Hefty_Waste_Basket_Decorative_Bronze_85_liter_trt.obj (match_name: Hefty_Waste_Basket_Decorative_Bronze_85_liter.obj)
# [DEBUG] No match for: INTERNATIONAL_PAPER_Willamette_4_Brown_Bag_500Count_trt.obj (match_name: INTERNATIONAL_PAPER_Willamette_4_Brown_Bag_500Count.obj)
# [DEBUG] No match for: KS_Chocolate_Cube_Box_Assortment_By_Neuhaus_2010_Ounces_trt.obj (match_name: KS_Chocolate_Cube_Box_Assortment_By_Neuhaus_2010_Ounces.obj)
# [DEBUG] No match for: Neat_Solutions_Character_Bib_2_pack_trt.obj (match_name: Neat_Solutions_Character_Bib_2_pack.obj)
# [DEBUG] No match for: Now_Designs_Bowl_Akita_Black_trt.obj (match_name: Now_Designs_Bowl_Akita_Black.obj)
# [DEBUG] No match for: Ortho_Forward_Facing_3Q6J2oKJD92_trt.obj (match_name: Ortho_Forward_Facing_3Q6J2oKJD92.obj)
# [DEBUG] No match for: PEPSI_NEXT_CACRV_trt.obj (match_name: PEPSI_NEXT_CACRV.obj)
# [DEBUG] No match for: POUNDING_MUSHROOMS_trt.obj (match_name: POUNDING_MUSHROOMS.obj)
# [DEBUG] No match for: PUNCH_DROP_TjicLPMqLvz_trt.obj (match_name: PUNCH_DROP_TjicLPMqLvz.obj)
# [DEBUG] No match for: Pepsi_Max_Cola_Zero_Calorie_12_12_fl_oz_355_ml_cans_144_fl_oz_426_lt_trt.obj (match_name: Pepsi_Max_Cola_Zero_Calorie_12_12_fl_oz_355_ml_cans_144_fl_oz_426_lt.obj)
# [DEBUG] No match for: Perricone_MD_AcylGlutathione_Eye_Lid_Serum_trt.obj (match_name: Perricone_MD_AcylGlutathione_Eye_Lid_Serum.obj)
# [DEBUG] No match for: Perricone_MD_Face_Finishing_Moisturizer_trt.obj (match_name: Perricone_MD_Face_Finishing_Moisturizer.obj)
# [DEBUG] No match for: Perricone_MD_Hypoallergenic_Firming_Eye_Cream_05_oz_trt.obj (match_name: Perricone_MD_Hypoallergenic_Firming_Eye_Cream_05_oz.obj)
# [DEBUG] No match for: Perricone_MD_No_Foundation_Foundation_No_1_trt.obj (match_name: Perricone_MD_No_Foundation_Foundation_No_1.obj)
# [DEBUG] No match for: Perricone_MD_Photo_Plasma_trt.obj (match_name: Perricone_MD_Photo_Plasma.obj)
# [DEBUG] No match for: Perricone_MD_Skin_Total_Body_Supplements_trt.obj (match_name: Perricone_MD_Skin_Total_Body_Supplements.obj)
# [DEBUG] No match for: Perricone_MD_Super_Berry_Powder_with_Acai_Supplements_trt.obj (match_name: Perricone_MD_Super_Berry_Powder_with_Acai_Supplements.obj)
# [DEBUG] No match for: Perricone_MD_Vitamin_C_Ester_Serum_trt.obj (match_name: Perricone_MD_Vitamin_C_Ester_Serum.obj)
# [DEBUG] No match for: Pony_C_Clamp_1440_trt.obj (match_name: Pony_C_Clamp_1440.obj)
# [DEBUG] No match for: Poppin_File_Sorter_Blue_trt.obj (match_name: Poppin_File_Sorter_Blue.obj)
# [DEBUG] No match for: Razer_BlackWidow_Stealth_2014_Keyboard_07VFzIVabgh_trt.obj (match_name: Razer_BlackWidow_Stealth_2014_Keyboard_07VFzIVabgh.obj)
# [DEBUG] No match for: Razer_Kraken_Pro_headset_Full_size_Black_trt.obj (match_name: Razer_Kraken_Pro_headset_Full_size_Black.obj)
# [DEBUG] No match for: Reef_Star_Cushion_Flipflops_Size_8_Black_trt.obj (match_name: Reef_Star_Cushion_Flipflops_Size_8_Black.obj)
# [DEBUG] No match for: Retail_Leadership_Summit_trt.obj (match_name: Retail_Leadership_Summit.obj)
# [DEBUG] No match for: Retail_Leadership_Summit_eCT3zqHYIkX_trt.obj (match_name: Retail_Leadership_Summit_eCT3zqHYIkX.obj)
# [DEBUG] No match for: Rexy_Glove_Heavy_Duty_Gloves_Medium_trt.obj (match_name: Rexy_Glove_Heavy_Duty_Gloves_Medium.obj)
# [DEBUG] No match for: Room_Essentials_Fabric_Cube_Lavender_trt.obj (match_name: Room_Essentials_Fabric_Cube_Lavender.obj)
# [DEBUG] No match for: Room_Essentials_Kitchen_Towels_16_x_26_2_count_trt.obj (match_name: Room_Essentials_Kitchen_Towels_16_x_26_2_count.obj)
# [DEBUG] No match for: Sea_to_Summit_Xl_Bowl_trt.obj (match_name: Sea_to_Summit_Xl_Bowl.obj)
# [DEBUG] No match for: Shurtape_Gaffers_Tape_Silver_2_x_60_yd_trt.obj (match_name: Shurtape_Gaffers_Tape_Silver_2_x_60_yd.obj)
# [DEBUG] No match for: Threshold_Performance_Bath_Sheet_Sandoval_Blue_33_x_63_trt.obj (match_name: Threshold_Performance_Bath_Sheet_Sandoval_Blue_33_x_63.obj)
# [DEBUG] No match for: Threshold_Porcelain_Serving_Bowl_Coupe_White_trt.obj (match_name: Threshold_Porcelain_Serving_Bowl_Coupe_White.obj)
# [DEBUG] No match for: Threshold_Porcelain_Spoon_Rest_White_trt.obj (match_name: Threshold_Porcelain_Spoon_Rest_White.obj)
# [DEBUG] No match for: Top_Paw_Dog_Bowl_Blue_Paw_Bone_Ceramic_25_fl_oz_total_trt.obj (match_name: Top_Paw_Dog_Bowl_Blue_Paw_Bone_Ceramic_25_fl_oz_total.obj)
# [DEBUG] No match for: Vtech_Cruise_Learn_Car_25_Years_trt.obj (match_name: Vtech_Cruise_Learn_Car_25_Years.obj)
# [DEBUG] No match for: Animal_Crossing_New_Leaf_Nintendo_3DS_Game_trt.obj (match_name: Animal_Crossing_New_Leaf_Nintendo_3DS_Game.obj)
# [DEBUG] No match for: BUNNY_RATTLE_trt.obj (match_name: BUNNY_RATTLE.obj)
# [DEBUG] No match for: Crayola_Crayons_24_count_trt.obj (match_name: Crayola_Crayons_24_count.obj)
# [DEBUG] No match for: Crayola_Model_Magic_Modeling_Material_White_3_oz_trt.obj (match_name: Crayola_Model_Magic_Modeling_Material_White_3_oz.obj)
# [DEBUG] No match for: Crayola_Washable_Sidewalk_Chalk_16_pack_trt.obj (match_name: Crayola_Washable_Sidewalk_Chalk_16_pack.obj)
# [DEBUG] No match for: D_ROSE_773_II_hvInJwJ5HUD_trt.obj (match_name: D_ROSE_773_II_hvInJwJ5HUD.obj)
# [DEBUG] No match for: Fisher_price_Classic_Toys_Buzzy_Bee_trt.obj (match_name: Fisher_price_Classic_Toys_Buzzy_Bee.obj)
# [DEBUG] No match for: Germanium_GE132_trt.obj (match_name: Germanium_GE132.obj)
# [DEBUG] No match for: GoPro_HERO3_Composite_Cable_trt.obj (match_name: GoPro_HERO3_Composite_Cable.obj)
# [DEBUG] No match for: Horses_in_Pink_Pencil_Case_trt.obj (match_name: Horses_in_Pink_Pencil_Case.obj)
# [DEBUG] No match for: JBL_Charge_Speaker_portable_wireless_wired_Green_trt.obj (match_name: JBL_Charge_Speaker_portable_wireless_wired_Green.obj)
# [DEBUG] No match for: Jarrow_Glucosamine_Chondroitin_Combination_120_Caps_trt.obj (match_name: Jarrow_Glucosamine_Chondroitin_Combination_120_Caps.obj)
# [DEBUG] No match for: Lutein_trt.obj (match_name: Lutein.obj)
# [DEBUG] No match for: MARTIN_WEDGE_LACE_BOOT_trt.obj (match_name: MARTIN_WEDGE_LACE_BOOT.obj)
# [DEBUG] No match for: MEAT_SET_trt.obj (match_name: MEAT_SET.obj)
# [DEBUG] No match for: MINI_ROLLER_trt.obj (match_name: MINI_ROLLER.obj)
# [DEBUG] No match for: MIRACLE_POUNDING_trt.obj (match_name: MIRACLE_POUNDING.obj)
# [DEBUG] No match for: MODERN_DOLL_FAMILY_trt.obj (match_name: MODERN_DOLL_FAMILY.obj)
# [DEBUG] No match for: Mad_Gab_Refresh_Card_Game_trt.obj (match_name: Mad_Gab_Refresh_Card_Game.obj)
# [DEBUG] No match for: Mario_Luigi_Dream_Team_Nintendo_3DS_Game_trt.obj (match_name: Mario_Luigi_Dream_Team_Nintendo_3DS_Game.obj)
# [DEBUG] No match for: Marvel_Avengers_Titan_Hero_Series_Doctor_Doom_trt.obj (match_name: Marvel_Avengers_Titan_Hero_Series_Doctor_Doom.obj)
# [DEBUG] No match for: Melissa_Doug_Felt_Food_Pizza_Set_trt.obj (match_name: Melissa_Doug_Felt_Food_Pizza_Set.obj)
# [DEBUG] No match for: Melissa_Doug_Pound_and_Roll_trt.obj (match_name: Melissa_Doug_Pound_and_Roll.obj)
# [DEBUG] No match for: Mens_Billfish_Slip_On_in_Coffee_e8bPKE9Lfgo_trt.obj (match_name: Mens_Billfish_Slip_On_in_Coffee_e8bPKE9Lfgo.obj)
# [DEBUG] No match for: Mens_Tremont_Kiltie_Tassel_Loafer_in_Black_Amaretto_trt.obj (match_name: Mens_Tremont_Kiltie_Tassel_Loafer_in_Black_Amaretto.obj)
# [DEBUG] No match for: Mens_Tremont_Kiltie_Tassel_Loafer_in_Black_Amaretto_rCdzRZqgCnI_trt.obj (match_name: Mens_Tremont_Kiltie_Tassel_Loafer_in_Black_Amaretto_rCdzRZqgCnI.obj)
# [DEBUG] No match for: Mist_Wipe_Warmer_trt.obj (match_name: Mist_Wipe_Warmer.obj)
# [DEBUG] No match for: My_First_Rolling_Lion_trt.obj (match_name: My_First_Rolling_Lion.obj)
# [DEBUG] No match for: Nescafe_Tasters_Choice_Instant_Coffee_Decaf_House_Blend_Light_7_oz_trt.obj (match_name: Nescafe_Tasters_Choice_Instant_Coffee_Decaf_House_Blend_Light_7_oz.obj)
# [DEBUG] No match for: Nestle_Pure_Life_Exotics_Sparkling_Water_Strawberry_Dragon_Fruit_8_count_12_fl_oz_can_trt.obj (match_name: Nestle_Pure_Life_Exotics_Sparkling_Water_Strawberry_Dragon_Fruit_8_count_12_fl_oz_can.obj)
# [DEBUG] No match for: Nickelodeon_Teenage_Mutant_Ninja_Turtles_Michelangelo_trt.obj (match_name: Nickelodeon_Teenage_Mutant_Ninja_Turtles_Michelangelo.obj)
# [DEBUG] No match for: Office_Depot_Canon_CLI_8Y_Ink_Cartridge_Yellow_0623B002_trt.obj (match_name: Office_Depot_Canon_CLI_8Y_Ink_Cartridge_Yellow_0623B002.obj)
# [DEBUG] No match for: Office_Depot_Canon_CL_41_Remanufactured_Ink_Cartridge_TriColor_trt.obj (match_name: Office_Depot_Canon_CL_41_Remanufactured_Ink_Cartridge_TriColor.obj)
# [DEBUG] No match for: Office_Depot_HP_71_Remanufactured_Ink_Cartridge_Black_trt.obj (match_name: Office_Depot_HP_71_Remanufactured_Ink_Cartridge_Black.obj)
# [DEBUG] No match for: Office_Depot_HP_74XL75_Remanufactured_Ink_Cartridges_BlackTriColor_2_count_trt.obj (match_name: Office_Depot_HP_74XL75_Remanufactured_Ink_Cartridges_BlackTriColor_2_count.obj)
# [DEBUG] No match for: Olive_Kids_Birdie_Lunch_Box_trt.obj (match_name: Olive_Kids_Birdie_Lunch_Box.obj)
# [DEBUG] No match for: Olive_Kids_Birdie_Munch_n_Lunch_trt.obj (match_name: Olive_Kids_Birdie_Munch_n_Lunch.obj)
# [DEBUG] No match for: Olive_Kids_Game_On_Pack_n_Snack_trt.obj (match_name: Olive_Kids_Game_On_Pack_n_Snack.obj)
# [DEBUG] No match for: Olive_Kids_Mermaids_Pack_n_Snack_Backpack_trt.obj (match_name: Olive_Kids_Mermaids_Pack_n_Snack_Backpack.obj)
# [DEBUG] No match for: Olive_Kids_Robots_Pencil_Case_trt.obj (match_name: Olive_Kids_Robots_Pencil_Case.obj)
# [DEBUG] No match for: Olive_Kids_Trains_Planes_Trucks_Bogo_Backpack_trt.obj (match_name: Olive_Kids_Trains_Planes_Trucks_Bogo_Backpack.obj)
# [DEBUG] No match for: Orbit_Bubblemint_Mini_Bottle_6_ct_trt.obj (match_name: Orbit_Bubblemint_Mini_Bottle_6_ct.obj)
# [DEBUG] No match for: PEEKABOO_ROLLER_trt.obj (match_name: PEEKABOO_ROLLER.obj)
# [DEBUG] No match for: PETS_ACCESSORIES_trt.obj (match_name: PETS_ACCESSORIES.obj)
# [DEBUG] No match for: Paul_Frank_Dot_Lunch_Box_trt.obj (match_name: Paul_Frank_Dot_Lunch_Box.obj)
# [DEBUG] No match for: Persona_Q_Shadow_of_the_Labyrinth_Nintendo_3DS_trt.obj (match_name: Persona_Q_Shadow_of_the_Labyrinth_Nintendo_3DS.obj)
# [DEBUG] No match for: Philips_EcoVantage_43_W_Light_Bulbs_Natural_Light_2_pack_trt.obj (match_name: Philips_EcoVantage_43_W_Light_Bulbs_Natural_Light_2_pack.obj)
# [DEBUG] No match for: Pokémon_Omega_Ruby_Alpha_Sapphire_Dual_Pack_Nintendo_3DS_trt.obj (match_name: Pokémon_Omega_Ruby_Alpha_Sapphire_Dual_Pack_Nintendo_3DS.obj)
# [DEBUG] No match for: Prostate_Optimizer_trt.obj (match_name: Prostate_Optimizer.obj)
# [DEBUG] No match for: PureConnect_2_Color_FernNightlifeSilverBlack_Size_70_5w0BYsiogeV_trt.obj (match_name: PureConnect_2_Color_FernNightlifeSilverBlack_Size_70_5w0BYsiogeV.obj)
# [DEBUG] No match for: QAbsorb_CoQ10_trt.obj (match_name: QAbsorb_CoQ10.obj)
# [DEBUG] No match for: QHPomegranate_trt.obj (match_name: QHPomegranate.obj)
# [DEBUG] No match for: Real_Deal_1nIwCHX1MTh_trt.obj (match_name: Real_Deal_1nIwCHX1MTh.obj)
# [DEBUG] No match for: Reebok_BREAKPOINT_MID_trt.obj (match_name: Reebok_BREAKPOINT_MID.obj)
# [DEBUG] No match for: Reebok_CLASSIC_JOGGER_trt.obj (match_name: Reebok_CLASSIC_JOGGER.obj)
# [DEBUG] No match for: Reebok_CL_RAYEN_trt.obj (match_name: Reebok_CL_RAYEN.obj)
# [DEBUG] No match for: Reebok_DMX_MAX_MANIA_WD_D_trt.obj (match_name: Reebok_DMX_MAX_MANIA_WD_D.obj)
# [DEBUG] No match for: Reebok_DMX_MAX_PLUS_RAINWALKER_trt.obj (match_name: Reebok_DMX_MAX_PLUS_RAINWALKER.obj)
# [DEBUG] No match for: Reebok_GL_6000_trt.obj (match_name: Reebok_GL_6000.obj)
# [DEBUG] No match for: Reebok_JR_ZIG_COOPERSTOWN_MR_trt.obj (match_name: Reebok_JR_ZIG_COOPERSTOWN_MR.obj)
# [DEBUG] No match for: Reebok_KAMIKAZE_II_MID_trt.obj (match_name: Reebok_KAMIKAZE_II_MID.obj)
# [DEBUG] No match for: Reebok_SH_PRIME_COURT_MID_trt.obj (match_name: Reebok_SH_PRIME_COURT_MID.obj)
# [DEBUG] No match for: Reebok_SMOOTHFLEX_CUSHRUN_20_trt.obj (match_name: Reebok_SMOOTHFLEX_CUSHRUN_20.obj)
# [DEBUG] No match for: SAMOA_trt.obj (match_name: SAMOA.obj)
# [DEBUG] No match for: SAMe_200_KX7ZmOw47co_trt.obj (match_name: SAMe_200_KX7ZmOw47co.obj)
# [DEBUG] No match for: Sleep_Optimizer_trt.obj (match_name: Sleep_Optimizer.obj)
# [DEBUG] No match for: Sony_Downloadable_Loops_trt.obj (match_name: Sony_Downloadable_Loops.obj)
# [DEBUG] No match for: TERREX_FAST_R_trt.obj (match_name: TERREX_FAST_R.obj)
# [DEBUG] No match for: TOP_TEN_HI_60KlbRbdoJA_trt.obj (match_name: TOP_TEN_HI_60KlbRbdoJA.obj)
# [DEBUG] No match for: Tieks_Ballet_Flats_Diamond_White_Croc_trt.obj (match_name: Tieks_Ballet_Flats_Diamond_White_Croc.obj)
# [DEBUG] No match for: Timberland_Mens_Earthkeepers_Newmarket_6Inch_Cupsole_Boot_trt.obj (match_name: Timberland_Mens_Earthkeepers_Newmarket_6Inch_Cupsole_Boot.obj)
# [DEBUG] No match for: Timberland_Mens_Earthkeepers_Stormbuck_Chukka_trt.obj (match_name: Timberland_Mens_Earthkeepers_Stormbuck_Chukka.obj)
# [DEBUG] No match for: Timberland_Womens_Earthkeepers_Classic_Unlined_Boat_Shoe_trt.obj (match_name: Timberland_Womens_Earthkeepers_Classic_Unlined_Boat_Shoe.obj)
# [DEBUG] No match for: Tory_Burch_Kaitlin_Ballet_Mestico_in_BlackGold_trt.obj (match_name: Tory_Burch_Kaitlin_Ballet_Mestico_in_BlackGold.obj)
# [DEBUG] No match for: Tory_Burch_Sabe_65mm_Bootie_Split_Suede_in_Caramel_trt.obj (match_name: Tory_Burch_Sabe_65mm_Bootie_Split_Suede_in_Caramel.obj)
# [DEBUG] No match for: Travel_Smart_Neck_Rest_Inflatable_trt.obj (match_name: Travel_Smart_Neck_Rest_Inflatable.obj)
# [DEBUG] No match for: UGG_Bailey_Button_Triplet_Womens_Boots_Black_7_trt.obj (match_name: UGG_Bailey_Button_Triplet_Womens_Boots_Black_7.obj)
# [DEBUG] No match for: UGG_Jena_Womens_Java_7_trt.obj (match_name: UGG_Jena_Womens_Java_7.obj)
# [DEBUG] No match for: Unmellow_Yellow_Tieks_Neon_Patent_Leather_Ballet_Flats_trt.obj (match_name: Unmellow_Yellow_Tieks_Neon_Patent_Leather_Ballet_Flats.obj)
# [DEBUG] No match for: Weston_No_33_Signature_Sausage_Tonic_12_fl_oz_trt.obj (match_name: Weston_No_33_Signature_Sausage_Tonic_12_fl_oz.obj)
# [DEBUG] No match for: Whey_Protein_Vanilla_trt.obj (match_name: Whey_Protein_Vanilla.obj)
# [DEBUG] No match for: Whey_Protein_Vanilla_12_Packets_trt.obj (match_name: Whey_Protein_Vanilla_12_Packets.obj)
# [DEBUG] No match for: Winning_Moves_1180_Aggravation_Board_Game_trt.obj (match_name: Winning_Moves_1180_Aggravation_Board_Game.obj)
# [DEBUG] No match for: Wishbone_Pencil_Case_trt.obj (match_name: Wishbone_Pencil_Case.obj)
# [DEBUG] No match for: Womens_Authentic_Original_Boat_Shoe_in_Classic_Brown_Leather_cJSCWiH7QmB_trt.obj (match_name: Womens_Authentic_Original_Boat_Shoe_in_Classic_Brown_Leather_cJSCWiH7QmB.obj)
# [DEBUG] No match for: Womens_Bluefish_2Eye_Boat_Shoe_in_Linen_Natural_Sparkle_Suede_w34KNQ41csH_trt.obj (match_name: Womens_Bluefish_2Eye_Boat_Shoe_in_Linen_Natural_Sparkle_Suede_w34KNQ41csH.obj)
# [DEBUG] No match for: Womens_Canvas_Bahama_in_Black_vnJULsDVyq5_trt.obj (match_name: Womens_Canvas_Bahama_in_Black_vnJULsDVyq5.obj)
# [DEBUG] No match for: Womens_Canvas_Bahama_in_White_4UyOhP6rYGO_trt.obj (match_name: Womens_Canvas_Bahama_in_White_4UyOhP6rYGO.obj)
# [DEBUG] No match for: Womens_Canvas_Bahama_in_White_UfZPHGQpvz0_trt.obj (match_name: Womens_Canvas_Bahama_in_White_UfZPHGQpvz0.obj)
# [DEBUG] No match for: Womens_Hikerfish_Boot_in_Black_Leopard_bVSNY1Le1sm_trt.obj (match_name: Womens_Hikerfish_Boot_in_Black_Leopard_bVSNY1Le1sm.obj)
# [DEBUG] No match for: Womens_Sequin_Bahama_in_White_Sequin_V9K1hf24Oxe_trt.obj (match_name: Womens_Sequin_Bahama_in_White_Sequin_V9K1hf24Oxe.obj)
# [DEBUG] No match for: Womens_Sequin_Bahama_in_White_Sequin_yGVsSA4tOwJ_trt.obj (match_name: Womens_Sequin_Bahama_in_White_Sequin_yGVsSA4tOwJ.obj)
# [DEBUG] No match for: Womens_Teva_Capistrano_Bootie_trt.obj (match_name: Womens_Teva_Capistrano_Bootie.obj)
# [DEBUG] No match for: Womens_Teva_Capistrano_Bootie_ldjRT9yZ5Ht_trt.obj (match_name: Womens_Teva_Capistrano_Bootie_ldjRT9yZ5Ht.obj)
# [DEBUG] No match for: Xyli_Pure_Xylitol_trt.obj (match_name: Xyli_Pure_Xylitol.obj)
# [DEBUG] No match for: adiZero_Slide_2_SC_trt.obj (match_name: adiZero_Slide_2_SC.obj)
# Moved: 3D_Dollhouse_Lamp_trt.obj from /Google_Dataset_Outputs to /home/rayhub-user/Optim-WaLa/Benchmark_quality/Tensor_RT
# Moved: 3D_Dollhouse_Sink_trt.obj from /Google_Dataset_Outputs to /home/rayhub-user/Optim-WaLa/Benchmark_quality/Tensor_RT
# Moved: 3D_Dollhouse_Sofa_trt.obj from /Google_Dataset_Outputs to /home/rayhub-user/Optim-WaLa/Benchmark_quality/Tensor_RT
# [DEBUG] No match for: ASSORTED_VEGETABLE_SET_trt.obj (match_name: ASSORTED_VEGETABLE_SET.obj)
# [DEBUG] No match for: Mens_Authentic_Original_Boat_Shoe_in_Navy_Leather_NHHQddDLQys_trt.obj (match_name: Mens_Authentic_Original_Boat_Shoe_in_Navy_Leather_NHHQddDLQys.obj)
# [DEBUG] No match for: Mens_Mako_Canoe_Moc_2Eye_Boat_Shoe_in_Coffee_9d05GG33QQQ_trt.obj (match_name: Mens_Mako_Canoe_Moc_2Eye_Boat_Shoe_in_Coffee_9d05GG33QQQ.obj)
# [DEBUG] No match for: Womens_Bluefish_2Eye_Boat_Shoe_in_Linen_Oat_trt.obj (match_name: Womens_Bluefish_2Eye_Boat_Shoe_in_Linen_Oat.obj)
# [DEBUG] No match for: Womens_Bluefish_2Eye_Boat_Shoe_in_Tan_trt.obj (match_name: Womens_Bluefish_2Eye_Boat_Shoe_in_Tan.obj)
# Moved: 3D_Dollhouse_Refrigerator_trt.obj from /Google_Dataset_Outputs to /home/rayhub-user/Optim-WaLa/Benchmark_quality/Tensor_RT
# [DEBUG] No match for: Air_Hogs_Wind_Flyers_Set_Airplane_Red_trt.obj (match_name: Air_Hogs_Wind_Flyers_Set_Airplane_Red.obj)
# [DEBUG] No match for: BAKING_UTENSILS_trt.obj (match_name: BAKING_UTENSILS.obj)
# [DEBUG] No match for: BIA_Porcelain_Ramekin_With_Glazed_Rim_35_45_oz_cup_trt.obj (match_name: BIA_Porcelain_Ramekin_With_Glazed_Rim_35_45_oz_cup.obj)
# [DEBUG] No match for: BREAKFAST_MENU_trt.obj (match_name: BREAKFAST_MENU.obj)
# [DEBUG] No match for: Bradshaw_International_11642_7_Qt_MP_Plastic_Bowl_trt.obj (match_name: Bradshaw_International_11642_7_Qt_MP_Plastic_Bowl.obj)
# [DEBUG] No match for: Brother_LC_1053PKS_Ink_Cartridge_CyanMagentaYellow_1pack_trt.obj (match_name: Brother_LC_1053PKS_Ink_Cartridge_CyanMagentaYellow_1pack.obj)
# [DEBUG] No match for: Brother_Printing_Cartridge_PC501_trt.obj (match_name: Brother_Printing_Cartridge_PC501.obj)
# [DEBUG] No match for: CHICKEN_NESTING_trt.obj (match_name: CHICKEN_NESTING.obj)
# [DEBUG] No match for: CHILDREN_BEDROOM_CLASSIC_trt.obj (match_name: CHILDREN_BEDROOM_CLASSIC.obj)
# [DEBUG] No match for: Calphalon_Kitchen_Essentials_12_Cast_Iron_Fry_Pan_Black_trt.obj (match_name: Calphalon_Kitchen_Essentials_12_Cast_Iron_Fry_Pan_Black.obj)
# [DEBUG] No match for: Chef_Style_Round_Cake_Pan_9_inch_pan_trt.obj (match_name: Chef_Style_Round_Cake_Pan_9_inch_pan.obj)
# [DEBUG] No match for: Circo_Fish_Toothbrush_Holder_14995988_trt.obj (match_name: Circo_Fish_Toothbrush_Holder_14995988.obj)
# [DEBUG] No match for: Cole_Hardware_Butter_Dish_Square_Red_trt.obj (match_name: Cole_Hardware_Butter_Dish_Square_Red.obj)
# [DEBUG] No match for: Cole_Hardware_Dishtowel_Blue_trt.obj (match_name: Cole_Hardware_Dishtowel_Blue.obj)
# [DEBUG] No match for: Cole_Hardware_Dishtowel_Multicolors_trt.obj (match_name: Cole_Hardware_Dishtowel_Multicolors.obj)
# [DEBUG] No match for: Cole_Hardware_Dishtowel_Red_trt.obj (match_name: Cole_Hardware_Dishtowel_Red.obj)
# [DEBUG] No match for: Cole_Hardware_Dishtowel_Stripe_trt.obj (match_name: Cole_Hardware_Dishtowel_Stripe.obj)
# [DEBUG] No match for: Cole_Hardware_Electric_Pot_Cabana_55_trt.obj (match_name: Cole_Hardware_Electric_Pot_Cabana_55.obj)
# [DEBUG] No match for: Cole_Hardware_Flower_Pot_1025_trt.obj (match_name: Cole_Hardware_Flower_Pot_1025.obj)
# [DEBUG] No match for: Cole_Hardware_Plant_Saucer_Glazed_9_trt.obj (match_name: Cole_Hardware_Plant_Saucer_Glazed_9.obj)
# [DEBUG] No match for: Cole_Hardware_Saucer_Electric_trt.obj (match_name: Cole_Hardware_Saucer_Electric.obj)
# [DEBUG] No match for: Cole_Hardware_School_Bell_Solid_Brass_38_trt.obj (match_name: Cole_Hardware_School_Bell_Solid_Brass_38.obj)
# [DEBUG] No match for: Corningware_CW_by_Corningware_3qt_Oblong_Casserole_Dish_Blue_trt.obj (match_name: Corningware_CW_by_Corningware_3qt_Oblong_Casserole_Dish_Blue.obj)
# [DEBUG] No match for: Crosley_Alarm_Clock_Vintage_Metal_trt.obj (match_name: Crosley_Alarm_Clock_Vintage_Metal.obj)
# [DEBUG] No match for: DPC_Thinsulate_Isolate_Gloves_Brown_trt.obj (match_name: DPC_Thinsulate_Isolate_Gloves_Brown.obj)
# [DEBUG] No match for: DPC_tropical_Trends_Hat_trt.obj (match_name: DPC_tropical_Trends_Hat.obj)
# [DEBUG] No match for: Design_Ideas_Drawer_Store_Organizer_trt.obj (match_name: Design_Ideas_Drawer_Store_Organizer.obj)
# [DEBUG] No match for: Dino_3_trt.obj (match_name: Dino_3.obj)
# [DEBUG] No match for: Dino_4_trt.obj (match_name: Dino_4.obj)
# [DEBUG] No match for: Dog_trt.obj (match_name: Dog.obj)
# [DEBUG] No match for: Down_To_Earth_Orchid_Pot_Ceramic_Lime_trt.obj (match_name: Down_To_Earth_Orchid_Pot_Ceramic_Lime.obj)
# [DEBUG] No match for: Down_To_Earth_Orchid_Pot_Ceramic_Red_trt.obj (match_name: Down_To_Earth_Orchid_Pot_Ceramic_Red.obj)
# [DEBUG] No match for: Ecoforms_Plant_Bowl_Atlas_Low_trt.obj (match_name: Ecoforms_Plant_Bowl_Atlas_Low.obj)
# [DEBUG] No match for: Ecoforms_Plant_Container_QP_Harvest_trt.obj (match_name: Ecoforms_Plant_Container_QP_Harvest.obj)
# [DEBUG] No match for: Ecoforms_Plant_Container_SB9Turquoise_trt.obj (match_name: Ecoforms_Plant_Container_SB9Turquoise.obj)
# [DEBUG] No match for: Ecoforms_Plant_Container_URN_SAN_trt.obj (match_name: Ecoforms_Plant_Container_URN_SAN.obj)
# [DEBUG] No match for: Ecoforms_Plant_Container_Urn_55_Avocado_trt.obj (match_name: Ecoforms_Plant_Container_Urn_55_Avocado.obj)
# [DEBUG] No match for: Ecoforms_Plant_Plate_S11Turquoise_trt.obj (match_name: Ecoforms_Plant_Plate_S11Turquoise.obj)
# [DEBUG] No match for: Ecoforms_Plant_Pot_GP9AAvocado_trt.obj (match_name: Ecoforms_Plant_Pot_GP9AAvocado.obj)
# [DEBUG] No match for: Ecoforms_Plant_Saucer_S20MOCHA_trt.obj (match_name: Ecoforms_Plant_Saucer_S20MOCHA.obj)
# [DEBUG] No match for: Ecoforms_Plant_Saucer_SQ1HARVEST_trt.obj (match_name: Ecoforms_Plant_Saucer_SQ1HARVEST.obj)
# [DEBUG] No match for: Ecoforms_Planter_Pot_GP12AAvocado_trt.obj (match_name: Ecoforms_Planter_Pot_GP12AAvocado.obj)
# [DEBUG] No match for: Ecoforms_Planter_Pot_QP6Ebony_trt.obj (match_name: Ecoforms_Planter_Pot_QP6Ebony.obj)
# [DEBUG] No match for: Ecoforms_Quadra_Saucer_SQ1_Avocado_trt.obj (match_name: Ecoforms_Quadra_Saucer_SQ1_Avocado.obj)
# [DEBUG] No match for: Embark_Lunch_Cooler_Blue_trt.obj (match_name: Embark_Lunch_Cooler_Blue.obj)
# [DEBUG] No match for: FARM_ANIMAL_trt.obj (match_name: FARM_ANIMAL.obj)
# [DEBUG] No match for: GEARS_PUZZLES_STANDARD_gcYxhNHhKlI_trt.obj (match_name: GEARS_PUZZLES_STANDARD_gcYxhNHhKlI.obj)
# [DEBUG] No match for: Gigabyte_GA78LMTUSB3_50_Motherboard_Micro_ATX_Socket_AM3_trt.obj (match_name: Gigabyte_GA78LMTUSB3_50_Motherboard_Micro_ATX_Socket_AM3.obj)
# [DEBUG] No match for: Gigabyte_GA970AUD3P_10_Motherboard_ATX_Socket_AM3_trt.obj (match_name: Gigabyte_GA970AUD3P_10_Motherboard_ATX_Socket_AM3.obj)
# [DEBUG] No match for: Granimals_20_Wooden_ABC_Blocks_Wagon_g2TinmUGGHI_trt.obj (match_name: Granimals_20_Wooden_ABC_Blocks_Wagon_g2TinmUGGHI.obj)
# [DEBUG] No match for: Grreat_Choice_Dog_Double_Dish_Plastic_Blue_trt.obj (match_name: Grreat_Choice_Dog_Double_Dish_Plastic_Blue.obj)
# [DEBUG] No match for: Home_Fashions_Washcloth_Linen_trt.obj (match_name: Home_Fashions_Washcloth_Linen.obj)
# [DEBUG] No match for: In_Green_Company_Surface_Saver_Ring_10_Terra_Cotta_trt.obj (match_name: In_Green_Company_Surface_Saver_Ring_10_Terra_Cotta.obj)
# [DEBUG] No match for: JA_Henckels_International_Premio_Cutlery_Block_Set_14Piece_trt.obj (match_name: JA_Henckels_International_Premio_Cutlery_Block_Set_14Piece.obj)
# [DEBUG] No match for: Kotobuki_Saucer_Dragon_Fly_trt.obj (match_name: Kotobuki_Saucer_Dragon_Fly.obj)
# [DEBUG] No match for: MY_MOOD_MEMO_trt.obj (match_name: MY_MOOD_MEMO.obj)
# [DEBUG] No match for: Magnifying_Glassassrt_trt.obj (match_name: Magnifying_Glassassrt.obj)
# [DEBUG] No match for: Markings_Letter_Holder_trt.obj (match_name: Markings_Letter_Holder.obj)
# [DEBUG] No match for: Nordic_Ware_Original_Bundt_Pan_trt.obj (match_name: Nordic_Ware_Original_Bundt_Pan.obj)
# [DEBUG] No match for: Now_Designs_Dish_Towel_Mojave_18_x_28_trt.obj (match_name: Now_Designs_Dish_Towel_Mojave_18_x_28.obj)
# [DEBUG] No match for: Now_Designs_Snack_Bags_Bicycle_2_count_trt.obj (match_name: Now_Designs_Snack_Bags_Bicycle_2_count.obj)
# [DEBUG] No match for: PUNCH_DROP_trt.obj (match_name: PUNCH_DROP.obj)
# [DEBUG] No match for: Perricoen_MD_No_Concealer_Concealer_trt.obj (match_name: Perricoen_MD_No_Concealer_Concealer.obj)
# [DEBUG] No match for: Perricone_MD_Blue_Plasma_Orbital_trt.obj (match_name: Perricone_MD_Blue_Plasma_Orbital.obj)
# [DEBUG] No match for: Poppin_File_Sorter_Pink_trt.obj (match_name: Poppin_File_Sorter_Pink.obj)
# [DEBUG] No match for: Progressive_Rubber_Spatulas_3_count_trt.obj (match_name: Progressive_Rubber_Spatulas_3_count.obj)
# [DEBUG] No match for: Provence_Bath_Towel_Royal_Blue_trt.obj (match_name: Provence_Bath_Towel_Royal_Blue.obj)
# [DEBUG] No match for: REEF_BANTU_trt.obj (match_name: REEF_BANTU.obj)
# [DEBUG] No match for: REEF_ZENFUN_trt.obj (match_name: REEF_ZENFUN.obj)
# [DEBUG] No match for: RJ_Rabbit_Easter_Basket_Blue_trt.obj (match_name: RJ_Rabbit_Easter_Basket_Blue.obj)
# [DEBUG] No match for: Racoon_trt.obj (match_name: Racoon.obj)
# [DEBUG] No match for: Razer_Goliathus_Control_Edition_Small_Soft_Gaming_Mouse_Mat_trt.obj (match_name: Razer_Goliathus_Control_Edition_Small_Soft_Gaming_Mouse_Mat.obj)
# [DEBUG] No match for: Razer_Naga_MMO_Gaming_Mouse_trt.obj (match_name: Razer_Naga_MMO_Gaming_Mouse.obj)
# [DEBUG] No match for: Razer_Taipan_Black_Ambidextrous_Gaming_Mouse_trt.obj (match_name: Razer_Taipan_Black_Ambidextrous_Gaming_Mouse.obj)
# [DEBUG] No match for: Rexy_Glove_Heavy_Duty_Large_trt.obj (match_name: Rexy_Glove_Heavy_Duty_Large.obj)
# [DEBUG] No match for: Room_Essentials_Mug_White_Yellow_trt.obj (match_name: Room_Essentials_Mug_White_Yellow.obj)
# [DEBUG] No match for: STEAK_SET_trt.obj (match_name: STEAK_SET.obj)
# [DEBUG] No match for: SANDWICH_MEAL_trt.obj (match_name: SANDWICH_MEAL.obj)
# [DEBUG] No match for: SAPPHIRE_R7_260X_OC_trt.obj (match_name: SAPPHIRE_R7_260X_OC.obj)
# [DEBUG] No match for: STACKING_BEAR_trt.obj (match_name: STACKING_BEAR.obj)
# [DEBUG] No match for: Sapota_Threshold_4_Ceramic_Round_Planter_Red_trt.obj (match_name: Sapota_Threshold_4_Ceramic_Round_Planter_Red.obj)
# [DEBUG] No match for: Sootheze_Toasty_Orca_trt.obj (match_name: Sootheze_Toasty_Orca.obj)
# [DEBUG] No match for: Squirrel_trt.obj (match_name: Squirrel.obj)
# [DEBUG] No match for: Sterilite_Caddy_Blue_Sky_17_58_x_12_58_x_9_14_trt.obj (match_name: Sterilite_Caddy_Blue_Sky_17_58_x_12_58_x_9_14.obj)
# [DEBUG] No match for: TABLEWARE_SET_5CHkPjjxVpp_trt.obj (match_name: TABLEWARE_SET_5CHkPjjxVpp.obj)
# [DEBUG] No match for: Tag_Dishtowel_Green_trt.obj (match_name: Tag_Dishtowel_Green.obj)
# [DEBUG] No match for: Tag_Dishtowel_Waffle_Gray_Checks_18_x_26_trt.obj (match_name: Tag_Dishtowel_Waffle_Gray_Checks_18_x_26.obj)
# [DEBUG] No match for: Threshold_Bead_Cereal_Bowl_White_trt.obj (match_name: Threshold_Bead_Cereal_Bowl_White.obj)
# [DEBUG] No match for: Threshold_Bistro_Ceramic_Dinner_Plate_Ruby_Ring_trt.obj (match_name: Threshold_Bistro_Ceramic_Dinner_Plate_Ruby_Ring.obj)
# [DEBUG] No match for: Threshold_Dinner_Plate_Square_Rim_White_Porcelain_trt.obj (match_name: Threshold_Dinner_Plate_Square_Rim_White_Porcelain.obj)
# [DEBUG] No match for: Threshold_Hand_Towel_Blue_Medallion_16_x_27_trt.obj (match_name: Threshold_Hand_Towel_Blue_Medallion_16_x_27.obj)
# [DEBUG] No match for: Threshold_Porcelain_Coffee_Mug_All_Over_Bead_White_trt.obj (match_name: Threshold_Porcelain_Coffee_Mug_All_Over_Bead_White.obj)
# [DEBUG] No match for: Vtech_Roll_Learn_Turtle_trt.obj (match_name: Vtech_Roll_Learn_Turtle.obj)
# [DEBUG] No match for: Weisshai_Great_White_Shark_trt.obj (match_name: Weisshai_Great_White_Shark.obj)
# Moved: 60_CONSTRUCTION_SET_trt.obj from /Google_Dataset_Outputs to /home/rayhub-user/Optim-WaLa/Benchmark_quality/Tensor_RT
# [DEBUG] No match for: Asus_X99Deluxe_Motherboard_ATX_LGA2011v3_Socket_trt.obj (match_name: Asus_X99Deluxe_Motherboard_ATX_LGA2011v3_Socket.obj)
# [DEBUG] No match for: Azure_Snake_Tieks_Leather_Snake_Print_Ballet_Flats_trt.obj (match_name: Azure_Snake_Tieks_Leather_Snake_Print_Ballet_Flats.obj)
# [DEBUG] No match for: BRAILLE_ALPHABET_AZ_trt.obj (match_name: BRAILLE_ALPHABET_AZ.obj)
# [DEBUG] No match for: BUNNY_RACER_trt.obj (match_name: BUNNY_RACER.obj)
# [DEBUG] No match for: CHILDRENS_ROOM_NEO_trt.obj (match_name: CHILDRENS_ROOM_NEO.obj)
# [DEBUG] No match for: Cascadia_8_Color_AquariusHibscsBearingSeaBlk_Size_50_trt.obj (match_name: Cascadia_8_Color_AquariusHibscsBearingSeaBlk_Size_50.obj)
# [DEBUG] No match for: ClimaCool_Aerate_2_W_Wide_trt.obj (match_name: ClimaCool_Aerate_2_W_Wide.obj)
# [DEBUG] No match for: Clue_Board_Game_Classic_Edition_trt.obj (match_name: Clue_Board_Game_Classic_Edition.obj)
# [DEBUG] No match for: Colton_Wntr_Chukka_y4jO0I8JQFW_trt.obj (match_name: Colton_Wntr_Chukka_y4jO0I8JQFW.obj)
# [DEBUG] No match for: Crazy_Shadow_2_trt.obj (match_name: Crazy_Shadow_2.obj)
# [DEBUG] No match for: Crazy_Shadow_2_oW4Jd10HFFr_trt.obj (match_name: Crazy_Shadow_2_oW4Jd10HFFr.obj)
# [DEBUG] No match for: Epson_Ink_Cartridge_Black_200_trt.obj (match_name: Epson_Ink_Cartridge_Black_200.obj)
# [DEBUG] No match for: F5_TRX_FG_trt.obj (match_name: F5_TRX_FG.obj)
# [DEBUG] No match for: FAIRY_TALE_BLOCKS_trt.obj (match_name: FAIRY_TALE_BLOCKS.obj)
# [DEBUG] No match for: FRUIT_VEGGIE_MEMO_GRADIENT_trt.obj (match_name: FRUIT_VEGGIE_MEMO_GRADIENT.obj)
# [DEBUG] No match for: Great_Jones_Wingtip_wxH3dbtlvBC_trt.obj (match_name: Great_Jones_Wingtip_wxH3dbtlvBC.obj)
# [DEBUG] No match for: HELICOPTER_trt.obj (match_name: HELICOPTER.obj)
# [DEBUG] No match for: Hasbro_Trivial_Pursuit_Family_Edition_Game_trt.obj (match_name: Hasbro_Trivial_Pursuit_Family_Edition_Game.obj)
# [DEBUG] No match for: Horse_Dreams_Pencil_Case_trt.obj (match_name: Horse_Dreams_Pencil_Case.obj)
# [DEBUG] No match for: IsoRich_Soy_trt.obj (match_name: IsoRich_Soy.obj)
# [DEBUG] No match for: Just_For_Men_Mustache_Beard_Brushin_Hair_Color_Gel_Kit_Jet_Black_M60_trt.obj (match_name: Just_For_Men_Mustache_Beard_Brushin_Hair_Color_Gel_Kit_Jet_Black_M60.obj)
# [DEBUG] No match for: Just_For_Men_Mustache_Beard_Brushin_Hair_Color_Gel_MediumDark_Brown_M40_trt.obj (match_name: Just_For_Men_Mustache_Beard_Brushin_Hair_Color_Gel_MediumDark_Brown_M40.obj)
# [DEBUG] No match for: Just_For_Men_ShampooIn_Haircolor_Jet_Black_60_trt.obj (match_name: Just_For_Men_ShampooIn_Haircolor_Jet_Black_60.obj)
# [DEBUG] No match for: Just_For_Men_ShampooIn_Haircolor_Light_Brown_25_trt.obj (match_name: Just_For_Men_ShampooIn_Haircolor_Light_Brown_25.obj)
# [DEBUG] No match for: Kid_Icarus_Uprising_Nintendo_3DS_Game_trt.obj (match_name: Kid_Icarus_Uprising_Nintendo_3DS_Game.obj)
# [DEBUG] No match for: Kingston_DT4000MR_G2_Management_Ready_USB_64GB_trt.obj (match_name: Kingston_DT4000MR_G2_Management_Ready_USB_64GB.obj)
# [DEBUG] No match for: Kotex_U_Tween_Pads_16_pads_trt.obj (match_name: Kotex_U_Tween_Pads_16_pads.obj)
# [DEBUG] No match for: Melissa_Doug_Chunky_Puzzle_Vehicles_trt.obj (match_name: Melissa_Doug_Chunky_Puzzle_Vehicles.obj)
# [DEBUG] No match for: Melissa_Doug_Pattern_Blocks_and_Boards_trt.obj (match_name: Melissa_Doug_Pattern_Blocks_and_Boards.obj)
# [DEBUG] No match for: Mens_ASV_Billfish_Boat_Shoe_in_Tan_Leather_wmUJ5PbwANc_trt.obj (match_name: Mens_ASV_Billfish_Boat_Shoe_in_Tan_Leather_wmUJ5PbwANc.obj)
# [DEBUG] No match for: Mens_Authentic_Original_Boat_Shoe_in_Navy_Leather_RpT4GvUXRRP_trt.obj (match_name: Mens_Authentic_Original_Boat_Shoe_in_Navy_Leather_RpT4GvUXRRP.obj)
# [DEBUG] No match for: Mens_Bahama_in_Black_b4ADzYywRHl_trt.obj (match_name: Mens_Bahama_in_Black_b4ADzYywRHl.obj)
# [DEBUG] No match for: Mens_Bahama_in_Khaki_Oyster_xU2jeqYwhQJ_trt.obj (match_name: Mens_Bahama_in_Khaki_Oyster_xU2jeqYwhQJ.obj)
# [DEBUG] No match for: Mens_Billfish_3Eye_Boat_Shoe_in_Dark_Tan_wyns9HRcEuH_trt.obj (match_name: Mens_Billfish_3Eye_Boat_Shoe_in_Dark_Tan_wyns9HRcEuH.obj)
# [DEBUG] No match for: Metallic_Pewter_Tieks_Italian_Leather_Ballet_Flats_trt.obj (match_name: Metallic_Pewter_Tieks_Italian_Leather_Ballet_Flats.obj)
# [DEBUG] No match for: NUTS_BOLTS_trt.obj (match_name: NUTS_BOLTS.obj)
# [DEBUG] No match for: Netgear_Ac1750_Router_Wireless_Dual_Band_Gigabit_Router_trt.obj (match_name: Netgear_Ac1750_Router_Wireless_Dual_Band_Gigabit_Router.obj)
# [DEBUG] No match for: Netgear_N750_Wireless_Dual_Band_Gigabit_Router_trt.obj (match_name: Netgear_N750_Wireless_Dual_Band_Gigabit_Router.obj)
# [DEBUG] No match for: Nickelodeon_The_Spongebob_Movie_PopAPart_Spongebob_trt.obj (match_name: Nickelodeon_The_Spongebob_Movie_PopAPart_Spongebob.obj)
# [DEBUG] No match for: Nikon_1_AW1_w11275mm_Lens_Silver_trt.obj (match_name: Nikon_1_AW1_w11275mm_Lens_Silver.obj)
# [DEBUG] No match for: Nintendo_2DS_Crimson_Red_trt.obj (match_name: Nintendo_2DS_Crimson_Red.obj)
# [DEBUG] No match for: OWL_SORTER_trt.obj (match_name: OWL_SORTER.obj)
# [DEBUG] No match for: Office_Depot_Canon_CLI_221BK_Ink_Cartridge_Black_2946B001_trt.obj (match_name: Office_Depot_Canon_CLI_221BK_Ink_Cartridge_Black_2946B001.obj)
# [DEBUG] No match for: Office_Depot_Canon_PG21XL_Remanufactured_Ink_Cartridge_Black_trt.obj (match_name: Office_Depot_Canon_PG21XL_Remanufactured_Ink_Cartridge_Black.obj)
# [DEBUG] No match for: Paint_Maker_trt.obj (match_name: Paint_Maker.obj)
# [DEBUG] No match for: Pet_Dophilus_powder_trt.obj (match_name: Pet_Dophilus_powder.obj)
# [DEBUG] No match for: Philips_60ct_Warm_White_LED_Smooth_Mini_String_Lights_trt.obj (match_name: Philips_60ct_Warm_White_LED_Smooth_Mini_String_Lights.obj)
# [DEBUG] No match for: Philips_Sonicare_Tooth_Brush_2_count_trt.obj (match_name: Philips_Sonicare_Tooth_Brush_2_count.obj)
# [DEBUG] No match for: PhosphOmega_trt.obj (match_name: PhosphOmega.obj)
# [DEBUG] No match for: Playmates_nickelodeon_teenage_mutant_ninja_turtles_shredder_trt.obj (match_name: Playmates_nickelodeon_teenage_mutant_ninja_turtles_shredder.obj)
# [DEBUG] No match for: ROAD_CONSTRUCTION_SET_trt.obj (match_name: ROAD_CONSTRUCTION_SET.obj)
# [DEBUG] No match for: Reebok_FS_HI_INT_R12_trt.obj (match_name: Reebok_FS_HI_INT_R12.obj)
# [DEBUG] No match for: Reebok_FS_HI_MINI_trt.obj (match_name: Reebok_FS_HI_MINI.obj)
# [DEBUG] No match for: Reebok_REESCULPT_TRAINER_II_trt.obj (match_name: Reebok_REESCULPT_TRAINER_II.obj)
# [DEBUG] No match for: Reebok_SL_FLIP_UPDATE_trt.obj (match_name: Reebok_SL_FLIP_UPDATE.obj)
# [DEBUG] No match for: Reebok_TRIPLE_BREAK_LITE_trt.obj (match_name: Reebok_TRIPLE_BREAK_LITE.obj)
# [DEBUG] No match for: Reebok_ULTIMATIC_2V_trt.obj (match_name: Reebok_ULTIMATIC_2V.obj)
# [DEBUG] No match for: Reebok_ZIGCOOPERSTOWN_QUAG_trt.obj (match_name: Reebok_ZIGCOOPERSTOWN_QUAG.obj)
# [DEBUG] No match for: Reebok_ZIGSTORM_trt.obj (match_name: Reebok_ZIGSTORM.obj)
# [DEBUG] No match for: Reebok_ZIGTECH_SHARK_MAYHEM360_trt.obj (match_name: Reebok_ZIGTECH_SHARK_MAYHEM360.obj)
# [DEBUG] No match for: Remington_1_12_inch_Hair_Straightener_trt.obj (match_name: Remington_1_12_inch_Hair_Straightener.obj)
# [DEBUG] No match for: SAMe_200_trt.obj (match_name: SAMe_200.obj)
# [DEBUG] No match for: Womens_Angelfish_Boat_Shoe_in_Linen_Oat_trt.obj (match_name: Womens_Angelfish_Boat_Shoe_in_Linen_Oat.obj)
# [DEBUG] No match for: Womens_Bluefish_2Eye_Boat_Shoe_in_Linen_Oat_IbrSyJdpT3h_trt.obj (match_name: Womens_Bluefish_2Eye_Boat_Shoe_in_Linen_Oat_IbrSyJdpT3h.obj)
# [DEBUG] No match for: adizero_5Tool_25_trt.obj (match_name: adizero_5Tool_25.obj)
# [DEBUG] No match for: Ecoforms_Plant_Saucer_SQ8COR_trt.obj (match_name: Ecoforms_Plant_Saucer_SQ8COR.obj)
# [DEBUG] No match for: Ecoforms_Plate_S20Avocado_trt.obj (match_name: Ecoforms_Plate_S20Avocado.obj)
# [DEBUG] No match for: Focus_8643_Lime_Squeezer_10x35x188_Enamelled_Aluminum_Light_trt.obj (match_name: Focus_8643_Lime_Squeezer_10x35x188_Enamelled_Aluminum_Light.obj)
# [DEBUG] No match for: GEOMETRIC_SORTING_BOARD_trt.obj (match_name: GEOMETRIC_SORTING_BOARD.obj)
# [DEBUG] No match for: GEOMETRIC_SORTING_BOARD_MNi4Rbuz9vj_trt.obj (match_name: GEOMETRIC_SORTING_BOARD_MNi4Rbuz9vj.obj)
# [DEBUG] No match for: HeavyDuty_Flashlight_trt.obj (match_name: HeavyDuty_Flashlight.obj)
# [DEBUG] No match for: Hilary_trt.obj (match_name: Hilary.obj)
# [DEBUG] No match for: OXO_Cookie_Spatula_trt.obj (match_name: OXO_Cookie_Spatula.obj)
# [DEBUG] No match for: Object_REmvBDJStub_trt.obj (match_name: Object_REmvBDJStub.obj)
# [DEBUG] No match for: Ortho_Forward_Facing_trt.obj (match_name: Ortho_Forward_Facing.obj)
# [DEBUG] No match for: Ortho_Forward_Facing_CkAW6rL25xH_trt.obj (match_name: Ortho_Forward_Facing_CkAW6rL25xH.obj)
# [DEBUG] No match for: PARENT_ROOM_FURNITURE_SET_1_trt.obj (match_name: PARENT_ROOM_FURNITURE_SET_1.obj)
# [DEBUG] No match for: Perricone_MD_Cold_Plasma_trt.obj (match_name: Perricone_MD_Cold_Plasma.obj)
# [DEBUG] No match for: Perricone_MD_Neuropeptide_Facial_Conformer_trt.obj (match_name: Perricone_MD_Neuropeptide_Facial_Conformer.obj)
# [DEBUG] No match for: Perricone_MD_Neuropeptide_Firming_Moisturizer_trt.obj (match_name: Perricone_MD_Neuropeptide_Firming_Moisturizer.obj)
# [DEBUG] No match for: Perricone_MD_No_Bronzer_Bronzer_trt.obj (match_name: Perricone_MD_No_Bronzer_Bronzer.obj)
# [DEBUG] No match for: Perricone_MD_No_Foundation_Serum_trt.obj (match_name: Perricone_MD_No_Foundation_Serum.obj)
# [DEBUG] No match for: Perricone_MD_No_Lipstick_Lipstick_trt.obj (match_name: Perricone_MD_No_Lipstick_Lipstick.obj)
# [DEBUG] No match for: Perricone_MD_No_Mascara_Mascara_trt.obj (match_name: Perricone_MD_No_Mascara_Mascara.obj)
# [DEBUG] No match for: Perricone_MD_Nutritive_Cleanser_trt.obj (match_name: Perricone_MD_Nutritive_Cleanser.obj)
# [DEBUG] No match for: Perricone_MD_The_Crease_Cure_Duo_trt.obj (match_name: Perricone_MD_The_Crease_Cure_Duo.obj)
# [DEBUG] No match for: Perricone_MD_The_Metabolic_Formula_Supplements_trt.obj (match_name: Perricone_MD_The_Metabolic_Formula_Supplements.obj)
# [DEBUG] No match for: Perricone_MD_Vitamin_C_Ester_15_trt.obj (match_name: Perricone_MD_Vitamin_C_Ester_15.obj)
# [DEBUG] No match for: Razer_BlackWidow_Ultimate_2014_Mechanical_Gaming_Keyboard_trt.obj (match_name: Razer_BlackWidow_Ultimate_2014_Mechanical_Gaming_Keyboard.obj)
# [DEBUG] No match for: Razer_Blackwidow_Tournament_Edition_Keyboard_trt.obj (match_name: Razer_Blackwidow_Tournament_Edition_Keyboard.obj)
# [DEBUG] No match for: Remington_TStudio_Hair_Dryer_trt.obj (match_name: Remington_TStudio_Hair_Dryer.obj)
# [DEBUG] No match for: SHAPE_SORTER_trt.obj (match_name: SHAPE_SORTER.obj)
# [DEBUG] No match for: Schleich_African_Black_Rhino_trt.obj (match_name: Schleich_African_Black_Rhino.obj)
# [DEBUG] No match for: Schleich_S_Bayala_Unicorn_70432_trt.obj (match_name: Schleich_S_Bayala_Unicorn_70432.obj)
# [DEBUG] No match for: Spritz_Easter_Basket_Plastic_Teal_trt.obj (match_name: Spritz_Easter_Basket_Plastic_Teal.obj)
# [DEBUG] No match for: TEA_SET_trt.obj (match_name: TEA_SET.obj)
# [DEBUG] No match for: Threshold_Porcelain_Teapot_White_trt.obj (match_name: Threshold_Porcelain_Teapot_White.obj)
# [DEBUG] No match for: Top_Paw_Dog_Bow_Bone_Ceramic_13_fl_oz_total_trt.obj (match_name: Top_Paw_Dog_Bow_Bone_Ceramic_13_fl_oz_total.obj)
# [DEBUG] No match for: VEGETABLE_GARDEN_trt.obj (match_name: VEGETABLE_GARDEN.obj)
# [DEBUG] No match for: ASICS_GEL1140V_WhiteRoyalSilver_trt.obj (match_name: ASICS_GEL1140V_WhiteRoyalSilver.obj)
# [DEBUG] No match for: ASICS_GELLinksmaster_WhiteSilverCarolina_Blue_trt.obj (match_name: ASICS_GELLinksmaster_WhiteSilverCarolina_Blue.obj)
# [DEBUG] No match for: ASICS_GELResolution_5_Flash_YellowBlackSilver_trt.obj (match_name: ASICS_GELResolution_5_Flash_YellowBlackSilver.obj)
# [DEBUG] No match for: AllergenFree_JarroDophilus_trt.obj (match_name: AllergenFree_JarroDophilus.obj)
# [DEBUG] No match for: Android_Figure_Chrome_trt.obj (match_name: Android_Figure_Chrome.obj)
# [DEBUG] No match for: Asus_80211ac_DualBand_Gigabit_Wireless_Router_RTAC68R_trt.obj (match_name: Asus_80211ac_DualBand_Gigabit_Wireless_Router_RTAC68R.obj)
# [DEBUG] No match for: Beta_Glucan_trt.obj (match_name: Beta_Glucan.obj)
# ...
# [DEBUG] No match for: OXO_Soft_Works_Can_Opener_SnapLock_trt.obj (match_name: OXO_Soft_Works_Can_Opener_SnapLock.obj)
# [DEBUG] No match for: Ocedar_Snap_On_Dust_Pan_And_Brush_1_ct_trt.obj (match_name: Ocedar_Snap_On_Dust_Pan_And_Brush_1_ct.obj)
# [DEBUG] No match for: Ortho_Forward_Facing_QCaor9ImJ2G_trt.obj (match_name: Ortho_Forward_Facing_QCaor9ImJ2G.obj)
# [DEBUG] No match for: Pepsi_Caffeine_Free_Diet_12_CT_trt.obj (match_name: Pepsi_Caffeine_Free_Diet_12_CT.obj)
# [DEBUG] No match for: Pepsi_Cola_Caffeine_Free_12_12_fl_oz_355_ml_cans_144_fl_oz_426_lt_trt.obj (match_name: Pepsi_Cola_Caffeine_Free_12_12_fl_oz_355_ml_cans_144_fl_oz_426_lt.obj)
# [DEBUG] No match for: Perricone_MD_High_Potency_Evening_Repair_trt.obj (match_name: Perricone_MD_High_Potency_Evening_Repair.obj)
# [DEBUG] No match for: Perricone_MD_The_Cold_Plasma_Face_Eyes_Duo_trt.obj (match_name: Perricone_MD_The_Cold_Plasma_Face_Eyes_Duo.obj)
# [DEBUG] No match for: REEF_BRAIDED_CUSHION_trt.obj (match_name: REEF_BRAIDED_CUSHION.obj)
# [DEBUG] No match for: Razer_Taipan_White_Ambidextrous_Gaming_Mouse_trt.obj (match_name: Razer_Taipan_White_Ambidextrous_Gaming_Mouse.obj)
# [DEBUG] No match for: Retail_Leadership_Summit_tQFCizMt6g0_trt.obj (match_name: Retail_Leadership_Summit_tQFCizMt6g0.obj)
# [DEBUG] No match for: Room_Essentials_Dish_Drainer_Collapsible_White_trt.obj (match_name: Room_Essentials_Dish_Drainer_Collapsible_White.obj)
# [DEBUG] No match for: Room_Essentials_Salad_Plate_Turquoise_trt.obj (match_name: Room_Essentials_Salad_Plate_Turquoise.obj)
# [DEBUG] No match for: Rubbermaid_Large_Drainer_trt.obj (match_name: Rubbermaid_Large_Drainer.obj)
# [DEBUG] No match for: SORTING_BUS_trt.obj (match_name: SORTING_BUS.obj)
# [DEBUG] No match for: SORTING_TRAIN_trt.obj (match_name: SORTING_TRAIN.obj)
# [DEBUG] No match for: STACKING_BEAR_V04KKgGBn2A_trt.obj (match_name: STACKING_BEAR_V04KKgGBn2A.obj)
# [DEBUG] No match for: STACKING_RING_trt.obj (match_name: STACKING_RING.obj)
# [DEBUG] No match for: Schleich_Bald_Eagle_trt.obj (match_name: Schleich_Bald_Eagle.obj)
# [DEBUG] No match for: Schleich_Hereford_Bull_trt.obj (match_name: Schleich_Hereford_Bull.obj)
# [DEBUG] No match for: Schleich_Spinosaurus_Action_Figure_trt.obj (match_name: Schleich_Spinosaurus_Action_Figure.obj)
# [DEBUG] No match for: Schleich_Therizinosaurus_ln9cruulPqc_trt.obj (match_name: Schleich_Therizinosaurus_ln9cruulPqc.obj)
# [DEBUG] No match for: Shark_trt.obj (match_name: Shark.obj)
# [DEBUG] No match for: Shaxon_100_Molded_Category_6_RJ45RJ45_Shielded_Patch_Cord_White_trt.obj (match_name: Shaxon_100_Molded_Category_6_RJ45RJ45_Shielded_Patch_Cord_White.obj)
# [DEBUG] No match for: Sootheze_Cold_Therapy_Elephant_trt.obj (match_name: Sootheze_Cold_Therapy_Elephant.obj)
# [DEBUG] No match for: TWISTED_PUZZLE_twb4AyFtu8Q_trt.obj (match_name: TWISTED_PUZZLE_twb4AyFtu8Q.obj)
# [DEBUG] No match for: TWIST_SHAPE_trt.obj (match_name: TWIST_SHAPE.obj)
# [DEBUG] No match for: Tag_Dishtowel_18_x_26_trt.obj (match_name: Tag_Dishtowel_18_x_26.obj)
# [DEBUG] No match for: Tag_Dishtowel_Dobby_Stripe_Blue_18_x_26_trt.obj (match_name: Tag_Dishtowel_Dobby_Stripe_Blue_18_x_26.obj)
# [DEBUG] No match for: Target_Basket_Medium_trt.obj (match_name: Target_Basket_Medium.obj)
# [DEBUG] No match for: Threshold_Bamboo_Ceramic_Soap_Dish_trt.obj (match_name: Threshold_Bamboo_Ceramic_Soap_Dish.obj)
# [DEBUG] No match for: Threshold_Basket_Natural_Finish_Fabric_Liner_Small_trt.obj (match_name: Threshold_Basket_Natural_Finish_Fabric_Liner_Small.obj)
# [DEBUG] No match for: Threshold_Ramekin_White_Porcelain_trt.obj (match_name: Threshold_Ramekin_White_Porcelain.obj)
# [DEBUG] No match for: Threshold_Salad_Plate_Square_Rim_Porcelain_trt.obj (match_name: Threshold_Salad_Plate_Square_Rim_Porcelain.obj)
# [DEBUG] No match for: Toys_R_Us_Treat_Dispenser_Smart_Puzzle_Foobler_trt.obj (match_name: Toys_R_Us_Treat_Dispenser_Smart_Puzzle_Foobler.obj)
# [DEBUG] No match for: Toysmith_Windem_Up_Flippin_Animals_Dog_trt.obj (match_name: Toysmith_Windem_Up_Flippin_Animals_Dog.obj)
# [DEBUG] No match for: TriStar_Products_PPC_Power_Pressure_Cooker_XL_in_Black_trt.obj (match_name: TriStar_Products_PPC_Power_Pressure_Cooker_XL_in_Black.obj)
# [DEBUG] No match for: Ubisoft_RockSmith_Real_Tone_Cable_Xbox_360_trt.obj (match_name: Ubisoft_RockSmith_Real_Tone_Cable_Xbox_360.obj)
# [DEBUG] No match for: Vtech_Stack_Sing_Rings_636_Months_trt.obj (match_name: Vtech_Stack_Sing_Rings_636_Months.obj)
# [DEBUG] No match for: ASICS_GELChallenger_9_Royal_BlueWhiteBlack_trt.obj (match_name: ASICS_GELChallenger_9_Royal_BlueWhiteBlack.obj)
# [DEBUG] No match for: ASICS_GELLinksmaster_WhiteRasberryGunmetal_trt.obj (match_name: ASICS_GELLinksmaster_WhiteRasberryGunmetal.obj)
# [DEBUG] No match for: ASICS_HyperRocketgirl_SP_5_WhiteMalibu_BlueBlack_trt.obj (match_name: ASICS_HyperRocketgirl_SP_5_WhiteMalibu_BlueBlack.obj)
# [DEBUG] No match for: Android_Figure_Orange_trt.obj (match_name: Android_Figure_Orange.obj)
# [DEBUG] No match for: Asus_Z97IPLUS_Motherboard_Mini_ITX_LGA1150_Socket_trt.obj (match_name: Asus_Z97IPLUS_Motherboard_Mini_ITX_LGA1150_Socket.obj)
# [DEBUG] No match for: BALANCING_CACTUS_trt.obj (match_name: BALANCING_CACTUS.obj)
# [DEBUG] No match for: Balderdash_Game_trt.obj (match_name: Balderdash_Game.obj)
# [DEBUG] No match for: Beyonc_Life_is_But_a_Dream_DVD_trt.obj (match_name: Beyonc_Life_is_But_a_Dream_DVD.obj)
# [DEBUG] No match for: Black_and_Decker_TR3500SD_2Slice_Toaster_trt.obj (match_name: Black_and_Decker_TR3500SD_2Slice_Toaster.obj)
# [DEBUG] No match for: Blackcurrant_Lutein_trt.obj (match_name: Blackcurrant_Lutein.obj)
# [DEBUG] No match for: Borage_GLA240Gamma_Tocopherol_trt.obj (match_name: Borage_GLA240Gamma_Tocopherol.obj)
# [DEBUG] No match for: CHICKEN_RACER_trt.obj (match_name: CHICKEN_RACER.obj)
# [DEBUG] No match for: COAST_GUARD_BOAT_trt.obj (match_name: COAST_GUARD_BOAT.obj)
# [DEBUG] No match for: CREATIVE_BLOCKS_35_MM_trt.obj (match_name: CREATIVE_BLOCKS_35_MM.obj)
# [DEBUG] No match for: Canon_Ink_Cartridge_Green_6_trt.obj (match_name: Canon_Ink_Cartridge_Green_6.obj)
# [DEBUG] No match for: Canon_Pixma_Chromalife_100_Magenta_8_trt.obj (match_name: Canon_Pixma_Chromalife_100_Magenta_8.obj)
# [DEBUG] No match for: Chelsea_BlkHeelPMP_DwxLtZNxLZZ_trt.obj (match_name: Chelsea_BlkHeelPMP_DwxLtZNxLZZ.obj)
# [DEBUG] No match for: CoQ10_BjTLbuRVt1t_trt.obj (match_name: CoQ10_BjTLbuRVt1t.obj)
# [DEBUG] No match for: Connect_4_Launchers_trt.obj (match_name: Connect_4_Launchers.obj)
# [DEBUG] No match for: Copperhead_Snake_Tieks_Brown_Snake_Print_Ballet_Flats_trt.obj (match_name: Copperhead_Snake_Tieks_Brown_Snake_Print_Ballet_Flats.obj)
# [DEBUG] No match for: Court_Attitude_trt.obj (match_name: Court_Attitude.obj)
# [DEBUG] No match for: Crayola_Crayons_120_crayons_trt.obj (match_name: Crayola_Crayons_120_crayons.obj)
# [DEBUG] No match for: Crayola_Model_Magic_Modeling_Material_Single_Packs_6_pack_05_oz_packs_trt.obj (match_name: Crayola_Model_Magic_Modeling_Material_Single_Packs_6_pack_05_oz_packs.obj)
# [DEBUG] No match for: Crazy_8_trt.obj (match_name: Crazy_8.obj)
# [DEBUG] No match for: Creatine_Monohydrate_trt.obj (match_name: Creatine_Monohydrate.obj)
# [DEBUG] No match for: DRAGON_W_trt.obj (match_name: DRAGON_W.obj)
# [DEBUG] No match for: Don_Franciscos_Gourmet_Coffee_Medium_Decaf_100_Colombian_12_oz_340_g_trt.obj (match_name: Don_Franciscos_Gourmet_Coffee_Medium_Decaf_100_Colombian_12_oz_340_g.obj)
# [DEBUG] No match for: ENFR_MID_ENFORCER_trt.obj (match_name: ENFR_MID_ENFORCER.obj)
# [DEBUG] No match for: Epson_273XL_Ink_Cartridge_Magenta_trt.obj (match_name: Epson_273XL_Ink_Cartridge_Magenta.obj)
# [DEBUG] No match for: Epson_UltraChrome_T0548_Ink_Cartridge_Matte_Black_1pack_trt.obj (match_name: Epson_UltraChrome_T0548_Ink_Cartridge_Matte_Black_1pack.obj)
# [DEBUG] No match for: F10_TRX_TF_rH7tmKCdUJq_trt.obj (match_name: F10_TRX_TF_rH7tmKCdUJq.obj)
# [DEBUG] No match for: FIRE_ENGINE_trt.obj (match_name: FIRE_ENGINE.obj)
# [DEBUG] No match for: FIRE_TRUCK_trt.obj (match_name: FIRE_TRUCK.obj)
# [DEBUG] No match for: FisherPrice_Make_A_Match_Game_Thomas_Friends_trt.obj (match_name: FisherPrice_Make_A_Match_Game_Thomas_Friends.obj)
# [DEBUG] No match for: Folic_Acid_trt.obj (match_name: Folic_Acid.obj)
# [DEBUG] No match for: Frozen_Olafs_In_Trouble_PopOMatic_Game_OEu83W9T8pD_trt.obj (match_name: Frozen_Olafs_In_Trouble_PopOMatic_Game_OEu83W9T8pD.obj)
# [DEBUG] No match for: GRANDMOTHER_trt.obj (match_name: GRANDMOTHER.obj)
# [DEBUG] No match for: Glycerin_11_Color_BrllntBluSkydvrSlvrBlckWht_Size_80_trt.obj (match_name: Glycerin_11_Color_BrllntBluSkydvrSlvrBlckWht_Size_80.obj)
# [DEBUG] No match for: Great_Jones_Wingtip_j5NV8GRnitM_trt.obj (match_name: Great_Jones_Wingtip_j5NV8GRnitM.obj)
# [DEBUG] No match for: Great_Jones_Wingtip_kAqSg6EgG0I_trt.obj (match_name: Great_Jones_Wingtip_kAqSg6EgG0I.obj)
# [DEBUG] No match for: Guardians_of_the_Galaxy_Galactic_Battlers_Rocket_Raccoon_Figure_trt.obj (match_name: Guardians_of_the_Galaxy_Galactic_Battlers_Rocket_Raccoon_Figure.obj)
# [DEBUG] No match for: Hey_You_Pikachu_Nintendo_64_trt.obj (match_name: Hey_You_Pikachu_Nintendo_64.obj)
# [DEBUG] No match for: JUNGLE_HEIGHT_trt.obj (match_name: JUNGLE_HEIGHT.obj)
# [DEBUG] No match for: JarroDophilusFOS_Value_Size_trt.obj (match_name: JarroDophilusFOS_Value_Size.obj)
# [DEBUG] No match for: JarroSil_Activated_Silicon_trt.obj (match_name: JarroSil_Activated_Silicon.obj)
# [DEBUG] No match for: Kotex_U_Barely_There_Liners_Thin_60_count_trt.obj (match_name: Kotex_U_Barely_There_Liners_Thin_60_count.obj)
# [DEBUG] No match for: LADYBUG_BEAD_trt.obj (match_name: LADYBUG_BEAD.obj)
# [DEBUG] No match for: LEGO_Fusion_Set_Town_Master_trt.obj (match_name: LEGO_Fusion_Set_Town_Master.obj)
# [DEBUG] No match for: Lalaloopsy_Peanut_Big_Top_Tricycle_trt.obj (match_name: Lalaloopsy_Peanut_Big_Top_Tricycle.obj)
# [DEBUG] No match for: Lego_Friends_Mia_trt.obj (match_name: Lego_Friends_Mia.obj)
# [DEBUG] No match for: MINI_EXCAVATOR_trt.obj (match_name: MINI_EXCAVATOR.obj)
# [DEBUG] No match for: MINI_FIRE_ENGINE_trt.obj (match_name: MINI_FIRE_ENGINE.obj)
# [DEBUG] No match for: MOVING_MOUSE_PW_6PCSSET_trt.obj (match_name: MOVING_MOUSE_PW_6PCSSET.obj)
# [DEBUG] No match for: Marc_Anthony_Skip_Professional_Oil_of_Morocco_Conditioner_with_Argan_Oil_trt.obj (match_name: Marc_Anthony_Skip_Professional_Oil_of_Morocco_Conditioner_with_Argan_Oil.obj)
# [DEBUG] No match for: Marc_Anthony_True_Professional_Strictly_Curls_Curl_Defining_Lotion_trt.obj (match_name: Marc_Anthony_True_Professional_Strictly_Curls_Curl_Defining_Lotion.obj)
# [DEBUG] No match for: Matte_Black_Tieks_Italian_Leather_Ballet_Flats_trt.obj (match_name: Matte_Black_Tieks_Italian_Leather_Ballet_Flats.obj)
# [DEBUG] No match for: Mens_Billfish_Ultra_Lite_Boat_Shoe_in_Dark_Brown_Blue_c6zDZTtRJr6_trt.obj (match_name: Mens_Billfish_Ultra_Lite_Boat_Shoe_in_Dark_Brown_Blue_c6zDZTtRJr6.obj)
# [DEBUG] No match for: Mens_Santa_Cruz_Thong_in_Chocolate_La1fo2mAovE_trt.obj (match_name: Mens_Santa_Cruz_Thong_in_Chocolate_La1fo2mAovE.obj)
# [DEBUG] No match for: My_Monopoly_Board_Game_trt.obj (match_name: My_Monopoly_Board_Game.obj)
# [DEBUG] No match for: NAPA_VALLEY_NAVAJO_SANDAL_trt.obj (match_name: NAPA_VALLEY_NAVAJO_SANDAL.obj)
# [DEBUG] No match for: NESCAFE_NESCAFE_TC_STKS_DECAF_6_CT_trt.obj (match_name: NESCAFE_NESCAFE_TC_STKS_DECAF_6_CT.obj)
# [DEBUG] No match for: Nintendo_Mario_Action_Figure_trt.obj (match_name: Nintendo_Mario_Action_Figure.obj)
# [DEBUG] No match for: Nintendo_Yoshi_Action_Figure_trt.obj (match_name: Nintendo_Yoshi_Action_Figure.obj)
# [DEBUG] No match for: Office_Depot_Dell_Series_5_Remanufactured_Ink_Cartridge_Black_trt.obj (match_name: Office_Depot_Dell_Series_5_Remanufactured_Ink_Cartridge_Black.obj)
# [DEBUG] No match for: Office_Depot_Dell_Series_9_Color_Ink_Ink_Cartridge_MK991_MK993_trt.obj (match_name: Office_Depot_Dell_Series_9_Color_Ink_Ink_Cartridge_MK991_MK993.obj)
# [DEBUG] No match for: Office_Depot_HP_564XL_Ink_Cartridge_Black_CN684WN_trt.obj (match_name: Office_Depot_HP_564XL_Ink_Cartridge_Black_CN684WN.obj)
# [DEBUG] No match for: Office_Depot_HP_61Tricolor_Ink_Cartridge_trt.obj (match_name: Office_Depot_HP_61Tricolor_Ink_Cartridge.obj)
# [DEBUG] No match for: Office_Depot_HP_950XL_Ink_Cartridge_Black_CN045AN_trt.obj (match_name: Office_Depot_HP_950XL_Ink_Cartridge_Black_CN045AN.obj)
# [DEBUG] No match for: Olive_Kids_Butterfly_Garden_Munch_n_Lunch_Bag_trt.obj (match_name: Olive_Kids_Butterfly_Garden_Munch_n_Lunch_Bag.obj)
# [DEBUG] No match for: Olive_Kids_Butterfly_Garden_Pencil_Case_trt.obj (match_name: Olive_Kids_Butterfly_Garden_Pencil_Case.obj)
# [DEBUG] No match for: Olive_Kids_Dinosaur_Land_Lunch_Box_trt.obj (match_name: Olive_Kids_Dinosaur_Land_Lunch_Box.obj)
# [DEBUG] No match for: Olive_Kids_Paisley_Pencil_Case_trt.obj (match_name: Olive_Kids_Paisley_Pencil_Case.obj)
# [DEBUG] No match for: Phillips_Caplets_Size_24_trt.obj (match_name: Phillips_Caplets_Size_24.obj)
# [DEBUG] No match for: Phillips_Stool_Softener_Liquid_Gels_30_liquid_gels_trt.obj (match_name: Phillips_Stool_Softener_Liquid_Gels_30_liquid_gels.obj)
# [DEBUG] No match for: Pokmon_Conquest_Nintendo_DS_Game_trt.obj (match_name: Pokmon_Conquest_Nintendo_DS_Game.obj)
# [DEBUG] No match for: Reebok_ALLYLYNN_trt.obj (match_name: Reebok_ALLYLYNN.obj)
# [DEBUG] No match for: Reebok_CLASSIC_LEGACY_II_trt.obj (match_name: Reebok_CLASSIC_LEGACY_II.obj)
# [DEBUG] No match for: Reebok_EASYTONE_CL_LEATHER_trt.obj (match_name: Reebok_EASYTONE_CL_LEATHER.obj)
# [DEBUG] No match for: Reebok_PUMP_OMNI_LITE_HLS_trt.obj (match_name: Reebok_PUMP_OMNI_LITE_HLS.obj)
# [DEBUG] No match for: Reebok_REALFLEX_SELECT_trt.obj (match_name: Reebok_REALFLEX_SELECT.obj)
# [DEBUG] No match for: Reebok_R_CROSSFIT_OLY_UFORM_trt.obj (match_name: Reebok_R_CROSSFIT_OLY_UFORM.obj)
# [DEBUG] No match for: Reebok_SOMERSET_RUN_trt.obj (match_name: Reebok_SOMERSET_RUN.obj)
# [DEBUG] No match for: Reebok_TURBO_RC_trt.obj (match_name: Reebok_TURBO_RC.obj)
# [DEBUG] No match for: Remington_TStudio_Silk_Ceramic_Hair_Straightener_2_Inch_Floating_Plates_trt.obj (match_name: Remington_TStudio_Silk_Ceramic_Hair_Straightener_2_Inch_Floating_Plates.obj)
# [DEBUG] No match for: Seagate_Archive_HDD_8_TB_Internal_hard_drive_SATA_6Gbs_35_ST8000AS0002_trt.obj (match_name: Seagate_Archive_HDD_8_TB_Internal_hard_drive_SATA_6Gbs_35_ST8000AS0002.obj)
# [DEBUG] No match for: SpiderMan_Titan_Hero_12Inch_Action_Figure_5Hnn4mtkFsP_trt.obj (match_name: SpiderMan_Titan_Hero_12Inch_Action_Figure_5Hnn4mtkFsP.obj)
# [DEBUG] No match for: SpiderMan_Titan_Hero_12Inch_Action_Figure_oo1qph4wwiW_trt.obj (match_name: SpiderMan_Titan_Hero_12Inch_Action_Figure_oo1qph4wwiW.obj)
# [DEBUG] No match for: TOOL_BELT_trt.obj (match_name: TOOL_BELT.obj)
# [DEBUG] No match for: TOWER_TUMBLING_trt.obj (match_name: TOWER_TUMBLING.obj)
# [DEBUG] No match for: Tena_Pads_Heavy_Long_42_pads_trt.obj (match_name: Tena_Pads_Heavy_Long_42_pads.obj)
# [DEBUG] No match for: UGG_Bailey_Bow_Womens_Clogs_Black_7_trt.obj (match_name: UGG_Bailey_Bow_Womens_Clogs_Black_7.obj)
# [DEBUG] No match for: Ultra_JarroDophilus_trt.obj (match_name: Ultra_JarroDophilus.obj)
# [DEBUG] No match for: WATER_LANDING_NET_trt.obj (match_name: WATER_LANDING_NET.obj)
# [DEBUG] No match for: Wild_Copper_Tieks_Metallic_Italian_Leather_Ballet_Flats_trt.obj (match_name: Wild_Copper_Tieks_Metallic_Italian_Leather_Ballet_Flats.obj)
# [DEBUG] No match for: Wilton_Easy_Layers_Cake_Pan_Set_trt.obj (match_name: Wilton_Easy_Layers_Cake_Pan_Set.obj)
# [DEBUG] No match for: Wilton_PreCut_Parchment_Sheets_10_x_15_24_sheets_trt.obj (match_name: Wilton_PreCut_Parchment_Sheets_10_x_15_24_sheets.obj)
# [DEBUG] No match for: Womens_Sparkle_Suede_Angelfish_in_Grey_Sparkle_Suede_Silver_trt.obj (match_name: Womens_Sparkle_Suede_Angelfish_in_Grey_Sparkle_Suede_Silver.obj)
# [DEBUG] No match for: Womens_Suede_Bahama_in_Graphite_Suede_t22AJSRjBOX_trt.obj (match_name: Womens_Suede_Bahama_in_Graphite_Suede_t22AJSRjBOX.obj)
# [DEBUG] No match for: ZigKick_Hoops_trt.obj (match_name: ZigKick_Hoops.obj)
# [DEBUG] No match for: adistar_boost_m_trt.obj (match_name: adistar_boost_m.obj)
# [DEBUG] Total matches moved: 20

# %%
source_folder = os.path.expanduser('/Google_Dataset_Outputs')
check_folder = Path("/home/rayhub-user/Optim-WaLa/Benchmark_quality/Original")
destination_folder = Path("/home/rayhub-user/Optim-WaLa/Benchmark_quality/Tensor_RT")

# Check the contents of each folder
Optim_Utils.check_folder_contents(source_folder)
Optim_Utils.check_folder_contents(check_folder)
Optim_Utils.check_folder_contents(destination_folder)
# Out:
# Contents of /Google_Dataset_Outputs:
# - 2_of_Jenga_Classic_Game_trt.obj
# - 50_BLOCKS_trt.obj
# - 5_HTP_trt.obj
# - ASICS_GELAce_Pro_Pearl_WhitePink_trt.obj
# - ASICS_GELBlur33_20_GS_BlackWhiteSafety_Orange_trt.obj
# - Asus_M5A78LMUSB3_Motherboard_Micro_ATX_Socket_AM3_trt.obj
# - Asus_M5A99FX_PRO_R20_Motherboard_ATX_Socket_AM3_trt.obj
# - Asus_Sabertooth_990FX_20_Motherboard_ATX_Socket_AM3_trt.obj
# - Asus_Sabertooth_Z97_MARK_1_Motherboard_ATX_LGA1150_Socket_trt.obj
# - BlackBlack_Nintendo_3DSXL_trt.obj
# - Black_Decker_Stainless_Steel_Toaster_4_Slice_trt.obj
# - Black_Elderberry_Syrup_54_oz_Gaia_Herbs_trt.obj
# - BlueBlack_Nintendo_3DSXL_trt.obj
# - Blue_Jasmine_Includes_Digital_Copy_UltraViolet_DVD_trt.obj
# - Cootie_Game_trt.obj
# - Dell_Series_9_Color_Ink_Cartridge_MK993_High_Yield_trt.obj
# - Frozen_Scrabble_Jr_trt.obj
# - Google_Cardboard_Original_package_trt.obj
# - HP_Card_Invitation_Kit_trt.obj
# - Hyaluronic_Acid_trt.obj
# - LEGO_Creationary_Game_trt.obj
# - LEGO_Creationary_Game_ZJa163wlWp2_trt.obj
# - Lenovo_Yoga_2_11_trt.obj
# - Logitech_Ultimate_Ears_Boom_Wireless_Speaker_Night_Black_trt.obj
# - Lovestruck_Tieks_Glittery_Rose_Gold_Italian_Leather_Ballet_Flats_trt.obj
# - Luigis_Mansion_Dark_Moon_Nintendo_3DS_Game_trt.obj
# - Mens_ASV_Billfish_Boat_Shoe_in_Dark_Brown_Leather_zdHVHXueI3w_trt.obj
# - Mens_Authentic_Original_Boat_Shoe_in_Navy_Leather_xgoEcZtRNmH_trt.obj
# - Mens_Striper_Sneaker_in_White_rnp8HUli59Y_trt.obj
# - Womens_Audrey_Slip_On_Boat_Shoe_in_Graphite_Nubuck_xWVkCJ5vxZe_trt.obj
# - Womens_Betty_Chukka_Boot_in_Grey_Jersey_Sequin_trt.obj
# - Womens_Betty_Chukka_Boot_in_Salt_Washed_Red_AL2YrOt9CRy_trt.obj
# - Womens_Bluefish_2Eye_Boat_Shoe_in_White_Tumbled_YG44xIePRHw_trt.obj
# - 30_CONSTRUCTION_SET_trt.obj
# - 3D_Dollhouse_Swing_trt.obj
# - 3M_Antislip_Surfacing_Light_Duty_White_trt.obj
# - 3M_Vinyl_Tape_Green_1_x_36_yd_trt.obj
# - Animal_Planet_Foam_2Headed_Dragon_trt.obj
# - Avengers_Thor_PLlrpYniaeB_trt.obj
# - BEDROOM_CLASSIC_trt.obj
# - BIA_Cordon_Bleu_White_Porcelain_Utensil_Holder_900028_trt.obj
# - CONE_SORTING_trt.obj
# - Clorox_Premium_Choice_Gloves_SM_1_pair_trt.obj
# - Cole_Hardware_Deep_Bowl_Good_Earth_1075_trt.obj
# - Cole_Hardware_Dishtowel_BlueWhite_trt.obj
# - Cole_Hardware_Hammer_Black_trt.obj
# - Cole_Hardware_Mini_Honey_Dipper_trt.obj
# - Cole_Hardware_Plant_Saucer_Brown_125_trt.obj
# - Deskstar_Desk_Top_Hard_Drive_1_TB_trt.obj
# - Cole_Hardware_Saucer_Glazed_6_trt.obj
# - Diet_Pepsi_Soda_Cola12_Pack_12_oz_Cans_trt.obj
# - Ecoforms_Cup_B4_SAN_trt.obj
# - Ecoforms_Plant_Container_B4_Har_trt.obj
# - Ecoforms_Plant_Container_GP16AMOCHA_trt.obj
# - Ecoforms_Plant_Container_GP16A_Coral_trt.obj
# - Ecoforms_Plant_Container_QP6HARVEST_trt.obj
# - Ecoforms_Plant_Container_URN_NAT_trt.obj
# - Ecoforms_Plant_Container_Urn_55_Mocha_trt.obj
# - Ecoforms_Plant_Pot_GP9_SAND_trt.obj
# - Ecoforms_Plant_Saucer_S17MOCHA_trt.obj
# - Ecoforms_Planter_Bowl_Cole_Hardware_trt.obj
# - Elephant_trt.obj
# - Gigabyte_GAZ97XSLI_10_motherboard_ATX_LGA1150_Socket_Z97_trt.obj
# - Granimals_20_Wooden_ABC_Blocks_Wagon_trt.obj
# - Great_Dinos_Triceratops_Toy_trt.obj
# - Hefty_Waste_Basket_Decorative_Bronze_85_liter_trt.obj
# - INTERNATIONAL_PAPER_Willamette_4_Brown_Bag_500Count_trt.obj
# - KS_Chocolate_Cube_Box_Assortment_By_Neuhaus_2010_Ounces_trt.obj
# - Neat_Solutions_Character_Bib_2_pack_trt.obj
# - Now_Designs_Bowl_Akita_Black_trt.obj
# - Ortho_Forward_Facing_3Q6J2oKJD92_trt.obj
# - PEPSI_NEXT_CACRV_trt.obj
# - POUNDING_MUSHROOMS_trt.obj
# - PUNCH_DROP_TjicLPMqLvz_trt.obj
# - Pepsi_Max_Cola_Zero_Calorie_12_12_fl_oz_355_ml_cans_144_fl_oz_426_lt_trt.obj
# - Perricone_MD_AcylGlutathione_Eye_Lid_Serum_trt.obj
# - Perricone_MD_Face_Finishing_Moisturizer_trt.obj
# - Perricone_MD_Hypoallergenic_Firming_Eye_Cream_05_oz_trt.obj
# - Perricone_MD_No_Foundation_Foundation_No_1_trt.obj
# - Perricone_MD_Photo_Plasma_trt.obj
# - Perricone_MD_Skin_Total_Body_Supplements_trt.obj
# - Perricone_MD_Super_Berry_Powder_with_Acai_Supplements_trt.obj
# - Perricone_MD_Vitamin_C_Ester_Serum_trt.obj
# - Pony_C_Clamp_1440_trt.obj
# - Poppin_File_Sorter_Blue_trt.obj
# - Razer_BlackWidow_Stealth_2014_Keyboard_07VFzIVabgh_trt.obj
# - Razer_Kraken_Pro_headset_Full_size_Black_trt.obj
# - Reef_Star_Cushion_Flipflops_Size_8_Black_trt.obj
# - Retail_Leadership_Summit_trt.obj
# - Retail_Leadership_Summit_eCT3zqHYIkX_trt.obj
# - Rexy_Glove_Heavy_Duty_Gloves_Medium_trt.obj
# - Room_Essentials_Fabric_Cube_Lavender_trt.obj
# - Room_Essentials_Kitchen_Towels_16_x_26_2_count_trt.obj
# - Sea_to_Summit_Xl_Bowl_trt.obj
# - Shurtape_Gaffers_Tape_Silver_2_x_60_yd_trt.obj
# - Threshold_Performance_Bath_Sheet_Sandoval_Blue_33_x_63_trt.obj
# - Threshold_Porcelain_Serving_Bowl_Coupe_White_trt.obj
# - Threshold_Porcelain_Spoon_Rest_White_trt.obj
# - Top_Paw_Dog_Bowl_Blue_Paw_Bone_Ceramic_25_fl_oz_total_trt.obj
# - Vtech_Cruise_Learn_Car_25_Years_trt.obj
# - Animal_Crossing_New_Leaf_Nintendo_3DS_Game_trt.obj
# - BUNNY_RATTLE_trt.obj
# - Crayola_Crayons_24_count_trt.obj
# - Crayola_Model_Magic_Modeling_Material_White_3_oz_trt.obj
# - Crayola_Washable_Sidewalk_Chalk_16_pack_trt.obj
# - D_ROSE_773_II_hvInJwJ5HUD_trt.obj
# - Fisher_price_Classic_Toys_Buzzy_Bee_trt.obj
# - Germanium_GE132_trt.obj
# - GoPro_HERO3_Composite_Cable_trt.obj
# - Horses_in_Pink_Pencil_Case_trt.obj
# - JBL_Charge_Speaker_portable_wireless_wired_Green_trt.obj
# - Jarrow_Glucosamine_Chondroitin_Combination_120_Caps_trt.obj
# - Lutein_trt.obj
# - MARTIN_WEDGE_LACE_BOOT_trt.obj
# - MEAT_SET_trt.obj
# - MINI_ROLLER_trt.obj
# - MIRACLE_POUNDING_trt.obj
# - MODERN_DOLL_FAMILY_trt.obj
# - Mad_Gab_Refresh_Card_Game_trt.obj
# - Mario_Luigi_Dream_Team_Nintendo_3DS_Game_trt.obj
# - Marvel_Avengers_Titan_Hero_Series_Doctor_Doom_trt.obj
# - Melissa_Doug_Felt_Food_Pizza_Set_trt.obj
# - Melissa_Doug_Pound_and_Roll_trt.obj
# - Mens_Billfish_Slip_On_in_Coffee_e8bPKE9Lfgo_trt.obj
# - Mens_Tremont_Kiltie_Tassel_Loafer_in_Black_Amaretto_trt.obj
# - Mens_Tremont_Kiltie_Tassel_Loafer_in_Black_Amaretto_rCdzRZqgCnI_trt.obj
# - Mist_Wipe_Warmer_trt.obj
# - My_First_Rolling_Lion_trt.obj
# - Nescafe_Tasters_Choice_Instant_Coffee_Decaf_House_Blend_Light_7_oz_trt.obj
# - Nestle_Pure_Life_Exotics_Sparkling_Water_Strawberry_Dragon_Fruit_8_count_12_fl_oz_can_trt.obj
# - Nickelodeon_Teenage_Mutant_Ninja_Turtles_Michelangelo_trt.obj
# - Office_Depot_Canon_CLI_8Y_Ink_Cartridge_Yellow_0623B002_trt.obj
# - Office_Depot_Canon_CL_41_Remanufactured_Ink_Cartridge_TriColor_trt.obj
# - Office_Depot_HP_71_Remanufactured_Ink_Cartridge_Black_trt.obj
# - Office_Depot_HP_74XL75_Remanufactured_Ink_Cartridges_BlackTriColor_2_count_trt.obj
# - Olive_Kids_Birdie_Lunch_Box_trt.obj
# - Olive_Kids_Birdie_Munch_n_Lunch_trt.obj
# - Olive_Kids_Game_On_Pack_n_Snack_trt.obj
# - Olive_Kids_Mermaids_Pack_n_Snack_Backpack_trt.obj
# - Olive_Kids_Robots_Pencil_Case_trt.obj
# - Olive_Kids_Trains_Planes_Trucks_Bogo_Backpack_trt.obj
# - Orbit_Bubblemint_Mini_Bottle_6_ct_trt.obj
# - PEEKABOO_ROLLER_trt.obj
# - PETS_ACCESSORIES_trt.obj
# - Paul_Frank_Dot_Lunch_Box_trt.obj
# - Persona_Q_Shadow_of_the_Labyrinth_Nintendo_3DS_trt.obj
# - Philips_EcoVantage_43_W_Light_Bulbs_Natural_Light_2_pack_trt.obj
# - Pokémon_Omega_Ruby_Alpha_Sapphire_Dual_Pack_Nintendo_3DS_trt.obj
# - Prostate_Optimizer_trt.obj
# - PureConnect_2_Color_FernNightlifeSilverBlack_Size_70_5w0BYsiogeV_trt.obj
# - QAbsorb_CoQ10_trt.obj
# - QHPomegranate_trt.obj
# - Real_Deal_1nIwCHX1MTh_trt.obj
# - Reebok_BREAKPOINT_MID_trt.obj
# - Reebok_CLASSIC_JOGGER_trt.obj
# - Reebok_CL_RAYEN_trt.obj
# - Reebok_DMX_MAX_MANIA_WD_D_trt.obj
# - Reebok_DMX_MAX_PLUS_RAINWALKER_trt.obj
# - Reebok_GL_6000_trt.obj
# - Reebok_JR_ZIG_COOPERSTOWN_MR_trt.obj
# - Reebok_KAMIKAZE_II_MID_trt.obj
# - Reebok_SH_PRIME_COURT_MID_trt.obj
# - Reebok_SMOOTHFLEX_CUSHRUN_20_trt.obj
# - SAMOA_trt.obj
# - SAMe_200_KX7ZmOw47co_trt.obj
# - Sleep_Optimizer_trt.obj
# - Sony_Downloadable_Loops_trt.obj
# - TERREX_FAST_R_trt.obj
# - TOP_TEN_HI_60KlbRbdoJA_trt.obj
# - Tieks_Ballet_Flats_Diamond_White_Croc_trt.obj
# - Timberland_Mens_Earthkeepers_Newmarket_6Inch_Cupsole_Boot_trt.obj
# - Timberland_Mens_Earthkeepers_Stormbuck_Chukka_trt.obj
# - Timberland_Womens_Earthkeepers_Classic_Unlined_Boat_Shoe_trt.obj
# - Tory_Burch_Kaitlin_Ballet_Mestico_in_BlackGold_trt.obj
# - Tory_Burch_Sabe_65mm_Bootie_Split_Suede_in_Caramel_trt.obj
# - Travel_Smart_Neck_Rest_Inflatable_trt.obj
# - UGG_Bailey_Button_Triplet_Womens_Boots_Black_7_trt.obj
# - UGG_Jena_Womens_Java_7_trt.obj
# - Unmellow_Yellow_Tieks_Neon_Patent_Leather_Ballet_Flats_trt.obj
# - Weston_No_33_Signature_Sausage_Tonic_12_fl_oz_trt.obj
# - Whey_Protein_Vanilla_trt.obj
# - Whey_Protein_Vanilla_12_Packets_trt.obj
# - Winning_Moves_1180_Aggravation_Board_Game_trt.obj
# - Wishbone_Pencil_Case_trt.obj
# - Womens_Authentic_Original_Boat_Shoe_in_Classic_Brown_Leather_cJSCWiH7QmB_trt.obj
# - Womens_Bluefish_2Eye_Boat_Shoe_in_Linen_Natural_Sparkle_Suede_w34KNQ41csH_trt.obj
# - Womens_Canvas_Bahama_in_Black_vnJULsDVyq5_trt.obj
# - Womens_Canvas_Bahama_in_White_4UyOhP6rYGO_trt.obj
# - Womens_Canvas_Bahama_in_White_UfZPHGQpvz0_trt.obj
# - Womens_Hikerfish_Boot_in_Black_Leopard_bVSNY1Le1sm_trt.obj
# - Womens_Sequin_Bahama_in_White_Sequin_V9K1hf24Oxe_trt.obj
# - Womens_Sequin_Bahama_in_White_Sequin_yGVsSA4tOwJ_trt.obj
# - Womens_Teva_Capistrano_Bootie_trt.obj
# - Womens_Teva_Capistrano_Bootie_ldjRT9yZ5Ht_trt.obj
# - Xyli_Pure_Xylitol_trt.obj
# - adiZero_Slide_2_SC_trt.obj
# - 3D_Dollhouse_Lamp_trt.obj
# - 3D_Dollhouse_Sink_trt.obj
# - 3D_Dollhouse_Sofa_trt.obj
# - ASSORTED_VEGETABLE_SET_trt.obj
# - Mens_Authentic_Original_Boat_Shoe_in_Navy_Leather_NHHQddDLQys_trt.obj
# - Mens_Mako_Canoe_Moc_2Eye_Boat_Shoe_in_Coffee_9d05GG33QQQ_trt.obj
# - Womens_Bluefish_2Eye_Boat_Shoe_in_Linen_Oat_trt.obj
# - Womens_Bluefish_2Eye_Boat_Shoe_in_Tan_trt.obj
# - 3D_Dollhouse_Refrigerator_trt.obj
# - Air_Hogs_Wind_Flyers_Set_Airplane_Red_trt.obj
# - BAKING_UTENSILS_trt.obj
# - BIA_Porcelain_Ramekin_With_Glazed_Rim_35_45_oz_cup_trt.obj
# - BREAKFAST_MENU_trt.obj
# - Bradshaw_International_11642_7_Qt_MP_Plastic_Bowl_trt.obj
# - Brother_LC_1053PKS_Ink_Cartridge_CyanMagentaYellow_1pack_trt.obj
# - Brother_Printing_Cartridge_PC501_trt.obj
# - CHICKEN_NESTING_trt.obj
# - CHILDREN_BEDROOM_CLASSIC_trt.obj
# - Calphalon_Kitchen_Essentials_12_Cast_Iron_Fry_Pan_Black_trt.obj
# - Chef_Style_Round_Cake_Pan_9_inch_pan_trt.obj
# - Circo_Fish_Toothbrush_Holder_14995988_trt.obj
# - Cole_Hardware_Butter_Dish_Square_Red_trt.obj
# - Cole_Hardware_Dishtowel_Blue_trt.obj
# - Cole_Hardware_Dishtowel_Multicolors_trt.obj
# - Cole_Hardware_Dishtowel_Red_trt.obj
# - Cole_Hardware_Dishtowel_Stripe_trt.obj
# - Cole_Hardware_Electric_Pot_Cabana_55_trt.obj
# - Cole_Hardware_Flower_Pot_1025_trt.obj
# - Cole_Hardware_Plant_Saucer_Glazed_9_trt.obj
# - Cole_Hardware_Saucer_Electric_trt.obj
# - Cole_Hardware_School_Bell_Solid_Brass_38_trt.obj
# - Corningware_CW_by_Corningware_3qt_Oblong_Casserole_Dish_Blue_trt.obj
# - Crosley_Alarm_Clock_Vintage_Metal_trt.obj
# - DPC_Thinsulate_Isolate_Gloves_Brown_trt.obj
# - DPC_tropical_Trends_Hat_trt.obj
# - Design_Ideas_Drawer_Store_Organizer_trt.obj
# - Dino_3_trt.obj
# - Dino_4_trt.obj
# - Dog_trt.obj
# - Down_To_Earth_Orchid_Pot_Ceramic_Lime_trt.obj
# - Down_To_Earth_Orchid_Pot_Ceramic_Red_trt.obj
# - Ecoforms_Plant_Bowl_Atlas_Low_trt.obj
# - Ecoforms_Plant_Container_QP_Harvest_trt.obj
# - Ecoforms_Plant_Container_SB9Turquoise_trt.obj
# - Ecoforms_Plant_Container_URN_SAN_trt.obj
# - Ecoforms_Plant_Container_Urn_55_Avocado_trt.obj
# - Ecoforms_Plant_Plate_S11Turquoise_trt.obj
# - Ecoforms_Plant_Pot_GP9AAvocado_trt.obj
# - Ecoforms_Plant_Saucer_S20MOCHA_trt.obj
# - Ecoforms_Plant_Saucer_SQ1HARVEST_trt.obj
# - Ecoforms_Planter_Pot_GP12AAvocado_trt.obj
# - Ecoforms_Planter_Pot_QP6Ebony_trt.obj
# - Ecoforms_Quadra_Saucer_SQ1_Avocado_trt.obj
# - Embark_Lunch_Cooler_Blue_trt.obj
# - FARM_ANIMAL_trt.obj
# - GEARS_PUZZLES_STANDARD_gcYxhNHhKlI_trt.obj
# - Gigabyte_GA78LMTUSB3_50_Motherboard_Micro_ATX_Socket_AM3_trt.obj
# - Gigabyte_GA970AUD3P_10_Motherboard_ATX_Socket_AM3_trt.obj
# - Granimals_20_Wooden_ABC_Blocks_Wagon_g2TinmUGGHI_trt.obj
# - Grreat_Choice_Dog_Double_Dish_Plastic_Blue_trt.obj
# - Home_Fashions_Washcloth_Linen_trt.obj
# - In_Green_Company_Surface_Saver_Ring_10_Terra_Cotta_trt.obj
# - JA_Henckels_International_Premio_Cutlery_Block_Set_14Piece_trt.obj
# - Kotobuki_Saucer_Dragon_Fly_trt.obj
# - MY_MOOD_MEMO_trt.obj
# - Magnifying_Glassassrt_trt.obj
# - Markings_Letter_Holder_trt.obj
# - Nordic_Ware_Original_Bundt_Pan_trt.obj
# - Now_Designs_Dish_Towel_Mojave_18_x_28_trt.obj
# - Now_Designs_Snack_Bags_Bicycle_2_count_trt.obj
# - PUNCH_DROP_trt.obj
# - Perricoen_MD_No_Concealer_Concealer_trt.obj
# - Perricone_MD_Blue_Plasma_Orbital_trt.obj
# - Poppin_File_Sorter_Pink_trt.obj
# - Progressive_Rubber_Spatulas_3_count_trt.obj
# - Provence_Bath_Towel_Royal_Blue_trt.obj
# - REEF_BANTU_trt.obj
# - REEF_ZENFUN_trt.obj
# - RJ_Rabbit_Easter_Basket_Blue_trt.obj
# - Racoon_trt.obj
# - Razer_Goliathus_Control_Edition_Small_Soft_Gaming_Mouse_Mat_trt.obj
# - Razer_Naga_MMO_Gaming_Mouse_trt.obj
# - Razer_Taipan_Black_Ambidextrous_Gaming_Mouse_trt.obj
# - Rexy_Glove_Heavy_Duty_Large_trt.obj
# - Room_Essentials_Mug_White_Yellow_trt.obj
# - STEAK_SET_trt.obj
# - SANDWICH_MEAL_trt.obj
# - SAPPHIRE_R7_260X_OC_trt.obj
# - STACKING_BEAR_trt.obj
# - Sapota_Threshold_4_Ceramic_Round_Planter_Red_trt.obj
# - Sootheze_Toasty_Orca_trt.obj
# - Squirrel_trt.obj
# - Sterilite_Caddy_Blue_Sky_17_58_x_12_58_x_9_14_trt.obj
# - TABLEWARE_SET_5CHkPjjxVpp_trt.obj
# - Tag_Dishtowel_Green_trt.obj
# - Tag_Dishtowel_Waffle_Gray_Checks_18_x_26_trt.obj
# - Threshold_Bead_Cereal_Bowl_White_trt.obj
# - Threshold_Bistro_Ceramic_Dinner_Plate_Ruby_Ring_trt.obj
# - Threshold_Dinner_Plate_Square_Rim_White_Porcelain_trt.obj
# - Threshold_Hand_Towel_Blue_Medallion_16_x_27_trt.obj
# - Threshold_Porcelain_Coffee_Mug_All_Over_Bead_White_trt.obj
# - Vtech_Roll_Learn_Turtle_trt.obj
# - Weisshai_Great_White_Shark_trt.obj
# - 60_CONSTRUCTION_SET_trt.obj
# - Asus_X99Deluxe_Motherboard_ATX_LGA2011v3_Socket_trt.obj
# - Azure_Snake_Tieks_Leather_Snake_Print_Ballet_Flats_trt.obj
# - BRAILLE_ALPHABET_AZ_trt.obj
# - BUNNY_RACER_trt.obj
# - CHILDRENS_ROOM_NEO_trt.obj
# - Cascadia_8_Color_AquariusHibscsBearingSeaBlk_Size_50_trt.obj
# - ClimaCool_Aerate_2_W_Wide_trt.obj
# - Clue_Board_Game_Classic_Edition_trt.obj
# - Colton_Wntr_Chukka_y4jO0I8JQFW_trt.obj
# - Crazy_Shadow_2_trt.obj
# - Crazy_Shadow_2_oW4Jd10HFFr_trt.obj
# - Epson_Ink_Cartridge_Black_200_trt.obj
# - F5_TRX_FG_trt.obj
# - FAIRY_TALE_BLOCKS_trt.obj
# - FRUIT_VEGGIE_MEMO_GRADIENT_trt.obj
# - Great_Jones_Wingtip_wxH3dbtlvBC_trt.obj
# - HELICOPTER_trt.obj
# - Hasbro_Trivial_Pursuit_Family_Edition_Game_trt.obj
# - Horse_Dreams_Pencil_Case_trt.obj
# - IsoRich_Soy_trt.obj
# - Just_For_Men_Mustache_Beard_Brushin_Hair_Color_Gel_Kit_Jet_Black_M60_trt.obj
# - Just_For_Men_Mustache_Beard_Brushin_Hair_Color_Gel_MediumDark_Brown_M40_trt.obj
# - Just_For_Men_ShampooIn_Haircolor_Jet_Black_60_trt.obj
# - Just_For_Men_ShampooIn_Haircolor_Light_Brown_25_trt.obj
# - Kid_Icarus_Uprising_Nintendo_3DS_Game_trt.obj
# - Kingston_DT4000MR_G2_Management_Ready_USB_64GB_trt.obj
# - Kotex_U_Tween_Pads_16_pads_trt.obj
# - Melissa_Doug_Chunky_Puzzle_Vehicles_trt.obj
# - Melissa_Doug_Pattern_Blocks_and_Boards_trt.obj
# - Mens_ASV_Billfish_Boat_Shoe_in_Tan_Leather_wmUJ5PbwANc_trt.obj
# - Mens_Authentic_Original_Boat_Shoe_in_Navy_Leather_RpT4GvUXRRP_trt.obj
# - Mens_Bahama_in_Black_b4ADzYywRHl_trt.obj
# - Mens_Bahama_in_Khaki_Oyster_xU2jeqYwhQJ_trt.obj
# - Mens_Billfish_3Eye_Boat_Shoe_in_Dark_Tan_wyns9HRcEuH_trt.obj
# - Metallic_Pewter_Tieks_Italian_Leather_Ballet_Flats_trt.obj
# - NUTS_BOLTS_trt.obj
# - Netgear_Ac1750_Router_Wireless_Dual_Band_Gigabit_Router_trt.obj
# - Netgear_N750_Wireless_Dual_Band_Gigabit_Router_trt.obj
# - Nickelodeon_The_Spongebob_Movie_PopAPart_Spongebob_trt.obj
# - Nikon_1_AW1_w11275mm_Lens_Silver_trt.obj
# - Nintendo_2DS_Crimson_Red_trt.obj
# - OWL_SORTER_trt.obj
# - Office_Depot_Canon_CLI_221BK_Ink_Cartridge_Black_2946B001_trt.obj
# - Office_Depot_Canon_PG21XL_Remanufactured_Ink_Cartridge_Black_trt.obj
# - Paint_Maker_trt.obj
# - Pet_Dophilus_powder_trt.obj
# - Philips_60ct_Warm_White_LED_Smooth_Mini_String_Lights_trt.obj
# - Philips_Sonicare_Tooth_Brush_2_count_trt.obj
# - PhosphOmega_trt.obj
# - Playmates_nickelodeon_teenage_mutant_ninja_turtles_shredder_trt.obj
# - ROAD_CONSTRUCTION_SET_trt.obj
# - Reebok_FS_HI_INT_R12_trt.obj
# - Reebok_FS_HI_MINI_trt.obj
# - Reebok_REESCULPT_TRAINER_II_trt.obj
# - Reebok_SL_FLIP_UPDATE_trt.obj
# - Reebok_TRIPLE_BREAK_LITE_trt.obj
# - Reebok_ULTIMATIC_2V_trt.obj
# - Reebok_ZIGCOOPERSTOWN_QUAG_trt.obj
# - Reebok_ZIGSTORM_trt.obj
# - Reebok_ZIGTECH_SHARK_MAYHEM360_trt.obj
# - Remington_1_12_inch_Hair_Straightener_trt.obj
# - SAMe_200_trt.obj
# - Womens_Angelfish_Boat_Shoe_in_Linen_Oat_trt.obj
# - Womens_Bluefish_2Eye_Boat_Shoe_in_Linen_Oat_IbrSyJdpT3h_trt.obj
# - adizero_5Tool_25_trt.obj
# - Ecoforms_Plant_Saucer_SQ8COR_trt.obj
# - Ecoforms_Plate_S20Avocado_trt.obj
# - Focus_8643_Lime_Squeezer_10x35x188_Enamelled_Aluminum_Light_trt.obj
# - GEOMETRIC_SORTING_BOARD_trt.obj
# - GEOMETRIC_SORTING_BOARD_MNi4Rbuz9vj_trt.obj
# - HeavyDuty_Flashlight_trt.obj
# - Hilary_trt.obj
# - OXO_Cookie_Spatula_trt.obj
# - Object_REmvBDJStub_trt.obj
# - Ortho_Forward_Facing_trt.obj
# - Ortho_Forward_Facing_CkAW6rL25xH_trt.obj
# - PARENT_ROOM_FURNITURE_SET_1_trt.obj
# - Perricone_MD_Cold_Plasma_trt.obj
# - Perricone_MD_Neuropeptide_Facial_Conformer_trt.obj
# - Perricone_MD_Neuropeptide_Firming_Moisturizer_trt.obj
# - Perricone_MD_No_Bronzer_Bronzer_trt.obj
# - Perricone_MD_No_Foundation_Serum_trt.obj
# - Perricone_MD_No_Lipstick_Lipstick_trt.obj
# - Perricone_MD_No_Mascara_Mascara_trt.obj
# - Perricone_MD_Nutritive_Cleanser_trt.obj
# - Perricone_MD_The_Crease_Cure_Duo_trt.obj
# - Perricone_MD_The_Metabolic_Formula_Supplements_trt.obj
# - Perricone_MD_Vitamin_C_Ester_15_trt.obj
# - Razer_BlackWidow_Ultimate_2014_Mechanical_Gaming_Keyboard_trt.obj
# - Razer_Blackwidow_Tournament_Edition_Keyboard_trt.obj
# - Remington_TStudio_Hair_Dryer_trt.obj
# - SHAPE_SORTER_trt.obj
# - Schleich_African_Black_Rhino_trt.obj
# - Schleich_S_Bayala_Unicorn_70432_trt.obj
# - Spritz_Easter_Basket_Plastic_Teal_trt.obj
# - TEA_SET_trt.obj
# - Threshold_Porcelain_Teapot_White_trt.obj
# - Top_Paw_Dog_Bow_Bone_Ceramic_13_fl_oz_total_trt.obj
# - VEGETABLE_GARDEN_trt.obj
# - ASICS_GEL1140V_WhiteRoyalSilver_trt.obj
# - ASICS_GELLinksmaster_WhiteSilverCarolina_Blue_trt.obj
# - ASICS_GELResolution_5_Flash_YellowBlackSilver_trt.obj
# - AllergenFree_JarroDophilus_trt.obj
# - Android_Figure_Chrome_trt.obj
# - Asus_80211ac_DualBand_Gigabit_Wireless_Router_RTAC68R_trt.obj
# - Beta_Glucan_trt.obj
# - Bifidus_Balance_FOS_trt.obj
# - Big_Dot_Aqua_Pencil_Case_trt.obj
# - Big_Dot_Pink_Pencil_Case_trt.obj
# - Black_and_Decker_PBJ2000_FusionBlade_Blender_Jars_trt.obj
# - Brisk_Iced_Tea_Lemon_12_12_fl_oz_355_ml_cans_144_fl_oz_426_lt_trt.obj
# - CAR_CARRIER_TRAIN_trt.obj
# - California_Navy_Tieks_Italian_Leather_Ballet_Flats_trt.obj
# - Canon_Pixma_Ink_Cartridge_8_trt.obj
# - Canon_Pixma_Ink_Cartridge_8_Green_trt.obj
# - CoQ10_trt.obj
# - Cream_Tieks_Italian_Leather_Ballet_Flats_trt.obj
# - Crunch_Girl_Scouts_Candy_Bars_Peanut_Butter_Creme_78_oz_box_trt.obj
# - Eat_to_Live_The_Amazing_NutrientRich_Program_for_Fast_and_Sustained_Weight_Loss_Revised_Edition_Book_trt.obj
# - Epson_DURABrite_Ultra_786_Black_Ink_Cartridge_T786120S_trt.obj
# - Epson_LabelWorks_LC5WBN9_Tape_reel_labels_071_x_295_Roll_Black_on_White_trt.obj
# - FYW_ALTERNATION_trt.obj
# - FYW_DIVISION_trt.obj
# - Final_Fantasy_XIV_A_Realm_Reborn_60Day_Subscription_trt.obj
# - Fujifilm_instax_SHARE_SP1_10_photos_trt.obj
# - GEOMETRIC_PEG_BOARD_trt.obj
# - GRANDFATHER_DOLL_trt.obj
# - Ghost_6_GTX_Color_AnthBlckSlvrFernSulphSprng_Size_80_trt.obj
# - Grand_Prix_trt.obj
# - HAMMER_PEG_trt.obj
# - HAPPY_ENGINE_trt.obj
# - Hasbro_Cranium_Performance_and_Acting_Game_trt.obj
# - Hasbro_Dont_Wake_Daddy_Board_Game_trt.obj
# - Hasbro_Monopoly_Hotels_Game_trt.obj
# - JUICER_SET_trt.obj
# - Jansport_School_Backpack_Blue_Streak_trt.obj
# - Jawbone_UP24_Wireless_Activity_Tracker_Pink_Coral_L_trt.obj
# - Justified_The_Complete_Fourth_Season_3_Discs_DVD_trt.obj
# - LACING_SHEEP_trt.obj
# - LEGO_Bricks_More_Creative_Suitcase_trt.obj
# - LEUCIPPUS_ADIPURE_trt.obj
# - Lactoferrin_trt.obj
# - Lavender_Snake_Tieks_Snake_Print_Ballet_Flats_trt.obj
# - Leap_Frog_Paint_Dabber_Dot_Art_5_paint_bottles_trt.obj
# - Lego_Friends_Advent_Calendar_trt.obj
# - Little_Debbie_Donut_Sticks_6_cake_donuts_10_oz_total_trt.obj
# - Marc_Anthony_Strictly_Curls_Curl_Envy_Perfect_Curl_Cream_6_fl_oz_bottle_trt.obj
# - Mattel_SKIP_BO_Card_Game_trt.obj
# - My_Little_Pony_Princess_Celestia_trt.obj
# - Nestl_Skinny_Cow_Heavenly_Crisp_Candy_Bar_Chocolate_Raspberry_6_pack_462_oz_total_trt.obj
# - Office_Depot_Canon_PG_240XL_Ink_Cartridge_Black_5206B001_trt.obj
# - Office_Depot_Dell_Series_11_Remanufactured_Ink_Cartridge_Black_trt.obj
# - Office_Depot_HP_564XL_Remanufactured_Ink_Cartridges_Color_Cyan_Magenta_Yellow_3_count_trt.obj
# - Olive_Kids_Dinosaur_Land_Munch_n_Lunch_trt.obj
# - Olive_Kids_Game_On_Lunch_Box_trt.obj
# - Olive_Kids_Game_On_Munch_n_Lunch_trt.obj
# - Olive_Kids_Trains_Planes_Trucks_Munch_n_Lunch_Bag_trt.obj
# - Organic_Whey_Protein_Unflavored_trt.obj
# - Paper_Mario_Sticker_Star_Nintendo_3DS_Game_trt.obj
# - PureConnect_2_Color_BlckBrllntBluNghtlfeAnthrct_Size_70_trt.obj
# - Ravenna_4_Color_WhtOlyBluBlkShkOrngSlvRdO_Size_70_trt.obj
# - Rose_Garden_Tieks_Leather_Ballet_Flats_with_Floral_Rosettes_trt.obj
# - SAMBA_HEMP_trt.obj
# - SCHOOL_BUS_trt.obj
# - SLACK_CRUISER_trt.obj
# - SPEED_BOAT_trt.obj
# - Santa_Cruz_Mens_YmsMDkFf11Z_trt.obj
# - Sienna_Brown_Croc_Tieks_Patent_Leather_Crocodile_Print_Ballet_Flats_trt.obj
# - Snack_Catcher_Snack_Dispenser_trt.obj
# - Sorry_Sliders_Board_Game_trt.obj
# - Sperry_TopSider_tNB9t6YBUf3_trt.obj
# - Squirtin_Barnyard_Friends_4pk_trt.obj
# - Star_Wars_Rogue_Squadron_Nintendo_64_trt.obj
# - Super_Mario_3D_World_Deluxe_Set_yThuvW9vZed_trt.obj
# - Super_Mario_3D_World_Wii_U_Game_trt.obj
# - Superman_Battle_of_Smallville_trt.obj
# - Supernatural_Ouija_Board_Game_trt.obj
# - Thomas_Friends_Woodan_Railway_Henry_trt.obj
# - Thomas_Friends_Wooden_Railway_Talking_Thomas_z7yi7UFHJRj_trt.obj
# - Timberland_Mens_Earthkeepers_Casco_Bay_Canvas_Oxford_trt.obj
# - Timberland_Mens_Earthkeepers_Stormbuck_Lite_Plain_Toe_Oxford_trt.obj
# - Transformers_Age_of_Extinction_Mega_1Step_Bumblebee_Figure_trt.obj
# - Tune_Belt_Sport_Armband_For_Samsung_Galaxy_S3_trt.obj
# - UGG_Bailey_Button_Womens_Boots_Black_7_trt.obj
# - UGG_Cambridge_Womens_Black_7_trt.obj
# - UGG_Classic_Tall_Womens_Boots_Chestnut_7_trt.obj
# - Vans_Cereal_Honey_Nut_Crunch_11_oz_box_trt.obj
# - WHALE_WHISTLE_6PCS_SET_trt.obj
# - White_Rose_Tieks_Leather_Ballet_Flats_with_Floral_Rosettes_trt.obj
# - Womens_Hikerfish_Boot_in_Linen_Leather_Sparkle_Suede_QktIyAkonrU_trt.obj
# - ZX700_mf9Pc06uL06_trt.obj
# - adizero_F50_TRX_FG_LEA_trt.obj
# - Breyer_Horse_Of_The_Year_2015_trt.obj
# - Perricone_MD_Chia_Serum_trt.obj
# - Perricone_MD_Face_Finishing_Moisturizer_4_oz_trt.obj
# - Perricone_MD_Firming_Neck_Therapy_Treatment_trt.obj
# - Perricone_MD_Hypoallergenic_Gentle_Cleanser_trt.obj
# - Perricone_MD_The_Power_Treatments_trt.obj
# - Utana_5_Porcelain_Ramekin_Large_trt.obj
# - ASICS_GEL1140V_WhiteBlackSilver_trt.obj
# - ASICS_GELBlur33_20_GS_Flash_YellowHot_PunchSilver_trt.obj
# - ASICS_GELDirt_Dog_4_SunFlameBlack_trt.obj
# - ASICS_GELLinksmaster_WhiteCoffeeSand_trt.obj
# - Adrenaline_GTS_13_Color_WhtObsdianBlckOlmpcSlvr_Size_70_trt.obj
# - Apples_to_Apples_Kids_Edition_trt.obj
# - Arm_Hammer_Diaper_Pail_Refills_12_Pack_MFWkmoweejt_trt.obj
# - BUILD_A_ZOO_trt.obj
# - CARSII_trt.obj
# - CITY_TAXI_POLICE_CAR_trt.obj
# - CLIMACOOL_BOAT_BREEZE_IE6CyqSaDwN_trt.obj
# - Chelsea_lo_fl_rdheel_nQ0LPNF1oMw_trt.obj
# - Crayola_Crayons_Washable_24_crayons_trt.obj
# - Crayola_Washable_Sidewalk_Chalk_16_pack_wDZECiw7J6s_trt.obj
# - DIM_CDG_trt.obj
# - FISHING_GAME_trt.obj
# - Firefly_Clue_Board_Game_trt.obj
# - Just_For_Men_Shampoo_In_Haircolor_Darkest_Brown_50_trt.obj
# - KID_ROOM_FURNITURE_SET_1_trt.obj
# - Kanex_MultiSync_Wireless_Keyboard_trt.obj
# - Krill_Oil_trt.obj
# - LEGO_5887_Dino_Defense_HQ_trt.obj
# - LTyrosine_trt.obj
# - Little_Debbie_Cloud_Cakes_10_ct_trt.obj
# - MONKEY_BOWLING_trt.obj
# - MOSAIC_trt.obj
# - Mario_Party_9_Wii_Game_trt.obj
# - Melissa_Doug_Cart_Turtle_Block_trt.obj
# - Melissa_Doug_Jumbo_Knob_Puzzles_Barnyard_Animals_trt.obj
# - Melissa_Doug_See_Spell_trt.obj
# - Melissa_Doug_Traffic_Signs_and_Vehicles_trt.obj
# - Mens_ASV_Shock_Light_Bungee_in_Light_Grey_xGCOvtLDnQJ_trt.obj
# - Mens_Bahama_in_White_vSwvGMCo32f_trt.obj
# - Mens_Billfish_Slip_On_in_Coffee_nK6AJJAHOae_trt.obj
# - Mens_Billfish_Slip_On_in_Tan_Beige_aaVUk0tNTv8_trt.obj
# - Mens_Gold_Cup_ASV_Dress_Casual_Venetian_in_Dark_Brown_Leather_trt.obj
# - Mens_Mako_Canoe_Moc_2Eye_Boat_Shoe_in_Coffee_K9e8FoV73uZ_trt.obj
# - NattoMax_trt.obj
# - Nescafe_16Count_Dolce_Gusto_Cappuccino_Capsules_trt.obj
# - Nescafe_Memento_Latte_Caramel_8_08_oz_23_g_packets_64_oz_184_g_trt.obj
# - Nestle_Candy_19_oz_Butterfinger_Singles_116567_trt.obj
# - Nestle_Skinny_Cow_Dreamy_Clusters_Candy_Dark_Chocolate_6_pack_1_oz_pouches_trt.obj
# - Nickelodeon_Teenage_Mutant_Ninja_Turtles_Leonardo_trt.obj
# - Nickelodeon_Teenage_Mutant_Ninja_Turtles_Raphael_trt.obj
# - Nintendo_Wii_Party_U_with_Controller_Wii_U_Game_trt.obj
# - Nips_Hard_Candy_Rich_Creamy_Butter_Rum_4_oz_1133_g_trt.obj
# - Office_Depot_Canon_CL211XL_Remanufactured_Ink_Cartridge_TriColor_trt.obj
# - Office_Depot_Canon_PGI22_Remanufactured_Ink_Cartridge_Black_trt.obj
# - Office_Depot_Canon_PGI35_Remanufactured_Ink_Cartridge_Black_trt.obj
# - Office_Depot_Canon_PGI5BK_Remanufactured_Ink_Cartridge_Black_trt.obj
# - Office_Depot_Dell_Series_1_Remanufactured_Ink_Cartridge_TriColor_trt.obj
# - Office_Depot_Dell_Series_9_Ink_Cartridge_Black_MK992_trt.obj
# - Office_Depot_HP_75_Remanufactured_Ink_Cartridge_TriColor_trt.obj
# - Office_Depot_HP_920XL_920_High_Yield_Black_and_Standard_CMY_Color_Ink_Cartridges_trt.obj
# - Office_Depot_HP_932XL_Ink_Cartridge_Black_CN053A_trt.obj
# - Office_Depot_HP_98_Remanufactured_Ink_Cartridge_Black_trt.obj
# - Olive_Kids_Birdie_Sidekick_Backpack_trt.obj
# - Olive_Kids_Dinosaur_Land_Pack_n_Snack_trt.obj
# - Organic_Whey_Protein_Vanilla_trt.obj
# - PINEAPPLE_MARACA_6_PCSSET_trt.obj
# - Phillips_Milk_of_Magnesia_Saline_Laxative_Liquid_Original_trt.obj
# - Pinwheel_Pencil_Case_trt.obj
# - Pokmon_X_Nintendo_3DS_Game_trt.obj
# - Playmates_Industrial_CoSplinter_Teenage_Mutant_Ninja_Turtle_Action_Figure_trt.obj
# - Pokémon_Yellow_Special_Pikachu_Edition_Nintendo_Game_Boy_Color_trt.obj
# - Predito_LZ_TRX_FG_W_trt.obj
# - QAbsorb_CoQ10_53iUqjWjW3O_trt.obj
# - RESCUE_CREW_trt.obj
# - Rayna_BootieWP_trt.obj
# - ReadytoUse_Rolled_Fondant_Pure_White_24_oz_box_trt.obj
# - Reebok_BREAKPOINT_LO_2V_trt.obj
# - Reebok_CL_LTHR_R12_trt.obj
# - Reebok_COMFORT_REEFRESH_FLIP_trt.obj
# - Reebok_FUELTRAIN_trt.obj
# - Reebok_RETRO_RUSH_2V_trt.obj
# - Reebok_SH_NEWPORT_LOW_trt.obj
# - Reebok_VERSA_TRAIN_trt.obj
# - Reebok_ZIGLITE_RUSH_trt.obj
# - Romantic_Blush_Tieks_Metallic_Italian_Leather_Ballet_Flats_trt.obj
# - SIT_N_WALK_PUPPY_trt.obj
# - Santa_Cruz_Mens_G7kQXK7cIky_trt.obj
# - Seagate_1TB_Backup_Plus_portable_drive_for_Mac_trt.obj
# - Seagate_1TB_Wireless_Plus_mobile_device_storage_trt.obj
# - Sony_Acid_Music_Studio_trt.obj
# - Spectrum_Wall_Mount_trt.obj
# - Sperry_TopSider_pSUFPWQXPp3_trt.obj
# - Starstruck_Tieks_Glittery_Gold_Italian_Leather_Ballet_Flats_trt.obj
# - Super_Mario_Kart_Super_Nintendo_Entertainment_System_trt.obj
# - Swiss_Miss_Hot_Cocoa_KCups_Milk_Chocolate_12_count_trt.obj
# - TOP_TEN_HI_trt.obj
# - The_Coffee_Bean_Tea_Leaf_KCup_Packs_Jasmine_Green_Tea_16_count_trt.obj
# - The_Scooper_Hooper_trt.obj
# - Thomas_Friends_Wooden_Railway_Deluxe_Track_Accessory_Pack_trt.obj
# - Tiek_Blue_Patent_Tieks_Italian_Leather_Ballet_Flats_trt.obj
# - Timberland_Mens_Earthkeepers_Heritage_2Eye_Boat_Shoe_trt.obj
# - Timberland_Mens_Earthkeepers_Stormbuck_Plain_Toe_Oxford_trt.obj
# - Timberland_Womens_Classic_Amherst_2Eye_Boat_Shoe_trt.obj
# - Weston_No_22_Cajun_Jerky_Tonic_12_fl_oz_nLj64ZnGwDh_trt.obj
# - Womens_Bluefish_2Eye_Boat_Shoe_in_Linen_Natural_Sparkle_Suede_kqi81aojcOR_trt.obj
# - ZX700_mzGbdP3u6JB_trt.obj
# - 11pro_SL_TRX_FG_trt.obj
# - ASICS_GELTour_Lyte_WhiteOrchidSilver_trt.obj
# - Asus_Z87PRO_Motherboard_ATX_LGA1150_Socket_trt.obj
# - Asus_Z97AR_LGA_1150_Intel_ATX_Motherboard_trt.obj
# - Avengers_Gamma_Green_Smash_Fists_trt.obj
# - BEDROOM_NEO_trt.obj
# - BIRD_RATTLE_trt.obj
# - Beetle_Adventure_Racing_Nintendo_64_trt.obj
# - Black_Decker_CM2035B_12Cup_Thermal_Coffeemaker_trt.obj
# - Canon_225226_Ink_Cartridges_BlackColor_Cyan_Magenta_Yellow_6_count_trt.obj
# - Canon_Pixma_Ink_Cartridge_251_M_trt.obj
# - Canon_Pixma_Ink_Cartridge_8_Red_trt.obj
# - Canon_Pixma_Ink_Cartridge_Cyan_251_trt.obj
# - CoQ10_wSSVoxVppVD_trt.obj
# - Cootie_Game_tDhURNbfU5J_trt.obj
# - Crayola_Washable_Fingerpaint_Red_Blue_Yellow_3_count_8_fl_oz_bottes_each_trt.obj
# - D_ROSE_45_trt.obj
# - D_ROSE_773_II_Kqclsph05pE_trt.obj
# - D_ROSE_ENGLEWOOD_II_trt.obj
# - TZX_Runner_trt.obj
# - Travel_Mate_P_series_Notebook_trt.obj
# - Twinlab_100_Whey_Protein_Fuel_Chocolate_trt.obj
# - Twinlab_100_Whey_Protein_Fuel_Vanilla_trt.obj
# - Twinlab_Nitric_Fuel_trt.obj
# - US_Army_Stash_Lunch_Bag_trt.obj
# - Womens_Angelfish_Boat_Shoe_in_Linen_Leopard_Sequin_NJDwosWNeZz_trt.obj
# - Womens_Authentic_Original_Boat_Shoe_in_Classic_Brown_Leather_trt.obj
# - Womens_Authentic_Original_Boat_Shoe_in_Classic_Brown_Leather_48Nh7VuMwW6_trt.obj
# - Womens_Authentic_Original_Boat_Shoe_in_Navy_Deerskin_50lWJaLWG8R_trt.obj
# - Womens_Canvas_Bahama_in_Black_trt.obj
# - Womens_Sequin_Bahama_in_White_Sequin_XoR8xTlxj1g_trt.obj
# - Womens_Suede_Bahama_in_Graphite_Suede_cUAjIMhWSO9_trt.obj
# - Wrigley_Orbit_Mint_Variety_18_Count_trt.obj
# - 3D_Dollhouse_Happy_Brother_trt.obj
# - ALPHABET_AZ_GRADIENT_trt.obj
# - ALPHABET_AZ_GRADIENT_WQb1ufEycSj_trt.obj
# - Android_Figure_Panda_trt.obj
# - Android_Lego_trt.obj
# - Aroma_Stainless_Steel_Milk_Frother_2_Cup_trt.obj
# - Big_O_Sponges_Assorted_Cellulose_12_pack_trt.obj
# - CASTLE_BLOCKS_trt.obj
# - Central_Garden_Flower_Pot_Goo_425_trt.obj
# - Cole_Hardware_Antislip_Surfacing_White_2_x_60_trt.obj
# - Cole_Hardware_Bowl_Scirocco_YellowBlue_trt.obj
# - Cole_Hardware_Mug_Classic_Blue_trt.obj
# - Cole_Hardware_Orchid_Pot_85_trt.obj
# - Craftsman_Grip_Screwdriver_Phillips_Cushion_trt.obj
# - Curver_Storage_Bin_Black_Small_trt.obj
# - DPC_Handmade_Hat_Brown_trt.obj
# - Dino_5_trt.obj
# - Dixie_10_ounce_Bowls_35_ct_trt.obj
# - Down_To_Earth_Ceramic_Orchid_Pot_Asst_Blue_trt.obj
# - Ecoforms_Garden_Pot_GP16ATurquois_trt.obj
# - Ecoforms_Plant_Bowl_Turquoise_7_trt.obj
# - Ecoforms_Plant_Container_FB6_Tur_trt.obj
# - Ecoforms_Plant_Container_Quadra_Sand_QP6_trt.obj
# - Ecoforms_Plant_Container_S14Turquoise_trt.obj
# - Ecoforms_Plant_Saucer_S14MOCHA_trt.obj
# - Ecoforms_Plant_Saucer_S14NATURAL_trt.obj
# - Ecoforms_Pot_Nova_6_Turquoise_trt.obj
# - Ecoforms_Saucer_SQ3_Turquoise_trt.obj
# - Envision_Home_Dish_Drying_Mat_Red_6_x_18_trt.obj
# - FRACTION_FUN_n4h4qte23QR_trt.obj
# - GIRLS_DECKHAND_trt.obj
# - Home_Fashions_Washcloth_Olive_Green_trt.obj
# - KITCHEN_FURNITURE_SET_1_trt.obj
# - KITCHEN_SET_CLASSIC_40HwCHfeG0H_trt.obj
# - Object_trt.obj
# - PARENT_ROOM_FURNITURE_SET_1_DLKEy8H4mwK_trt.obj
# - Pennington_Electric_Pot_Cabana_4_trt.obj
# - Pepsi_Cola_Wild_Cherry_Diet_12_12_fl_oz_355_ml_cans_144_fl_oz_426_lt_trt.obj
# - Perricone_MD_AcylGlutathione_Deep_Crease_Serum_trt.obj
# - Perricone_MD_Best_of_Perricone_7Piece_Collection_MEGsO6GIsyL_trt.obj
# - Perricone_MD_Cold_Plasma_Body_trt.obj
# - Perricone_MD_Health_Weight_Management_Supplements_trt.obj
# - Perricone_MD_OVM_trt.obj
# - Perricone_MD_Omega_3_Supplements_trt.obj
# - Perricone_MD_Skin_Clear_Supplements_trt.obj
# - Poppin_File_Sorter_White_trt.obj
# - ProSport_Harness_to_Booster_Seat_trt.obj
# - Razer_Abyssus_Ambidextrous_Gaming_Mouse_trt.obj
# - Razer_Kraken_71_Chroma_headset_Full_size_Black_trt.obj
# - Room_Essentials_Bowl_Turquiose_trt.obj
# - SHAPE_MATCHING_trt.obj
# - SHAPE_MATCHING_NxacpAY9jDt_trt.obj
# - Schleich_Allosaurus_trt.obj
# - Schleich_Lion_Action_Figure_trt.obj
# - Shurtape_30_Day_Removal_UV_Delct_15_trt.obj
# - Shurtape_Tape_Purple_CP28_trt.obj
# - Smith_Hawken_Woven_BasketTray_Organizer_with_3_Compartments_95_x_9_x_13_trt.obj
# - Sonny_School_Bus_trt.obj
# - Sushi_Mat_trt.obj
# - TABLEWARE_SET_trt.obj
# - TABLEWARE_SET_5ww1UFLuCJG_trt.obj
# - TWISTED_PUZZLE_trt.obj
# - Tag_Dishtowel_Basket_Weave_Red_18_x_26_trt.obj
# - Threshold_Porcelain_Pitcher_White_trt.obj
# - Threshold_Textured_Damask_Bath_Towel_Pink_trt.obj
# - Threshold_Tray_Rectangle_Porcelain_trt.obj
# - Victor_Reversible_Bookend_trt.obj
# - AMBERLIGHT_UP_W_trt.obj
# - Adrenaline_GTS_13_Color_DrkDenimWhtBachlorBttnSlvr_Size_50_yfK40TNjq0V_trt.obj
# - BABY_CAR_trt.obj
# - Black_Forest_Fruit_Snacks_28_Pack_Grape_trt.obj
# - Black_Forest_Fruit_Snacks_Juicy_Filled_Centers_10_pouches_9_oz_total_trt.obj
# - Chelsea_lo_fl_rdheel_zAQrnhlEfw8_trt.obj
# - Crayola_Bonus_64_Crayons_trt.obj
# - Dell_Ink_Cartridge_trt.obj
# - Dell_Ink_Cartridge_Yellow_31_trt.obj
# - Epson_Ink_Cartridge_126_Yellow_trt.obj
# - Epson_LabelWorks_LC4WBN9_Tape_reel_labels_047_x_295_Roll_Black_on_White_trt.obj
# - Epson_T5803_Ink_Cartridge_Magenta_1pack_trt.obj
# - Epson_UltraChrome_T0543_Ink_Cartridge_Magenta_1pack_trt.obj
# - F10_TRX_FG_ssscuo9tGxb_trt.obj
# - FRUIT_VEGGIE_DOMINO_GRADIENT_trt.obj
# - FemDophilus_trt.obj
# - Fresca_Peach_Citrus_Sparkling_Flavored_Soda_12_PK_trt.obj
# - Frozen_Olafs_In_Trouble_PopOMatic_Game_trt.obj
# - Fruity_Friends_trt.obj
# - Ghost_6_Color_BlckWhtLavaSlvrCitrus_Size_80_trt.obj
# - Ghost_6_Color_MdngtDenmPomBrtePnkSlvBlk_Size_50_trt.obj
# - Glycerin_11_Color_AqrsDrsdnBluBlkSlvShckOrng_Size_50_trt.obj
# - Great_Jones_Wingtip_trt.obj
# - HAMMER_BALL_trt.obj
# - HP_1800_Tablet_8GB_7_trt.obj
# - Hasbro_Dont_Wake_Daddy_Board_Game_NJnjGna4u1a_trt.obj
# - Hasbro_Life_Board_Game_trt.obj
# - House_of_Cards_The_Complete_First_Season_4_Discs_DVD_trt.obj
# - HyperX_Cloud_II_Headset_Gun_Metal_trt.obj
# - HyperX_Cloud_II_Headset_Red_trt.obj
# - Imaginext_Castle_Ogre_trt.obj
# - Inositol_trt.obj
# - JS_WINGS_20_BLACK_FLAG_trt.obj
# - JarroSil_Activated_Silicon_5exdZHIeLAp_trt.obj
# - Jarrow_Formulas_Glucosamine_Hci_Mega_1000_100_ct_trt.obj
# - LEGO_City_Advent_Calendar_trt.obj
# - LEGO_Duplo_Build_and_Play_Box_4629_trt.obj
# - LEGO_Duplo_Creative_Animals_10573_trt.obj
# - LEGO_Star_Wars_Advent_Calendar_trt.obj
# - Little_Big_Planet_3_Plush_Edition_trt.obj
# - Little_Debbie_Chocolate_Cupcakes_8_ct_trt.obj
# - Little_House_on_the_Prairie_Season_Two_5_Discs_Includes_Digital_trt.obj
# - Marc_Anthony_True_Professional_Oil_of_Morocco_Argan_Oil_Treatment_trt.obj
# - Mastic_Gum_trt.obj
# - Melissa_Doug_Shape_Sorting_Clock_trt.obj
# - Mens_Gold_Cup_ASV_2Eye_Boat_Shoe_in_Cognac_Leather_trt.obj
# - Mens_Gold_Cup_ASV_Capetown_Penny_Loafer_in_Black_EjPnk3E8fCs_trt.obj
# - Mens_Gold_Cup_ASV_Capetown_Penny_Loafer_in_Black_GkQBKqABeQN_trt.obj
# - Mens_Largo_Slip_On_in_Taupe_gooyS417q4R_trt.obj
# - Mens_Mako_Canoe_Moc_2Eye_Boat_Shoe_in_OysterTaupe_otyRrfvPMiA_trt.obj
# - Mens_RR_Moc_in_Navy_Suede_vmFfijhBzL3_trt.obj
# - Mens_Santa_Cruz_Thong_in_Chocolate_lvxYW7lek6B_trt.obj
# - Mens_Tremont_Kiltie_Tassel_Loafer_in_Black_Amaretto_FT0I9OjSA6O_trt.obj
# - Mens_Wave_Driver_Kiltie_Moc_in_Tan_Leather_trt.obj
# - Metallic_Gold_Tieks_Italian_Leather_Ballet_Flats_trt.obj
# - My_First_Animal_Tower_trt.obj
# - My_First_Wiggle_Crocodile_trt.obj
# - Nescafe_Momento_Mocha_Specialty_Coffee_Mix_8_ct_trt.obj
# - Nestl_Crunch_Girl_Scouts_Cookie_Flavors_Caramel_Coconut_78_oz_box_trt.obj
# - Nestle_Raisinets_Milk_Chocolate_35_oz_992_g_trt.obj
# - Netgear_Nighthawk_X6_AC3200_TriBand_Gigabit_Wireless_Router_trt.obj
# - Office_Depot_Canon_CLI36_Remanufactured_Ink_Cartridge_TriColor_trt.obj
# - Office_Depot_Canon_CLI_8CMY_Remanufactured_Ink_Cartridges_Color_Cyan_Magenta_Yellow_3_count_trt.obj
# - Office_Depot_Dell_Series_1_Remanufactured_Ink_Cartridge_Black_trt.obj
# - Office_Depot_HP_2_Remanufactured_Ink_Cartridges_Color_Cyan_Magenta_Yellow_3_count_trt.obj
# - Office_Depot_HP_96_Remanufactured_Ink_Cartridge_Black_trt.obj
# - Olive_Kids_Birdie_Pack_n_Snack_trt.obj
# - Olive_Kids_Dinosaur_Land_Sidekick_Backpack_trt.obj
# - PHEEHAN_RUN_trt.obj
# - Phillips_Colon_Health_Probiotic_Capsule_trt.obj
# - Poise_Ultimate_Pads_Long_trt.obj
# - Pokmon_Y_Nintendo_3DS_Game_trt.obj
# - Polar_Herring_Fillets_Smoked_Peppered_705_oz_total_trt.obj
# - Predator_LZ_TRX_FG_trt.obj
# - Quercetin_500_trt.obj
# - RedBlack_Nintendo_3DSXL_trt.obj
# - Reebok_CL_DIBELLO_II_trt.obj
# - Reebok_DMX_MAX_PLUS_ATHLETIC_trt.obj
# - Reebok_R_DANCE_FLASH_trt.obj
# - Reebok_SH_COURT_MID_II_trt.obj
# - Reebok_SH_PRIME_COURT_LOW_trt.obj
# - Reebok_STUDIO_BEAT_LOW_V_trt.obj
# - Reebok_ZIGLITE_RUSH_AC_trt.obj
# - Seagate_1TB_Backup_Plus_portable_drive_Blue_trt.obj
# - Seagate_1TB_Backup_Plus_portable_drive_Silver_trt.obj
# - Seagate_3TB_Central_shared_storage_trt.obj
# - TERREX_FAST_X_GTX_trt.obj
# - Teenage_Mutant_Ninja_Turtles_Rahzar_Action_Figure_trt.obj
# - Tetris_Link_Game_trt.obj
# - Theanine_trt.obj
# - Tory_Burch_Kiernan_Riding_Boot_trt.obj
# - Tory_Burch_Reva_Metal_Logo_Litus_Snake_Print_in_dark_BranchGold_trt.obj
# - UGG_Classic_Tall_Womens_Boots_Grey_7_trt.obj
# - U_By_Kotex_Cleanwear_Heavy_Flow_Pads_32_Ct_trt.obj
# - VANS_FIRE_ROASTED_VEGGIE_CRACKERS_GLUTEN_FREE_trt.obj
# - Wilton_Pearlized_Sugar_Sprinkles_525_oz_Gold_trt.obj
# - Womens_Bluefish_2Eye_Boat_Shoe_in_Brown_Deerskin_JJ2pfEHTZG7_trt.obj
# - Womens_Bluefish_2Eye_Boat_Shoe_in_Brown_Deerskin_i1TgjjO0AKY_trt.obj
# - Womens_Bluefish_2Eye_Boat_Shoe_in_Linen_Oat_niKJKeWsmxY_trt.obj
# - Womens_Multi_13_trt.obj
# - Digital_Camo_Double_Decker_Lunch_Bag_trt.obj
# - Reebok_HIMARA_LTR_trt.obj
# - SNAIL_MEASURING_TAPE_trt.obj
# - Samsung_CLTC406S_Toner_Cartridge_Cyan_1pack_trt.obj
# - Simon_Swipe_Game_trt.obj
# - Squirt_Strain_Fruit_Basket_trt.obj
# - TURBOPROP_AIRPLANE_WITH_PILOT_trt.obj
# - Timberland_Mens_Classic_2Eye_Boat_Shoe_trt.obj
# - Timberland_Mens_Earthkeepers_Casco_Bay_Suede_1Eye_trt.obj
# - Timberland_Womens_Waterproof_Nellie_Chukka_Double_trt.obj
# - Twinlab_100_Whey_Protein_Fuel_Cookies_and_Cream_trt.obj
# - Twinlab_Premium_Creatine_Fuel_Powder_trt.obj
# - W_Lou_z0dkC78niiZ_trt.obj
# - Whey_Protein_3_Flavor_Variety_Pack_12_Packets_trt.obj
# - Whey_Protein_Chocolate_12_Packets_trt.obj
# - Womens_Betty_Chukka_Boot_in_Navy_Jersey_Sequin_y0SsHk7dKUX_trt.obj
# - Womens_Betty_Chukka_Boot_in_Navy_aEE8OqvMII4_trt.obj
# - Womens_Cloud_Logo_Authentic_Original_Boat_Shoe_in_Black_Supersoft_8LigQYwf4gr_trt.obj
# - Womens_Cloud_Logo_Authentic_Original_Boat_Shoe_in_Black_Supersoft_cZR022qFI4k_trt.obj
# - Womens_Hikerfish_Boot_in_Linen_Leather_Sparkle_Suede_imlP8VkwqIH_trt.obj
# - Womens_Sparkle_Suede_Bahama_in_Silver_Sparkle_Suede_Grey_Patent_tYrIBLMhSTN_trt.obj
# - Womens_Sparkle_Suede_Bahama_in_Silver_Sparkle_Suede_Grey_Patent_x9rclU7EJXx_trt.obj
# - Womens_Suede_Bahama_in_Graphite_Suede_p1KUwoWbw7R_trt.obj
# - Wooden_ABC_123_Blocks_50_pack_trt.obj
# - YumYum_D3_Liquid_trt.obj
# - ZX700_lYiwcTIekXk_trt.obj
# - 3D_Dollhouse_TablePurple_trt.obj
# - 45oz_RAMEKIN_ASST_DEEP_COLORS_trt.obj
# - ACE_Coffee_Mug_Kristen_16_oz_cup_trt.obj
# - BAGEL_WITH_CHEESE_trt.obj
# - BATHROOM_CLASSIC_trt.obj
# - BATHROOM_FURNITURE_SET_1_trt.obj
# - BUILD_A_ROBOT_trt.obj
# - Baby_Elements_Stacking_Cups_trt.obj
# - Brother_Ink_Cartridge_Magenta_LC75M_trt.obj
# - CONE_SORTING_kg5fbARBwts_trt.obj
# - Chefmate_8_Frypan_trt.obj
# - Closetmaid_Premium_Fabric_Cube_Red_trt.obj
# - Cole_Hardware_Antislip_Surfacing_Material_White_trt.obj
# - Cole_Hardware_Electric_Pot_Assortment_55_trt.obj
# - DANCING_ALLIGATOR_zoWBjc0jbTs_trt.obj
# - DINING_ROOM_CLASSIC_trt.obj
# - DINING_ROOM_CLASSIC_UJuxQ0hv5XU_trt.obj
# - DINNING_ROOM_FURNITURE_SET_1_trt.obj
# - DOLL_FAMILY_trt.obj
# - Diamond_Visions_Scissors_Red_trt.obj
# - Ecoforms_Plant_Container_12_Pot_Nova_trt.obj
# - Ecoforms_Plant_Container_QP6CORAL_trt.obj
# - Ecoforms_Plant_Container_QP_Turquoise_trt.obj
# - Ecoforms_Plant_Container_Quadra_Turquoise_QP12_trt.obj
# - Ecoforms_Plant_Container_S24NATURAL_trt.obj
# - Ecoforms_Plant_Container_S24Turquoise_trt.obj
# - FOOD_BEVERAGE_SET_trt.obj
# - Footed_Bowl_Sand_trt.obj
# - Full_Circle_Happy_Scraps_Out_Collector_Gray_trt.obj
# - GARDEN_SWING_trt.obj
# - Granimals_20_Wooden_ABC_Blocks_Wagon_85VdSftGsLi_trt.obj
# - Grreatv_Choice_Dog_Bowl_Gray_Bones_Plastic_20_fl_oz_total_trt.obj
# - InterDesign_Over_Door_trt.obj
# - Kong_Puppy_Teething_Rubber_Small_Pink_trt.obj
# - Lovable_Huggable_Cuddly_Boutique_Teddy_Bear_Beige_trt.obj
# - Markings_Desk_Caddy_trt.obj
# - OXO_Soft_Works_Can_Opener_SnapLock_trt.obj
# - Ocedar_Snap_On_Dust_Pan_And_Brush_1_ct_trt.obj
# - Ortho_Forward_Facing_QCaor9ImJ2G_trt.obj
# - Pepsi_Caffeine_Free_Diet_12_CT_trt.obj
# - Pepsi_Cola_Caffeine_Free_12_12_fl_oz_355_ml_cans_144_fl_oz_426_lt_trt.obj
# - Perricone_MD_High_Potency_Evening_Repair_trt.obj
# - Perricone_MD_The_Cold_Plasma_Face_Eyes_Duo_trt.obj
# - REEF_BRAIDED_CUSHION_trt.obj
# - Razer_Taipan_White_Ambidextrous_Gaming_Mouse_trt.obj
# - Retail_Leadership_Summit_tQFCizMt6g0_trt.obj
# - Room_Essentials_Dish_Drainer_Collapsible_White_trt.obj
# - Room_Essentials_Salad_Plate_Turquoise_trt.obj
# - Rubbermaid_Large_Drainer_trt.obj
# - SORTING_BUS_trt.obj
# - SORTING_TRAIN_trt.obj
# - STACKING_BEAR_V04KKgGBn2A_trt.obj
# - STACKING_RING_trt.obj
# - Schleich_Bald_Eagle_trt.obj
# - Schleich_Hereford_Bull_trt.obj
# - Schleich_Spinosaurus_Action_Figure_trt.obj
# - Schleich_Therizinosaurus_ln9cruulPqc_trt.obj
# - Shark_trt.obj
# - Shaxon_100_Molded_Category_6_RJ45RJ45_Shielded_Patch_Cord_White_trt.obj
# - Sootheze_Cold_Therapy_Elephant_trt.obj
# - TWISTED_PUZZLE_twb4AyFtu8Q_trt.obj
# - TWIST_SHAPE_trt.obj
# - Tag_Dishtowel_18_x_26_trt.obj
# - Tag_Dishtowel_Dobby_Stripe_Blue_18_x_26_trt.obj
# - Target_Basket_Medium_trt.obj
# - Threshold_Bamboo_Ceramic_Soap_Dish_trt.obj
# - Threshold_Basket_Natural_Finish_Fabric_Liner_Small_trt.obj
# - Threshold_Ramekin_White_Porcelain_trt.obj
# - Threshold_Salad_Plate_Square_Rim_Porcelain_trt.obj
# - Toys_R_Us_Treat_Dispenser_Smart_Puzzle_Foobler_trt.obj
# - Toysmith_Windem_Up_Flippin_Animals_Dog_trt.obj
# - TriStar_Products_PPC_Power_Pressure_Cooker_XL_in_Black_trt.obj
# - Ubisoft_RockSmith_Real_Tone_Cable_Xbox_360_trt.obj
# - Vtech_Stack_Sing_Rings_636_Months_trt.obj
# - ASICS_GELChallenger_9_Royal_BlueWhiteBlack_trt.obj
# - ASICS_GELLinksmaster_WhiteRasberryGunmetal_trt.obj
# - ASICS_HyperRocketgirl_SP_5_WhiteMalibu_BlueBlack_trt.obj
# - Android_Figure_Orange_trt.obj
# - Asus_Z97IPLUS_Motherboard_Mini_ITX_LGA1150_Socket_trt.obj
# - BALANCING_CACTUS_trt.obj
# - Balderdash_Game_trt.obj
# - Beyonc_Life_is_But_a_Dream_DVD_trt.obj
# - Black_and_Decker_TR3500SD_2Slice_Toaster_trt.obj
# - Blackcurrant_Lutein_trt.obj
# - Borage_GLA240Gamma_Tocopherol_trt.obj
# - CHICKEN_RACER_trt.obj
# - COAST_GUARD_BOAT_trt.obj
# - CREATIVE_BLOCKS_35_MM_trt.obj
# - Canon_Ink_Cartridge_Green_6_trt.obj
# - Canon_Pixma_Chromalife_100_Magenta_8_trt.obj
# - Chelsea_BlkHeelPMP_DwxLtZNxLZZ_trt.obj
# - CoQ10_BjTLbuRVt1t_trt.obj
# - Connect_4_Launchers_trt.obj
# - Copperhead_Snake_Tieks_Brown_Snake_Print_Ballet_Flats_trt.obj
# - Court_Attitude_trt.obj
# - Crayola_Crayons_120_crayons_trt.obj
# - Crayola_Model_Magic_Modeling_Material_Single_Packs_6_pack_05_oz_packs_trt.obj
# - Crazy_8_trt.obj
# - Creatine_Monohydrate_trt.obj
# - DRAGON_W_trt.obj
# - Don_Franciscos_Gourmet_Coffee_Medium_Decaf_100_Colombian_12_oz_340_g_trt.obj
# - ENFR_MID_ENFORCER_trt.obj
# - Epson_273XL_Ink_Cartridge_Magenta_trt.obj
# - Epson_UltraChrome_T0548_Ink_Cartridge_Matte_Black_1pack_trt.obj
# - F10_TRX_TF_rH7tmKCdUJq_trt.obj
# - FIRE_ENGINE_trt.obj
# - FIRE_TRUCK_trt.obj
# - FisherPrice_Make_A_Match_Game_Thomas_Friends_trt.obj
# - Folic_Acid_trt.obj
# - Frozen_Olafs_In_Trouble_PopOMatic_Game_OEu83W9T8pD_trt.obj
# - GRANDMOTHER_trt.obj
# - Glycerin_11_Color_BrllntBluSkydvrSlvrBlckWht_Size_80_trt.obj
# - Great_Jones_Wingtip_j5NV8GRnitM_trt.obj
# - Great_Jones_Wingtip_kAqSg6EgG0I_trt.obj
# - Guardians_of_the_Galaxy_Galactic_Battlers_Rocket_Raccoon_Figure_trt.obj
# - Hey_You_Pikachu_Nintendo_64_trt.obj
# - JUNGLE_HEIGHT_trt.obj
# - JarroDophilusFOS_Value_Size_trt.obj
# - JarroSil_Activated_Silicon_trt.obj
# - Kotex_U_Barely_There_Liners_Thin_60_count_trt.obj
# - LADYBUG_BEAD_trt.obj
# - LEGO_Fusion_Set_Town_Master_trt.obj
# - Lalaloopsy_Peanut_Big_Top_Tricycle_trt.obj
# - Lego_Friends_Mia_trt.obj
# - MINI_EXCAVATOR_trt.obj
# - MINI_FIRE_ENGINE_trt.obj
# - MOVING_MOUSE_PW_6PCSSET_trt.obj
# - Marc_Anthony_Skip_Professional_Oil_of_Morocco_Conditioner_with_Argan_Oil_trt.obj
# - Marc_Anthony_True_Professional_Strictly_Curls_Curl_Defining_Lotion_trt.obj
# - Matte_Black_Tieks_Italian_Leather_Ballet_Flats_trt.obj
# - Mens_Billfish_Ultra_Lite_Boat_Shoe_in_Dark_Brown_Blue_c6zDZTtRJr6_trt.obj
# - Mens_Santa_Cruz_Thong_in_Chocolate_La1fo2mAovE_trt.obj
# - My_Monopoly_Board_Game_trt.obj
# - NAPA_VALLEY_NAVAJO_SANDAL_trt.obj
# - NESCAFE_NESCAFE_TC_STKS_DECAF_6_CT_trt.obj
# - Nintendo_Mario_Action_Figure_trt.obj
# - Nintendo_Yoshi_Action_Figure_trt.obj
# - Office_Depot_Dell_Series_5_Remanufactured_Ink_Cartridge_Black_trt.obj
# - Office_Depot_Dell_Series_9_Color_Ink_Ink_Cartridge_MK991_MK993_trt.obj
# - Office_Depot_HP_564XL_Ink_Cartridge_Black_CN684WN_trt.obj
# - Office_Depot_HP_61Tricolor_Ink_Cartridge_trt.obj
# - Office_Depot_HP_950XL_Ink_Cartridge_Black_CN045AN_trt.obj
# - Olive_Kids_Butterfly_Garden_Munch_n_Lunch_Bag_trt.obj
# - Olive_Kids_Butterfly_Garden_Pencil_Case_trt.obj
# - Olive_Kids_Dinosaur_Land_Lunch_Box_trt.obj
# - Olive_Kids_Paisley_Pencil_Case_trt.obj
# - Phillips_Caplets_Size_24_trt.obj
# - Phillips_Stool_Softener_Liquid_Gels_30_liquid_gels_trt.obj
# - Pokmon_Conquest_Nintendo_DS_Game_trt.obj
# - Reebok_ALLYLYNN_trt.obj
# - Reebok_CLASSIC_LEGACY_II_trt.obj
# - Reebok_EASYTONE_CL_LEATHER_trt.obj
# - Reebok_PUMP_OMNI_LITE_HLS_trt.obj
# - Reebok_REALFLEX_SELECT_trt.obj
# - Reebok_R_CROSSFIT_OLY_UFORM_trt.obj
# - Reebok_SOMERSET_RUN_trt.obj
# - Reebok_TURBO_RC_trt.obj
# - Remington_TStudio_Silk_Ceramic_Hair_Straightener_2_Inch_Floating_Plates_trt.obj
# - Seagate_Archive_HDD_8_TB_Internal_hard_drive_SATA_6Gbs_35_ST8000AS0002_trt.obj
# - SpiderMan_Titan_Hero_12Inch_Action_Figure_5Hnn4mtkFsP_trt.obj
# - SpiderMan_Titan_Hero_12Inch_Action_Figure_oo1qph4wwiW_trt.obj
# - TOOL_BELT_trt.obj
# - TOWER_TUMBLING_trt.obj
# - Tena_Pads_Heavy_Long_42_pads_trt.obj
# - UGG_Bailey_Bow_Womens_Clogs_Black_7_trt.obj
# - Ultra_JarroDophilus_trt.obj
# - WATER_LANDING_NET_trt.obj
# - Wild_Copper_Tieks_Metallic_Italian_Leather_Ballet_Flats_trt.obj
# - Wilton_Easy_Layers_Cake_Pan_Set_trt.obj
# - Wilton_PreCut_Parchment_Sheets_10_x_15_24_sheets_trt.obj
# - Womens_Sparkle_Suede_Angelfish_in_Grey_Sparkle_Suede_Silver_trt.obj
# - Womens_Suede_Bahama_in_Graphite_Suede_t22AJSRjBOX_trt.obj
# - ZigKick_Hoops_trt.obj
# - adistar_boost_m_trt.obj
# Contents of /home/rayhub-user/Optim-WaLa/Benchmark_quality/Original:
# - 3D_Dollhouse_Refrigerator.obj
# - 60_CONSTRUCTION_SET.obj
# - 3M_Antislip_Surfacing_Light_Duty_White.obj
# - ALPHABET_AZ_GRADIENT.obj
# - 3D_Dollhouse_Sink.obj
# - 3D_Dollhouse_Lamp.obj
# - 5_HTP.obj
# - 2_of_Jenga_Classic_Game.obj
# - 3D_Dollhouse_Swing.obj
# - 30_CONSTRUCTION_SET.obj
# - 3D_Dollhouse_Happy_Brother.obj
# - 3M_Vinyl_Tape_Green_1_x_36_yd.obj
# - ALPHABET_AZ_GRADIENT_WQb1ufEycSj.obj
# - ACE_Coffee_Mug_Kristen_16_oz_cup.obj
# - 50_BLOCKS.obj
# - 3D_Dollhouse_Sofa.obj
# - 11pro_SL_TRX_FG.obj
# - 45oz_RAMEKIN_ASST_DEEP_COLORS.obj
# - 3D_Dollhouse_TablePurple.obj
# - AMBERLIGHT_UP_W.obj
# Contents of /home/rayhub-user/Optim-WaLa/Benchmark_quality/Tensor_RT:

# %% [markdown]
# ### Dataset download and extraction

# %%
zip_dir = '/Google_Dataset'         # Folder with zip files
output_dir = '/Google_Extracted_Dataset/'  # Where to save extracted thumbnails
os.makedirs(output_dir, exist_ok=True)

Optim_Utils.extract_first_thumbnail('/Google_Dataset/Dataset', '/Google_Dataset/Dataset/Single_Images')

# %%
folder1 = "/home/ray/WaLa/Benchmark_quality/Original"
folder2 = "/home/ray/WaLa/Benchmark_quality/Simplified"
Optim_Utils.compare_file_sizes(folder1, folder2)

# %% [markdown]
# ### Dataset Inference Tests

# %%
experiment = start(
  api_key="mqrUAXjKBRul24uX6pxR3gRHX*eyJiYXNlVXJsIjoiaHR0cHM6Ly9jb21ldC5kZXYuY2xvdWRvcy5hdXRvZGVzay5jb20ifQ",
  project_name="wala-time-checks",
  workspace="alessandro-giuliano")


  # Define the hyperparameters
hyperparameters = {
    "model_name": "ADSKAILab/WaLa-SV-1B",
    "images_path": str(Path("examples/single_view/")),
    "single_image": ["examples/single_view/table.png"],
    "output_dir": "examples/Test_Gen",
    "output_format": "obj",
    "target_num_faces": None,
    "scale": 1.8,
    "seed": 42,
    "diffusion_rescale_timestep": 5,
    "Mcubes-Optimized": True,
    "Object-3D_simplified_mesh": 'Quadratic (Post)',
}

# Log the hyperparameters to Comet
experiment.log_parameters(hyperparameters)

# %%
### Scanned Objects by Google Research
google_test_img_path = Path(os.path.expanduser('~/test_images'))  # Expands '~' to the full home directory path
output_dir = os.path.expanduser('~/Obj_generated')

model = Model.from_pretrained(pretrained_model_name_or_path=model_name)
image_transform = get_image_transform_latent_model()

run_inference(google_test_img_path,output_dir,model, experiment)

experiment.end()

# %% [markdown]
# ### Data Visualization

# %%
api_key="mqrUAXjKBRul24uX6pxR3gRHX*eyJiYXNlVXJsIjoiaHR0cHM6Ly9jb21ldC5kZXYuY2xvdWRvcy5hdXRvZGVzay5jb20ifQ"
comet_api = API(api_key=api_key)
project_name="wala-time-checks"
workspace="alessandro-giuliano"
experiment_key = '1bf42d8c3ee545628968903512893acf'
experiment_keys = {'Benchmark' : '1bf42d8c3ee545628968903512893acf',
                    'mcubes_fast_write' : '223ac82d90fc4292a33c60cc93e9f929',
                    'Simplified Vertex' : '7fa0d3b99b0d48588f11da362ed52aca',
                    'Simplified Quadratic (Inside)' : '86c28056aca843ef9f450d948beb7c61',
                    'Simplified Quadratic (Outside)' : 'ab20f6ca2c98422399ebae16ad717dff'}
                    
                    
# Retrieve the experiment
experiment = comet_api.get_experiment(workspace, project_name, experiment_keys['Benchmark'])



all_metric_data, metric_names, metric_display_names = Optim_Visualizations.retrieve_and_plot(experiment,plotting = True)

# %%
metric_statistics, default_delta_values = Optim_Visualizations.get_stats(experiment, metric_names, display = True)

# %%
Optim_Visualizations.plot_metric_pie(metric_statistics,metric_display_names)

# %%
Optim_Visualizations.plot_metric_heatmap(
    metric_statistics,
    metric_display_names,
    default_delta_values,
    include_min=True,
    include_max=True,
    include_median=True
)

# %% [markdown]
# #### Display Comparisons

# %%
# Retrieve both experiments
experiment1 = comet_api.get_experiment(workspace, project_name, experiment_keys['Benchmark'])
experiment2 = comet_api.get_experiment(workspace, project_name, experiment_keys['mcubes_fast_write'])


# Compare "export obj time"
Optim_Visualizations.compare_metric_distribution(
    experiment1, experiment2, 
    metric_name="export obj time", 
    label1="WaLa Original", 
    label2="WaLa MCubes Fast Write", 
    display_name="Object File Writing Time"
)

# Compare "Default Delta" (total runtime)
Optim_Visualizations.compare_metric_distribution(
    experiment1, experiment2, 
    metric_name="Default Delta", 
    label1="WaLa Original", 
    label2="WaLa MCubes Fast Write",
    display_name="Total Runtime"
)

# %% [markdown]
# ### Custom Optimization Implementations

# %% [markdown]
# #### Mcubes object export/ write object to file

# %%
# Generate a large random mesh for testing
num_vertices = 100_000
num_faces = 200_000

vertices = np.random.rand(num_vertices, 3)
triangles = np.random.randint(0, num_vertices, size=(num_faces, 3))


# Test and compare
filename1 = "test_original.obj"
filename2 = "test_optimized.obj"

t1 = Optim_Utils.benchmark_export(Optim_Utils.export_obj_fast, vertices, triangles, filename1)
t2 = Optim_Utils.benchmark_export(Optim_Utils.export_obj_original, vertices, triangles, filename2)

print(f"Original export_obj_original time: {t2:.4f} seconds")
print(f"Optimized export_obj time: {t1:.4f} seconds")
print(f"Speedup: {t2/t1:.2f}x faster")

# %% [markdown]
# ### Straight Through Visualization with Forward

# %%
from src.diffusion_modules.dwt import DWTInverse3d
import mcubes
args_max_depth = 3
args_wavelet = 'bior6.8'
args_padding_mode = 'constant'
args_resolution = 256


def save_visualization_obj(image_name, obj_path, samples):
        """Save a visualization object."""
        low, highs = samples

        dwt_inverse_3d = DWTInverse3d(args_max_depth, args_wavelet,args_padding_mode )
        sdf_recon = dwt_inverse_3d((low, highs))
        vertices, triangles = mcubes.marching_cubes(
            sdf_recon.cpu().detach().numpy()[0, 0], 0.0
        )

        vertices = (vertices / args_resolution) * 2.0 - 1.0
        triangles = triangles[:, ::-1]
        mcubes.export_obj(vertices, triangles, obj_path)
     
      
def display_visualization_3d(image_name, samples, output_dir):
    """Generate and save 3D visualization as multiple viewpoint images."""
    import open3d as o3d
    import numpy as np
    import mcubes
    from pathlib import Path

    # Create output directory for renders
    render_dir = Path(output_dir) / "renders" / image_name
    render_dir.mkdir(parents=True, exist_ok=True)

    # Get samples
    low, highs = samples

    # Reconstruct 3D object
    dwt_inverse_3d = DWTInverse3d(args_max_depth, args_wavelet, args_padding_mode)
    sdf_recon = dwt_inverse_3d((low, highs))
    vertices, triangles = mcubes.marching_cubes(
        sdf_recon.cpu().detach().numpy()[0, 0], 0.0
    )

    # Normalize vertices
    vertices = (vertices / args_resolution) * 2.0 - 1.0
    triangles = triangles[:, ::-1]

    # Create Open3D mesh
    mesh = o3d.geometry.TriangleMesh()
    mesh.vertices = o3d.utility.Vector3dVector(vertices)
    mesh.triangles = o3d.utility.Vector3iVector(triangles)
    mesh.compute_vertex_normals()

    # Create offscreen renderer
    render = o3d.visualization.rendering.OffscreenRenderer(800, 600)
    mat = o3d.visualization.rendering.MaterialRecord()
    mat.shader = 'defaultLit'
    render.scene.add_geometry("mesh", mesh, mat)

    # Render from multiple viewpoints
    viewpoints = [
        ([0, 0, 1], [0, 1, 0]),  # front
        ([1, 0, 0], [0, 1, 0]),  # right
        ([0, 0, -1], [0, 1, 0]), # back
        ([-1, 0, 0], [0, 1, 0]), # left
        ([0, 1, 0], [0, 0, 1]),  # top
    ]

    for i, (eye, up) in enumerate(viewpoints):
        render.setup_camera(60.0, [0, 0, 0], eye, up)
        img = render.render_to_image()
        img_path = render_dir / f"view_{i}.png"
        o3d.io.write_image(str(img_path), img)

    return render_dir

# %%
temp_save_path = '/home/ray/WaLa/examples/Test_Gen'
save_dir = Path(temp_save_path)
lh_dic = run_inference(images_path,output_dir,model)

for image_name, samples_tuple in lh_dic.items(): # Use .items() to get key-value pairs
    obj_path = os.path.join(save_dir, f"{image_name}.obj")
    low_pred, highs_pred = samples_tuple # Unpack the tuple from the dictionary value
      

    save_visualization_obj( image_name,
        obj_path=obj_path, samples=(low_pred, highs_pred)
    )

# %% [markdown]
# ## ONNX Optimization

# %%
import torch.nn.functional as F
import traceback

orig_interpolate = F.interpolate  # Save the original function


def debug_interpolate(*args, **kwargs):
    mode = kwargs.get('mode', None)
    antialias = kwargs.get('antialias', None)
    if mode == 'bicubic' and (antialias is None or antialias is True):
        print("Bicubic with antialias detected!")
        traceback.print_stack()
    return orig_interpolate(*args, **kwargs)
F.interpolate = debug_interpolate

# %%
import onnxruntime as ort
import numpy as np


image_path = Path('examples/single_view/')
single_image = ['examples/single_view/table.png']
image_transform = get_image_transform_latent_model()
lh_dic = {}

# Load your ONNX model
onnx_model_path = "model.onnx"  # Update with your actual model path
#session = ort.InferenceSession(onnx_model_path)

# Use CUDA (GPU) if available
providers = ['CUDAExecutionProvider', 'CPUExecutionProvider']
session = ort.InferenceSession(onnx_model_path, providers=providers)

for idx, image_path in enumerate(image_path.iterdir()):  # Enumerate to get the index

        print(f"Processing image: {image_path}")
        data = get_singleview_data(
            image_file=Path(image_path),
            image_transform=image_transform,
            device='cuda:0',
            image_over_white=False,
        )
        data_idx = 0
        base_name = os.path.basename(image_path)
        image_name = os.path.splitext(base_name)[0]  

        # Prepare ONNX input dictionary using model input names
        input_feed = {}
        print([inp.name for inp in session.get_inputs()])
        # If 'data' is a dictionary, flatten it for ONNX input
        input_feed = {
            "data": data["images"].cpu().numpy() if hasattr(data["images"], "cpu") else np.array(data["images"]),
            "data_low": data["low"].cpu().numpy() if hasattr(data["low"], "cpu") else np.array(data["low"]),
            "data_idx": (
                np.array([data["img_idx"].cpu().item()], dtype=np.int64)
                if hasattr(data["img_idx"], "cpu")
                else np.array([data["img_idx"]], dtype=np.int64)
            )
        }

        # Run inference
        t_inf_onnx = time.time()
        outputs = session.run(None, input_feed)
        print("Inference Time of new ONNX model", time.time() - t_inf_onnx, 's')
        lh_dic[image_name] = outputs
 

print("ONNX inference output:", outputs)

# %%
import importlib
import torch
importlib.reload(Optim_Utils)
temp_save_path = '/home/rayhub-user/Optim-WaLa/examples/Test_Gen'
save_dir = Path(temp_save_path)

for image_name, samples_tuple in lh_dic.items(): # Use .items() to get key-value pairs
    obj_path = os.path.join(save_dir, f"{image_name}.obj")
    low_pred, highs_pred = samples_tuple # Unpack the tuple from the dictionary value
    
    
    # Convert numpy arrays to torch tensors
    if isinstance(low_pred, np.ndarray):
        low_pred = torch.from_numpy(low_pred)
    if isinstance(highs_pred, np.ndarray):
        highs_pred = torch.from_numpy(highs_pred)
     # If highs_pred is not a list, wrap it in a list
    if not isinstance(highs_pred, (list, tuple)):
        highs_pred = [highs_pred]

    # Move all tensors to the correct device
    low_pred = low_pred.to('cuda:0')
    highs_pred = [h.to('cuda:0') for h in highs_pred]

    Optim_Utils.save_visualization_obj( image_name,
        obj_path=obj_path, samples=(low_pred, highs_pred)
    )

# %%
import boto3
from pathlib import Path

def upload_files_to_s3(file_paths, bucket_name, s3_prefix=""):
    """
    Uploads a list of files to an S3 bucket.

    Args:
        file_paths (list): List of file paths (str or Path) to upload.
        bucket_name (str): Name of the S3 bucket.
        s3_prefix (str): Optional prefix (folder) in the bucket.
    """
    s3 = boto3.client('s3')
    for file_path in file_paths:
        file_path = Path(file_path)
        s3_key = f"{s3_prefix}/{file_path.name}" if s3_prefix else file_path.name
        with open(file_path, "rb") as f:
            s3.upload_fileobj(f, bucket_name, s3_key)
        print(f"Uploaded {file_path} to s3://{bucket_name}/{s3_key}")

# Example usage:
files = ["model.onnx.data", "model.onnx"]
upload_files_to_s3(files, "giuliaa-optim", s3_prefix="/ONNX")
# Out:
# Uploaded model.onnx.data to s3://giuliaa-optim//ONNX/model.onnx.data
# Uploaded model.onnx to s3://giuliaa-optim//ONNX/model.onnx

# %% [markdown]
# ### TensorRT

# %%
import onnx
import tensorrt as trt
import numpy as np
import pycuda.driver as cuda
import pycuda.autoinit
import io
s3 = boto3.client('s3')

bucket_name = 'giuliaa-optim'
s3_key = '/TRT/model_base.trt'

# Convert ONNX to TensorRT engine
onnx_model_path = "model.onnx"
trt_engine_path = "model.trt"
trt_engine_path_optimized = "model_optimized.trt"

TRT_LOGGER = trt.Logger(trt.Logger.WARNING)
builder = trt.Builder(TRT_LOGGER)
network_flags = 1 << int(trt.NetworkDefinitionCreationFlag.EXPLICIT_BATCH)
network = builder.create_network(network_flags)
parser = trt.OnnxParser(network, TRT_LOGGER)

with open(onnx_model_path, "rb") as f:
    if not parser.parse(f.read()):
        for i in range(parser.num_errors):
            print(parser.get_error(i))
        raise RuntimeError("Failed to parse ONNX model")


config = builder.create_builder_config()
config.set_memory_pool_limit(trt.MemoryPoolType.WORKSPACE, 10 << 30) # 1 GiB
#config.set_flag(trt.BuilderFlag.FP16)
#config.profiling_verbosity = trt.ProfilingVerbosity.DETAILED
#config.set_tactic_sources(trt.TacticSource.CUBLAS | trt.TacticSource.CUDNN | trt.TacticSource.EDGE_MASK_CONVOLUTIONS)
#config.builder_optimization_level = 3

# Build the TensorRT engine (TensorRT 8.x+)
serialized_engine = builder.build_serialized_network(network, config)

with open(trt_engine_path, "wb") as f:
    f.write(serialized_engine)



s3.upload_fileobj(io.BytesIO(serialized_engine), bucket_name, s3_key)
print(f"Uploaded TensorRT engine to s3://{bucket_name}/{s3_key}")
# Out:
# [05/30/2025-17:28:15] [TRT] [W] ModelImporter.cpp:516: Make sure input data_idx has Int64 binding.
# [05/30/2025-17:28:32] [TRT] [W] Unused Input: data_idx
# [05/30/2025-17:28:32] [TRT] [W] Unused Input: data_low
# [05/30/2025-17:28:37] [TRT] [W] [RemoveDeadLayers] Input Tensor data_idx is unused or used only at compile-time, but is not being removed.
# [05/30/2025-17:28:37] [TRT] [W] [RemoveDeadLayers] Input Tensor data_low is unused or used only at compile-time, but is not being removed.
# Uploaded TensorRT engine to s3://giuliaa-optim//TRT/model_base.trt

# %%
import tensorrt as trt
import numpy as np
import time
import torch
from pathlib import Path
import os
import pycuda.driver as cuda
import pycuda.autoinit
import io
from src.dataset_utils import get_singleview_data, get_image_transform_latent_model
import Optim_Utils

# Load TensorRT engine
def load_engine(engine_path):
    logger = trt.Logger(trt.Logger.WARNING)
    with open(engine_path, "rb") as f:
        runtime = trt.Runtime(logger)
        return runtime.deserialize_cuda_engine(f.read())

def load_engine_from_s3(bucket_name, s3_key):
    """
    Loads a TensorRT engine directly from S3 into memory and checks buffer size.
    """


    s3 = boto3.client('s3')
    # Get expected file size from S3
    obj = s3.head_object(Bucket=bucket_name, Key=s3_key)
    expected_size = obj['ContentLength']

    engine_buffer = io.BytesIO()
    s3.download_fileobj(bucket_name, s3_key, engine_buffer)
    engine_buffer.seek(0)
    actual_size = len(engine_buffer.getvalue())
    print(f"S3 engine size: {expected_size} bytes, Downloaded buffer size: {actual_size} bytes")
    if actual_size != expected_size:
        raise RuntimeError("Downloaded engine size does not match S3 object size!")

    logger = trt.Logger(trt.Logger.WARNING)
    runtime = trt.Runtime(logger)
    return runtime.deserialize_cuda_engine(engine_buffer.read())




# Modern TensorRT inference function using tensor API
def run_trt_inference(engine, input_data,stream,context):
    """
    Run inference using TensorRT with modern tensor API
    
    Args:
        engine: TensorRT engine
        input_data: List of input numpy arrays
        
    Returns:
        List of output numpy arrays
    """


    # Get input and output tensor names
    input_names = []
    output_names = []
    
    time_input_names = time.time()
    for i in range(engine.num_io_tensors):
        name = engine.get_tensor_name(i)
        if engine.get_tensor_mode(name) == trt.TensorIOMode.INPUT:
            input_names.append(name)
        else:
            output_names.append(name)
    print(f"Time to get input/output names: {time.time() - time_input_names:.4f} seconds")
    # Prepare device memory
    device_memory = []
    
    time_handle = time.time()
    # Handle inputs
    for i, name in enumerate(input_names):
        if i >= len(input_data):
            continue
            
        data = input_data[i]
        
        # Handle dynamic input shapes
        if -1 in engine.get_tensor_shape(name):
            context.set_input_shape(name, data.shape)
        
        # Allocate device memory and copy input data
        mem = cuda.mem_alloc(data.nbytes)
        cuda.memcpy_htod_async(mem, data, stream)
        device_memory.append(mem)
        context.set_tensor_address(name, int(mem))
    print(f"Time to handle inputs: {time.time() - time_handle:.4f} seconds")

    # Prepare outputs
    outputs = []
    output_memory = []
    
    time_allocate = time.time()
    # Allocate output memory
    for name in output_names:
        shape = context.get_tensor_shape(name)
        dtype = trt.nptype(engine.get_tensor_dtype(name))
        
        # Allocate device memory for output
        size = trt.volume(shape) * np.dtype(dtype).itemsize
        mem = cuda.mem_alloc(size)
        device_memory.append(mem)
        output_memory.append(mem)
        
        # Set output tensor address
        context.set_tensor_address(name, int(mem))
        
        # Create host output array
        output = np.empty(shape, dtype=dtype)
        outputs.append(output)
    print(f"Time to allocate output memory: {time.time() - time_allocate:.4f} seconds")

    # Run inference
    time_asyncv3 = time.time()
    context.execute_async_v3(stream_handle=stream.handle)
    print(f"Async inference time: {time.time() - time_asyncv3:.4f} seconds")

    time_copy = time.time()
    # Copy outputs from device to host
    for i, mem in enumerate(output_memory):
        cuda.memcpy_dtoh_async(outputs[i], mem, stream)
    print(f"Time to copy outputs: {time.time() - time_copy:.4f} seconds")

    time_sync = time.time()
    # Synchronize to ensure all operations are complete
    stream.synchronize()
    print(f"Time to synchronize: {time.time() - time_sync:.4f} seconds")

    time_free = time.time()
    # Free device memory
    for mem in device_memory:
        mem.free()
    print(f"Time to free device memory: {time.time() - time_free:.4f} seconds")


    return outputs

# Main experiment function
def run_tensorrt_experiment(image_dir, engine_path,bucket_name = 'giuliaa-optim',s3_key='TRT/model_base.trt', use_s3 = False, experiment = None):
    # Load image transform
    image_transform = get_image_transform_latent_model()
    
    
    if use_s3:
        # Load TensorRT engine from S3
        engine = load_engine_from_s3(bucket_name, s3_key)
    else:
        # Load TensorRT engine from local path
        if not os.path.exists(engine_path):
            raise FileNotFoundError(f"TensorRT engine file {engine_path} does not exist.")
        engine = load_engine(engine_path)
    
    # Results storage
    results = []
    image_path = Path(image_dir)
    save_dir = Path('/home/rayhub-user/Optim-WaLa/examples/Test_Gen')
    os.makedirs(save_dir, exist_ok=True)


    time_contx = time.time()
    # Create execution context
    context = engine.create_execution_context()
    print(f"Time to create execution context: {time.time() - time_contx:.4f} seconds")

    time_stream = time.time()
    # Create a CUDA stream for async operations
    stream = cuda.Stream()
    print(f"Time to create CUDA stream: {time.time() - time_stream:.4f} seconds")

    try:

        experiment.log_metric("Time to create execution context", time.time() - time_contx)
        experiment.log_metric("Time to create CUDA stream", time.time() - time_stream)
    except:
        pass

    # Process each image
    for img_file in image_path.iterdir():      
        time_default = time.time()
  
        print(f"\nProcessing image: {img_file.name}")
        img_name = img_file.stem
        
        # Get image data
        data = get_singleview_data(
            image_file=img_file,
            image_transform=image_transform,
            image_over_white=False,
            device = 'cpu'
        )
        
        


        # Prepare input data as numpy arrays
        inputs = [
            data["images"].cpu().numpy() if hasattr(data["images"], "cpu") else np.array(data["images"]),
            data["low"].cpu().numpy() if hasattr(data["low"], "cpu") else np.array(data["low"]),
            data["img_idx"].cpu().numpy() if hasattr(data["img_idx"], "cpu") else np.array([data["img_idx"]], dtype=np.int64)
        ]


####### For Debug
        #for i, arr in enumerate(data.values()):
            #print(f"Input[{i}] min/max/mean:", np.nanmin(arr), np.nanmax(arr), np.nanmean(arr))
            #print(f"Any NaN in input[{i}]?", np.isnan(arr).any())
#######
        # Run TensorRT inference and measure time
        start_time = time.time()
        outputs = run_trt_inference(engine, inputs,stream,context)
        inference_time = time.time() - start_time

        try:
            experiment.log_metric("TensorRT Inference Time", inference_time)
        except: 
            pass
####### For Debug        
        #print("Output[0] min/max/mean:", np.nanmin(outputs[0]), np.nanmax(outputs[0]), np.nanmean(outputs[0]))
        #print("Output[1] min/max/mean:", np.nanmin(outputs[1]), np.nanmax(outputs[1]), np.nanmean(outputs[1]))
        #print("Any NaN in output[0]?", np.isnan(outputs[0]).any())
        #print("Any NaN in output[1]?", np.isnan(outputs[1]).any())
#######



        print(f"TensorRT inference time: {inference_time:.4f} seconds")
        
        # Store result
        results.append({
            "image": img_name,
            "inference_time": inference_time
        })
        
        # Generate 3D object from TensorRT outputs
        low_trt = torch.from_numpy(outputs[0]).to('cuda:0')
        high_trt = [torch.from_numpy(outputs[1]).to('cuda:0')]
        obj_path = str(save_dir / f"{img_name}_trt.obj")
        # Save visualization
        Optim_Utils.save_visualization_obj(img_name, obj_path, (low_trt, high_trt))
        print('Total Inference time with Writing', time.time() - time_default)
        
        try:
            experiment.log_metric("Default Delta", time.time() - time_default)
        except:
            pass

        
    # Calculate average inference time
    avg_time = sum(item["inference_time"] for item in results) / len(results)
    print(f"\nAverage TensorRT inference time: {avg_time:.4f} seconds")
    
    return results

# Run the experiment
image_dir = 'examples/single_view/'
trt_engine_path = "model.trt"
s3_key='/TRT/model_base.trt'
bucket_name = 'giuliaa-optim'

results = run_tensorrt_experiment(image_dir, trt_engine_path,bucket_name, s3_key, use_s3 = True, experiment = None)
# Out:
# S3 engine size: 5301395820 bytes, Downloaded buffer size: 5301395820 bytes
# Time to create execution context: 1.3477 seconds
# Time to create CUDA stream: 0.0000 seconds
#
# Processing image: table.png
# Time to get input/output names: 0.0000 seconds
# Time to handle inputs: 0.0002 seconds
# Time to allocate output memory: 0.0003 seconds
# Async inference time: 1.3587 seconds
# Time to copy outputs: 0.3741 seconds
# Time to synchronize: 0.0002 seconds
# Time to free device memory: 0.0003 seconds
# TensorRT inference time: 1.7341 seconds
# Total Inference time with Writing 1.853771686553955
#
# Processing image: apple.jpeg
# Time to get input/output names: 0.0000 seconds
# Time to handle inputs: 0.0003 seconds
# Time to allocate output memory: 0.0004 seconds
# Async inference time: 1.3501 seconds
# Time to copy outputs: 0.3745 seconds
# Time to synchronize: 0.0002 seconds
# Time to free device memory: 0.0003 seconds
# TensorRT inference time: 1.7260 seconds
# Total Inference time with Writing 1.7829906940460205
#
# Processing image: pear.jpeg
# Time to get input/output names: 0.0000 seconds
# Time to handle inputs: 0.0002 seconds
# Time to allocate output memory: 0.0004 seconds
# Async inference time: 1.3502 seconds
# Time to copy outputs: 0.3755 seconds
# Time to synchronize: 0.0001 seconds
# Time to free device memory: 0.0003 seconds
# TensorRT inference time: 1.7270 seconds
# Total Inference time with Writing 1.787013053894043
#
# Processing image: chair.png
# Time to get input/output names: 0.0000 seconds
# Time to handle inputs: 0.0002 seconds
# Time to allocate output memory: 0.0003 seconds
# Async inference time: 1.3499 seconds
# Time to copy outputs: 0.3740 seconds
# Time to synchronize: 0.0002 seconds
# Time to free device memory: 0.0003 seconds
# TensorRT inference time: 1.7253 seconds
# Total Inference time with Writing 1.9010505676269531
#
# Average TensorRT inference time: 1.7281 seconds

# %% [markdown]
# ### Inference TRT Google Dataset

# %%
experiment = start(
  api_key="mqrUAXjKBRul24uX6pxR3gRHX*eyJiYXNlVXJsIjoiaHR0cHM6Ly9jb21ldC5kZXYuY2xvdWRvcy5hdXRvZGVzay5jb20ifQ",
  project_name="wala-time-checks",
  workspace="alessandro-giuliano")


  # Define the hyperparameters
hyperparameters = {
    "model_name": "ADSKAILab/WaLa-SV-1B",
    "output_format": "obj",
    "target_num_faces": None,
    "scale": 1.8,
    "seed": 42,
    "diffusion_rescale_timestep": 5,
    "Mcubes-Optimized": True,
    "Object-3D_simplified_mesh": None,
    "TRT Model": "model.trt",
    "TRT Optimization": "Base",
}

# Log the hyperparameters to Comet
experiment.log_parameters(hyperparameters)
# Out:
# COMET INFO: An experiment with the same configuration options is already running and will be reused.

# %%
import tensorrt as trt
import numpy as np
import time
import torch
from pathlib import Path
import os
import pycuda.driver as cuda
import pycuda.autoinit

from src.dataset_utils import get_singleview_data, get_image_transform_latent_model
import Optim_Utils



# Load TensorRT engine
def load_engine(engine_path):
    logger = trt.Logger(trt.Logger.WARNING)
    with open(engine_path, "rb") as f:
        runtime = trt.Runtime(logger)
        return runtime.deserialize_cuda_engine(f.read())

# %%
google_test_img_path = '/GD_Dataset_Single_View'
output_dir = '/Google_Dataset_Outputs'

image_path = Path(google_test_img_path)
save_dir = Path(output_dir)
os.makedirs(save_dir, exist_ok=True)
image_transform = get_image_transform_latent_model()

engine = load_engine(trt_engine_path)
context = engine.create_execution_context()
stream = cuda.Stream()

results = []
for img_file in image_path.glob('*.[jp][pn]g'):
    time_default = time.time()
    print(f"\nProcessing image: {img_file.name}")
    img_name = img_file.stem

    data = get_singleview_data(
        image_file=img_file,
        image_transform=image_transform,
        image_over_white=False,
        device='cpu'
    )

    inputs = [
        data["images"].cpu().numpy() if hasattr(data["images"], "cpu") else np.array(data["images"]),
        data["low"].cpu().numpy() if hasattr(data["low"], "cpu") else np.array(data["low"]),
        data["img_idx"].cpu().numpy() if hasattr(data["img_idx"], "cpu") else np.array([data["img_idx"]], dtype=np.int64)
    ]

    start_time = time.time()
    outputs = run_trt_inference(engine, inputs, stream, context)
    inference_time = time.time() - start_time

    experiment.log_metric("TensorRT Inference Time", inference_time, step=None)
    print(f"TensorRT inference time: {inference_time:.4f} seconds")

    results.append({
        "image": img_name,
        "inference_time": inference_time
    })

    low_trt = torch.from_numpy(outputs[0]).to('cuda:0')
    high_trt = [torch.from_numpy(outputs[1]).to('cuda:0')]
    obj_path = str(save_dir / f"{img_name}_trt.obj")
    Optim_Utils.save_visualization_obj(img_name, obj_path, (low_trt, high_trt))
    print('Total Inference time with Writing', time.time() - time_default)

avg_time = sum(item["inference_time"] for item in results) / len(results)
experiment.log_metric("Average TensorRT Inference Time", avg_time)
print(f"\nAverage TensorRT inference time: {avg_time:.4f} seconds")

experiment.end()
# Out:
# Processing image: 2_of_Jenga_Classic_Game.jpg
# Time to get input/output names: 0.0000 seconds
# Time to handle inputs: 0.0003 seconds
# Time to allocate output memory: 0.0004 seconds
# Async inference time: 1.3603 seconds
# Time to copy outputs: 0.3737 seconds
# Time to synchronize: 0.0000 seconds
# Time to free device memory: 0.0003 seconds
# TensorRT inference time: 1.7358 seconds
# Total Inference time with Writing 1.765320062637329
#
# Processing image: 50_BLOCKS.jpg
# Time to get input/output names: 0.0000 seconds
# Time to handle inputs: 0.0003 seconds
# Time to allocate output memory: 0.0004 seconds
# Async inference time: 1.3505 seconds
# Time to copy outputs: 0.3742 seconds
# Time to synchronize: 0.0000 seconds
# Time to free device memory: 0.0003 seconds
# TensorRT inference time: 1.7266 seconds
# Total Inference time with Writing 1.7941734790802002
#
# Processing image: 5_HTP.jpg
# Time to get input/output names: 0.0001 seconds
# Time to handle inputs: 0.0003 seconds
# Time to allocate output memory: 0.0004 seconds
# Async inference time: 1.3500 seconds
# Time to copy outputs: 0.3738 seconds
# Time to synchronize: 0.0000 seconds
# Time to free device memory: 0.0003 seconds
# TensorRT inference time: 1.7257 seconds
# Total Inference time with Writing 1.8470094203948975
#
# Processing image: ASICS_GELAce_Pro_Pearl_WhitePink.jpg
# Time to get input/output names: 0.0000 seconds
# Time to handle inputs: 0.0003 seconds
# Time to allocate output memory: 0.0004 seconds
# Async inference time: 1.3505 seconds
# Time to copy outputs: 0.3740 seconds
# Time to synchronize: 0.0000 seconds
# Time to free device memory: 0.0003 seconds
# TensorRT inference time: 1.7263 seconds
# Total Inference time with Writing 1.816295862197876
#
# Processing image: ASICS_GELBlur33_20_GS_BlackWhiteSafety_Orange.jpg
# Time to get input/output names: 0.0000 seconds
# Time to handle inputs: 0.0003 seconds
# Time to allocate output memory: 0.0004 seconds
# Async inference time: 1.3504 seconds
# Time to copy outputs: 0.3738 seconds
# Time to synchronize: 0.0000 seconds
# Time to free device memory: 0.0003 seconds
# TensorRT inference time: 1.7261 seconds
# Total Inference time with Writing 1.8279170989990234
#
# Processing image: Asus_M5A78LMUSB3_Motherboard_Micro_ATX_Socket_AM3.jpg
# Time to get input/output names: 0.0000 seconds
# Time to handle inputs: 0.0003 seconds
# Time to allocate output memory: 0.0004 seconds
# Async inference time: 1.3503 seconds
# Time to copy outputs: 0.3739 seconds
# Time to synchronize: 0.0000 seconds
# Time to free device memory: 0.0003 seconds
# TensorRT inference time: 1.7261 seconds
# Total Inference time with Writing 1.844719409942627
#
# Processing image: Asus_M5A99FX_PRO_R20_Motherboard_ATX_Socket_AM3.jpg
# Time to get input/output names: 0.0000 seconds
# Time to handle inputs: 0.0003 seconds
# Time to allocate output memory: 0.0004 seconds
# Async inference time: 1.3504 seconds
# Time to copy outputs: 0.3737 seconds
# Time to synchronize: 0.0000 seconds
# Time to free device memory: 0.0003 seconds
# TensorRT inference time: 1.7259 seconds
# Total Inference time with Writing 1.8565070629119873
#
# Processing image: Asus_Sabertooth_990FX_20_Motherboard_ATX_Socket_AM3.jpg
# Time to get input/output names: 0.0000 seconds
# Time to handle inputs: 0.0003 seconds
# Time to allocate output memory: 0.0004 seconds
# Async inference time: 1.3503 seconds
# Time to copy outputs: 0.3740 seconds
# Time to synchronize: 0.0001 seconds
# Time to free device memory: 0.0003 seconds
# TensorRT inference time: 1.7261 seconds
# Total Inference time with Writing 1.8479840755462646
#
# Processing image: Asus_Sabertooth_Z97_MARK_1_Motherboard_ATX_LGA1150_Socket.jpg
# Time to get input/output names: 0.0000 seconds
# Time to handle inputs: 0.0003 seconds
# Time to allocate output memory: 0.0004 seconds
# Async inference time: 1.3503 seconds
# Time to copy outputs: 0.3739 seconds
# Time to synchronize: 0.0000 seconds
# Time to free device memory: 0.0003 seconds
# TensorRT inference time: 1.7260 seconds
# Total Inference time with Writing 1.8447647094726562
#
# Processing image: BlackBlack_Nintendo_3DSXL.jpg
# Time to get input/output names: 0.0000 seconds
# Time to handle inputs: 0.0003 seconds
# Time to allocate output memory: 0.0004 seconds
# Async inference time: 1.3505 seconds
# Time to copy outputs: 0.3739 seconds
# Time to synchronize: 0.0000 seconds
# Time to free device memory: 0.0003 seconds
# TensorRT inference time: 1.7262 seconds
# Total Inference time with Writing 1.8358874320983887
#
# Processing image: Black_Decker_Stainless_Steel_Toaster_4_Slice.jpg
# Time to get input/output names: 0.0000 seconds
# Time to handle inputs: 0.0003 seconds
# Time to allocate output memory: 0.0004 seconds
# Async inference time: 1.3503 seconds
# Time to copy outputs: 0.3740 seconds
# Time to synchronize: 0.0000 seconds
# Time to free device memory: 0.0003 seconds
# TensorRT inference time: 1.7260 seconds
# Total Inference time with Writing 1.8406269550323486
#
# Processing image: Black_Elderberry_Syrup_54_oz_Gaia_Herbs.jpg
# Time to get input/output names: 0.0000 seconds
# Time to handle inputs: 0.0003 seconds
# Time to allocate output memory: 0.0004 seconds
# Async inference time: 1.3502 seconds
# Time to copy outputs: 0.3740 seconds
# Time to synchronize: 0.0000 seconds
# Time to free device memory: 0.0003 seconds
# TensorRT inference time: 1.7259 seconds
# Total Inference time with Writing 1.8393828868865967
#
# Processing image: BlueBlack_Nintendo_3DSXL.jpg
# Time to get input/output names: 0.0000 seconds
# Time to handle inputs: 0.0003 seconds
# Time to allocate output memory: 0.0004 seconds
# Async inference time: 1.3503 seconds
# Time to copy outputs: 0.3739 seconds
# Time to synchronize: 0.0000 seconds
# Time to free device memory: 0.0003 seconds
# TensorRT inference time: 1.7260 seconds
# Total Inference time with Writing 1.8324065208435059
#
# Processing image: Blue_Jasmine_Includes_Digital_Copy_UltraViolet_DVD.jpg
# Time to get input/output names: 0.0000 seconds
# Time to handle inputs: 0.0003 seconds
# Time to allocate output memory: 0.0004 seconds
# Async inference time: 1.3505 seconds
# Time to copy outputs: 0.3740 seconds
# Time to synchronize: 0.0000 seconds
# Time to free device memory: 0.0003 seconds
# TensorRT inference time: 1.7264 seconds
# Total Inference time with Writing 1.77431058883667
#
# Processing image: Cootie_Game.jpg
# Time to get input/output names: 0.0000 seconds
# Time to handle inputs: 0.0003 seconds
# Time to allocate output memory: 0.0004 seconds
# Async inference time: 1.3506 seconds
# Time to copy outputs: 0.3741 seconds
# Time to synchronize: 0.0000 seconds
# Time to free device memory: 0.0003 seconds
# TensorRT inference time: 1.7265 seconds
# Total Inference time with Writing 1.7914605140686035
#
# Processing image: Dell_Series_9_Color_Ink_Cartridge_MK993_High_Yield.jpg
# Time to get input/output names: 0.0000 seconds
# Time to handle inputs: 0.0003 seconds
# Time to allocate output memory: 0.0004 seconds
# Async inference time: 1.3502 seconds
# Time to copy outputs: 0.3738 seconds
# Time to synchronize: 0.0000 seconds
# Time to free device memory: 0.0003 seconds
# TensorRT inference time: 1.7258 seconds
# Total Inference time with Writing 1.8230621814727783
#
# Processing image: Frozen_Scrabble_Jr.jpg
# Time to get input/output names: 0.0000 seconds
# Time to handle inputs: 0.0003 seconds
# Time to allocate output memory: 0.0004 seconds
# Async inference time: 1.3505 seconds
# Time to copy outputs: 0.3739 seconds
# Time to synchronize: 0.0000 seconds
# Time to free device memory: 0.0003 seconds
# TensorRT inference time: 1.7262 seconds
# Total Inference time with Writing 1.8239643573760986
#
# Processing image: Google_Cardboard_Original_package.jpg
# Time to get input/output names: 0.0000 seconds
# Time to handle inputs: 0.0003 seconds
# Time to allocate output memory: 0.0004 seconds
# Async inference time: 1.3505 seconds
# Time to copy outputs: 0.3739 seconds
# Time to synchronize: 0.0000 seconds
# Time to free device memory: 0.0003 seconds
# TensorRT inference time: 1.7262 seconds
# Total Inference time with Writing 1.7998194694519043
#
# Processing image: HP_Card_Invitation_Kit.jpg
# Time to get input/output names: 0.0000 seconds
# Time to handle inputs: 0.0003 seconds
# Time to allocate output memory: 0.0004 seconds
# Async inference time: 1.3505 seconds
# Time to copy outputs: 0.3740 seconds
# Time to synchronize: 0.0000 seconds
# Time to free device memory: 0.0003 seconds
# TensorRT inference time: 1.7263 seconds
# Total Inference time with Writing 1.8364930152893066
#
# Processing image: Hyaluronic_Acid.jpg
# Time to get input/output names: 0.0000 seconds
# Time to handle inputs: 0.0003 seconds
# Time to allocate output memory: 0.0004 seconds
# Async inference time: 1.3506 seconds
# Time to copy outputs: 0.3739 seconds
# Time to synchronize: 0.0000 seconds
# Time to free device memory: 0.0003 seconds
# TensorRT inference time: 1.7263 seconds
# Total Inference time with Writing 1.838550329208374
#
# Processing image: LEGO_Creationary_Game.jpg
# Time to get input/output names: 0.0001 seconds
# Time to handle inputs: 0.0004 seconds
# Time to allocate output memory: 0.0004 seconds
# Async inference time: 1.3502 seconds
# Time to copy outputs: 0.3739 seconds
# Time to synchronize: 0.0000 seconds
# Time to free device memory: 0.0003 seconds
# TensorRT inference time: 1.7262 seconds
# Total Inference time with Writing 1.7917048931121826
#
# Processing image: LEGO_Creationary_Game_ZJa163wlWp2.jpg
# Time to get input/output names: 0.0000 seconds
# Time to handle inputs: 0.0003 seconds
# Time to allocate output memory: 0.0004 seconds
# Async inference time: 1.3503 seconds
# Time to copy outputs: 0.3739 seconds
# Time to synchronize: 0.0000 seconds
# Time to free device memory: 0.0003 seconds
# TensorRT inference time: 1.7260 seconds
# Total Inference time with Writing 1.8336694240570068
#
# Processing image: Lenovo_Yoga_2_11.jpg
# Time to get input/output names: 0.0000 seconds
# Time to handle inputs: 0.0003 seconds
# Time to allocate output memory: 0.0004 seconds
# Async inference time: 1.3503 seconds
# Time to copy outputs: 0.3740 seconds
# Time to synchronize: 0.0000 seconds
# Time to free device memory: 0.0003 seconds
# TensorRT inference time: 1.7261 seconds
# Total Inference time with Writing 1.8293046951293945
#
# Processing image: Logitech_Ultimate_Ears_Boom_Wireless_Speaker_Night_Black.jpg
# Time to get input/output names: 0.0000 seconds
# Time to handle inputs: 0.0003 seconds
# Time to allocate output memory: 0.0004 seconds
# Async inference time: 1.3503 seconds
# Time to copy outputs: 0.3739 seconds
# Time to synchronize: 0.0000 seconds
# Time to free device memory: 0.0003 seconds
# TensorRT inference time: 1.7259 seconds
# Total Inference time with Writing 1.786539077758789
#
# Processing image: Lovestruck_Tieks_Glittery_Rose_Gold_Italian_Leather_Ballet_Flats.jpg
# Time to get input/output names: 0.0000 seconds
# Time to handle inputs: 0.0003 seconds
# Time to allocate output memory: 0.0004 seconds
# Async inference time: 1.3503 seconds
# Time to copy outputs: 0.3739 seconds
# Time to synchronize: 0.0000 seconds
# Time to free device memory: 0.0003 seconds
# TensorRT inference time: 1.7261 seconds
# Total Inference time with Writing 1.8233704566955566
#
# Processing image: Luigis_Mansion_Dark_Moon_Nintendo_3DS_Game.jpg
# Time to get input/output names: 0.0000 seconds
# Time to handle inputs: 0.0003 seconds
# Time to allocate output memory: 0.0004 seconds
# Async inference time: 1.3501 seconds
# Time to copy outputs: 0.3738 seconds
# Time to synchronize: 0.0000 seconds
# Time to free device memory: 0.0003 seconds
# TensorRT inference time: 1.7256 seconds
# Total Inference time with Writing 1.8040924072265625
#
# Processing image: Mens_ASV_Billfish_Boat_Shoe_in_Dark_Brown_Leather_zdHVHXueI3w.jpg
# Time to get input/output names: 0.0000 seconds
# Time to handle inputs: 0.0003 seconds
# Time to allocate output memory: 0.0004 seconds
# Async inference time: 1.3503 seconds
# Time to copy outputs: 0.3740 seconds
# Time to synchronize: 0.0000 seconds
# Time to free device memory: 0.0003 seconds
# TensorRT inference time: 1.7260 seconds
# Total Inference time with Writing 1.8138573169708252
#
# Processing image: Mens_Authentic_Original_Boat_Shoe_in_Navy_Leather_xgoEcZtRNmH.jpg
# Time to get input/output names: 0.0000 seconds
# Time to handle inputs: 0.0003 seconds
# Time to allocate output memory: 0.0004 seconds
# Async inference time: 1.3503 seconds
# Time to copy outputs: 0.3740 seconds
# Time to synchronize: 0.0000 seconds
# Time to free device memory: 0.0003 seconds
# TensorRT inference time: 1.7259 seconds
# Total Inference time with Writing 1.801696538925171
#
# Processing image: Mens_Striper_Sneaker_in_White_rnp8HUli59Y.jpg
# Time to get input/output names: 0.0000 seconds
# Time to handle inputs: 0.0003 seconds
# Time to allocate output memory: 0.0004 seconds
# Async inference time: 1.3505 seconds
# Time to copy outputs: 0.3740 seconds
# Time to synchronize: 0.0000 seconds
# Time to free device memory: 0.0003 seconds
# TensorRT inference time: 1.7262 seconds
# Total Inference time with Writing 1.807082176208496
#
# Processing image: Womens_Audrey_Slip_On_Boat_Shoe_in_Graphite_Nubuck_xWVkCJ5vxZe.jpg
# Time to get input/output names: 0.0000 seconds
# Time to handle inputs: 0.0003 seconds
# Time to allocate output memory: 0.0004 seconds
# Async inference time: 1.3504 seconds
# Time to copy outputs: 0.3740 seconds
# Time to synchronize: 0.0000 seconds
# Time to free device memory: 0.0003 seconds
# TensorRT inference time: 1.7261 seconds
# Total Inference time with Writing 1.804321050643921
#
# Processing image: Womens_Betty_Chukka_Boot_in_Grey_Jersey_Sequin.jpg
# Time to get input/output names: 0.0000 seconds
# Time to handle inputs: 0.0003 seconds
# Time to allocate output memory: 0.0004 seconds
# Async inference time: 1.3507 seconds
# Time to copy outputs: 0.3741 seconds
# Time to synchronize: 0.0000 seconds
# Time to free device memory: 0.0003 seconds
# TensorRT inference time: 1.7264 seconds
# Total Inference time with Writing 1.8203299045562744
#
# Processing image: Womens_Betty_Chukka_Boot_in_Salt_Washed_Red_AL2YrOt9CRy.jpg
# Time to get input/output names: 0.0000 seconds
# Time to handle inputs: 0.0003 seconds
# Time to allocate output memory: 0.0004 seconds
# Async inference time: 1.3504 seconds
# Time to copy outputs: 0.3739 seconds
# Time to synchronize: 0.0001 seconds
# Time to free device memory: 0.0003 seconds
# TensorRT inference time: 1.7260 seconds
# Total Inference time with Writing 1.8362927436828613
#
# Processing image: Womens_Bluefish_2Eye_Boat_Shoe_in_White_Tumbled_YG44xIePRHw.jpg
# Time to get input/output names: 0.0000 seconds
# Time to handle inputs: 0.0003 seconds
# Time to allocate output memory: 0.0004 seconds
# Async inference time: 1.3501 seconds
# Time to copy outputs: 0.3740 seconds
# Time to synchronize: 0.0000 seconds
# Time to free device memory: 0.0003 seconds
# TensorRT inference time: 1.7257 seconds
# Total Inference time with Writing 1.828066349029541
#
# Processing image: 30_CONSTRUCTION_SET.jpg
# Time to get input/output names: 0.0000 seconds
# Time to handle inputs: 0.0003 seconds
# Time to allocate output memory: 0.0004 seconds
# Async inference time: 1.3504 seconds
# Time to copy outputs: 0.3741 seconds
# Time to synchronize: 0.0000 seconds
# Time to free device memory: 0.0003 seconds
# TensorRT inference time: 1.7261 seconds
# Total Inference time with Writing 1.814208745956421
#
# Processing image: 3D_Dollhouse_Swing.jpg
# Time to get input/output names: 0.0000 seconds
# Time to handle inputs: 0.0003 seconds
# Time to allocate output memory: 0.0004 seconds
# Async inference time: 1.3503 seconds
# Time to copy outputs: 0.3740 seconds
# Time to synchronize: 0.0000 seconds
# Time to free device memory: 0.0003 seconds
# TensorRT inference time: 1.7261 seconds
# Total Inference time with Writing 1.8459315299987793
#
# Processing image: 3M_Antislip_Surfacing_Light_Duty_White.jpg
# Time to get input/output names: 0.0000 seconds
# Time to handle inputs: 0.0003 seconds
# Time to allocate output memory: 0.0004 seconds
# Async inference time: 1.3506 seconds
# Time to copy outputs: 0.3740 seconds
# Time to synchronize: 0.0000 seconds
# Time to free device memory: 0.0003 seconds
# TensorRT inference time: 1.7263 seconds
# Total Inference time with Writing 1.8044450283050537
#
# Processing image: 3M_Vinyl_Tape_Green_1_x_36_yd.jpg
# Time to get input/output names: 0.0000 seconds
# Time to handle inputs: 0.0003 seconds
# Time to allocate output memory: 0.0004 seconds
# Async inference time: 1.3505 seconds
# Time to copy outputs: 0.3739 seconds
# Time to synchronize: 0.0000 seconds
# Time to free device memory: 0.0003 seconds
# TensorRT inference time: 1.7259 seconds
# Total Inference time with Writing 1.8249988555908203
#
# Processing image: Animal_Planet_Foam_2Headed_Dragon.jpg
# Time to get input/output names: 0.0001 seconds
# Time to handle inputs: 0.0003 seconds
# Time to allocate output memory: 0.0004 seconds
# Async inference time: 1.3504 seconds
# Time to copy outputs: 0.3742 seconds
# Time to synchronize: 0.0000 seconds
# Time to free device memory: 0.0003 seconds
# TensorRT inference time: 1.7263 seconds
# Total Inference time with Writing 1.804147481918335
#
# Processing image: Avengers_Thor_PLlrpYniaeB.jpg
# Time to get input/output names: 0.0000 seconds
# Time to handle inputs: 0.0003 seconds
# Time to allocate output memory: 0.0004 seconds
# Async inference time: 1.3503 seconds
# Time to copy outputs: 0.3740 seconds
# Time to synchronize: 0.0000 seconds
# Time to free device memory: 0.0003 seconds
# TensorRT inference time: 1.7259 seconds
# Total Inference time with Writing 1.876420021057129
#
# Processing image: BEDROOM_CLASSIC.jpg
# Time to get input/output names: 0.0000 seconds
# Time to handle inputs: 0.0003 seconds
# Time to allocate output memory: 0.0004 seconds
# Async inference time: 1.3515 seconds
# Time to copy outputs: 0.3744 seconds
# Time to synchronize: 0.0000 seconds
# Time to free device memory: 0.0003 seconds
# TensorRT inference time: 1.7276 seconds
# Total Inference time with Writing 1.8112430572509766
#
# Processing image: BIA_Cordon_Bleu_White_Porcelain_Utensil_Holder_900028.jpg
# Time to get input/output names: 0.0000 seconds
# Time to handle inputs: 0.0004 seconds
# Time to allocate output memory: 0.0004 seconds
# Async inference time: 1.3517 seconds
# Time to copy outputs: 0.3742 seconds
# Time to synchronize: 0.0000 seconds
# Time to free device memory: 0.0003 seconds
# TensorRT inference time: 1.7279 seconds
# Total Inference time with Writing 1.907642126083374
#
# Processing image: CONE_SORTING.jpg
# Time to get input/output names: 0.0000 seconds
# Time to handle inputs: 0.0003 seconds
# Time to allocate output memory: 0.0004 seconds
# Async inference time: 1.3515 seconds
# Time to copy outputs: 0.3743 seconds
# Time to synchronize: 0.0000 seconds
# Time to free device memory: 0.0003 seconds
# TensorRT inference time: 1.7276 seconds
# Total Inference time with Writing 1.8554432392120361
#
# Processing image: Clorox_Premium_Choice_Gloves_SM_1_pair.jpg
# Time to get input/output names: 0.0000 seconds
# Time to handle inputs: 0.0003 seconds
# Time to allocate output memory: 0.0004 seconds
# Async inference time: 1.3517 seconds
# Time to copy outputs: 0.3742 seconds
# Time to synchronize: 0.0000 seconds
# Time to free device memory: 0.0003 seconds
# TensorRT inference time: 1.7278 seconds
# Total Inference time with Writing 1.778730869293213
#
# Processing image: Cole_Hardware_Deep_Bowl_Good_Earth_1075.jpg
# Time to get input/output names: 0.0000 seconds
# Time to handle inputs: 0.0003 seconds
# Time to allocate output memory: 0.0004 seconds
# Async inference time: 1.3513 seconds
# Time to copy outputs: 0.3742 seconds
# Time to synchronize: 0.0000 seconds
# Time to free device memory: 0.0003 seconds
# TensorRT inference time: 1.7273 seconds
# Total Inference time with Writing 1.8522353172302246
#
# Processing image: Cole_Hardware_Dishtowel_BlueWhite.jpg
# Time to get input/output names: 0.0000 seconds
# Time to handle inputs: 0.0003 seconds
# Time to allocate output memory: 0.0004 seconds
# Async inference time: 1.3517 seconds
# Time to copy outputs: 0.3743 seconds
# Time to synchronize: 0.0000 seconds
# Time to free device memory: 0.0003 seconds
# TensorRT inference time: 1.7277 seconds
# Total Inference time with Writing 1.7925736904144287
#
# Processing image: Cole_Hardware_Hammer_Black.jpg
# Time to get input/output names: 0.0000 seconds
# Time to handle inputs: 0.0003 seconds
# Time to allocate output memory: 0.0004 seconds
# Async inference time: 1.3517 seconds
# Time to copy outputs: 0.3742 seconds
# Time to synchronize: 0.0002 seconds
# Time to free device memory: 0.0003 seconds
# TensorRT inference time: 1.7278 seconds
# Total Inference time with Writing 1.78131103515625
#
# Processing image: Cole_Hardware_Mini_Honey_Dipper.jpg
# Time to get input/output names: 0.0000 seconds
# Time to handle inputs: 0.0003 seconds
# Time to allocate output memory: 0.0004 seconds
# Async inference time: 1.3514 seconds
# Time to copy outputs: 0.3744 seconds
# Time to synchronize: 0.0000 seconds
# Time to free device memory: 0.0003 seconds
# TensorRT inference time: 1.7277 seconds
# Total Inference time with Writing 1.7555582523345947
#
# Processing image: Cole_Hardware_Plant_Saucer_Brown_125.jpg
# Time to get input/output names: 0.0000 seconds
# Time to handle inputs: 0.0003 seconds
# Time to allocate output memory: 0.0004 seconds
# Async inference time: 1.3515 seconds
# Time to copy outputs: 0.3744 seconds
# Time to synchronize: 0.0000 seconds
# Time to free device memory: 0.0003 seconds
# TensorRT inference time: 1.7276 seconds
# Total Inference time with Writing 1.8118839263916016
#
# Processing image: Deskstar_Desk_Top_Hard_Drive_1_TB.jpg
# Time to get input/output names: 0.0000 seconds
# Time to handle inputs: 0.0003 seconds
# Time to allocate output memory: 0.0004 seconds
# Async inference time: 1.3514 seconds
# Time to copy outputs: 0.3743 seconds
# Time to synchronize: 0.0000 seconds
# Time to free device memory: 0.0003 seconds
# TensorRT inference time: 1.7275 seconds
# Total Inference time with Writing 1.8564753532409668
#
# Processing image: Cole_Hardware_Saucer_Glazed_6.jpg
# Time to get input/output names: 0.0000 seconds
# Time to handle inputs: 0.0003 seconds
# Time to allocate output memory: 0.0004 seconds
# Async inference time: 1.3515 seconds
# Time to copy outputs: 0.3743 seconds
# Time to synchronize: 0.0000 seconds
# Time to free device memory: 0.0003 seconds
# TensorRT inference time: 1.7276 seconds
# Total Inference time with Writing 1.8193743228912354
#
# Processing image: Diet_Pepsi_Soda_Cola12_Pack_12_oz_Cans.jpg
# Time to get input/output names: 0.0000 seconds
# Time to handle inputs: 0.0003 seconds
# Time to allocate output memory: 0.0004 seconds
# Async inference time: 1.3506 seconds
# Time to copy outputs: 0.3740 seconds
# Time to synchronize: 0.0000 seconds
# Time to free device memory: 0.0003 seconds
# TensorRT inference time: 1.7264 seconds
# Total Inference time with Writing 1.805929183959961
#
# Processing image: Ecoforms_Cup_B4_SAN.jpg
# Time to get input/output names: 0.0000 seconds
# Time to handle inputs: 0.0003 seconds
# Time to allocate output memory: 0.0004 seconds
# Async inference time: 1.3505 seconds
# Time to copy outputs: 0.3739 seconds
# Time to synchronize: 0.0000 seconds
# Time to free device memory: 0.0003 seconds
# TensorRT inference time: 1.7261 seconds
# Total Inference time with Writing 1.8802907466888428
#
# Processing image: Ecoforms_Plant_Container_B4_Har.jpg
# Time to get input/output names: 0.0000 seconds
# Time to handle inputs: 0.0003 seconds
# Time to allocate output memory: 0.0004 seconds
# Async inference time: 1.3505 seconds
# Time to copy outputs: 0.3739 seconds
# Time to synchronize: 0.0000 seconds
# Time to free device memory: 0.0003 seconds
# TensorRT inference time: 1.7261 seconds
# Total Inference time with Writing 1.8888881206512451
#
# Processing image: Ecoforms_Plant_Container_GP16AMOCHA.jpg
# Time to get input/output names: 0.0000 seconds
# Time to handle inputs: 0.0003 seconds
# Time to allocate output memory: 0.0004 seconds
# Async inference time: 1.3514 seconds
# Time to copy outputs: 0.3742 seconds
# Time to synchronize: 0.0000 seconds
# Time to free device memory: 0.0003 seconds
# TensorRT inference time: 1.7274 seconds
# Total Inference time with Writing 1.903102159500122
#
# Processing image: Ecoforms_Plant_Container_GP16A_Coral.jpg
# Time to get input/output names: 0.0000 seconds
# Time to handle inputs: 0.0003 seconds
# Time to allocate output memory: 0.0004 seconds
# Async inference time: 1.3526 seconds
# Time to copy outputs: 0.3743 seconds
# Time to synchronize: 0.0000 seconds
# Time to free device memory: 0.0003 seconds
# TensorRT inference time: 1.7288 seconds
# Total Inference time with Writing 1.9104466438293457
#
# Processing image: Ecoforms_Plant_Container_QP6HARVEST.jpg
# Time to get input/output names: 0.0000 seconds
# Time to handle inputs: 0.0003 seconds
# Time to allocate output memory: 0.0004 seconds
# Async inference time: 1.3516 seconds
# Time to copy outputs: 0.3743 seconds
# Time to synchronize: 0.0000 seconds
# Time to free device memory: 0.0003 seconds
# TensorRT inference time: 1.7277 seconds
# Total Inference time with Writing 1.9015076160430908
#
# Processing image: Ecoforms_Plant_Container_URN_NAT.jpg
# Time to get input/output names: 0.0000 seconds
# Time to handle inputs: 0.0003 seconds
# Time to allocate output memory: 0.0004 seconds
# Async inference time: 1.3507 seconds
# Time to copy outputs: 0.3739 seconds
# Time to synchronize: 0.0000 seconds
# Time to free device memory: 0.0003 seconds
# TensorRT inference time: 1.7265 seconds
# Total Inference time with Writing 1.891479253768921
#
# Processing image: Ecoforms_Plant_Container_Urn_55_Mocha.jpg
# Time to get input/output names: 0.0000 seconds
# Time to handle inputs: 0.0003 seconds
# Time to allocate output memory: 0.0004 seconds
# Async inference time: 1.3505 seconds
# Time to copy outputs: 0.3742 seconds
# Time to synchronize: 0.0000 seconds
# Time to free device memory: 0.0003 seconds
# TensorRT inference time: 1.7265 seconds
# Total Inference time with Writing 1.8873145580291748
#
# Processing image: Ecoforms_Plant_Pot_GP9_SAND.jpg
# Time to get input/output names: 0.0000 seconds
# Time to handle inputs: 0.0003 seconds
# Time to allocate output memory: 0.0004 seconds
# Async inference time: 1.3516 seconds
# Time to copy outputs: 0.3743 seconds
# Time to synchronize: 0.0000 seconds
# Time to free device memory: 0.0003 seconds
# TensorRT inference time: 1.7278 seconds
# Total Inference time with Writing 1.9044947624206543
#
# Processing image: Ecoforms_Plant_Saucer_S17MOCHA.jpg
# Time to get input/output names: 0.0000 seconds
# Time to handle inputs: 0.0003 seconds
# Time to allocate output memory: 0.0004 seconds
# Async inference time: 1.3515 seconds
# Time to copy outputs: 0.3742 seconds
# Time to synchronize: 0.0002 seconds
# Time to free device memory: 0.0003 seconds
# TensorRT inference time: 1.7277 seconds
# Total Inference time with Writing 1.8181378841400146
#
# Processing image: Ecoforms_Planter_Bowl_Cole_Hardware.jpg
# Time to get input/output names: 0.0000 seconds
# Time to handle inputs: 0.0003 seconds
# Time to allocate output memory: 0.0004 seconds
# Async inference time: 1.3516 seconds
# Time to copy outputs: 0.3742 seconds
# Time to synchronize: 0.0000 seconds
# Time to free device memory: 0.0003 seconds
# TensorRT inference time: 1.7276 seconds
# Total Inference time with Writing 1.874101161956787
#
# Processing image: Elephant.jpg
# Time to get input/output names: 0.0000 seconds
# Time to handle inputs: 0.0003 seconds
# Time to allocate output memory: 0.0004 seconds
# Async inference time: 1.3506 seconds
# Time to copy outputs: 0.3740 seconds
# Time to synchronize: 0.0003 seconds
# Time to free device memory: 0.0003 seconds
# TensorRT inference time: 1.7267 seconds
# Total Inference time with Writing 1.8201096057891846
#
# Processing image: Gigabyte_GAZ97XSLI_10_motherboard_ATX_LGA1150_Socket_Z97.jpg
# Time to get input/output names: 0.0000 seconds
# Time to handle inputs: 0.0003 seconds
# Time to allocate output memory: 0.0004 seconds
# Async inference time: 1.3508 seconds
# Time to copy outputs: 0.3741 seconds
# Time to synchronize: 0.0000 seconds
# Time to free device memory: 0.0003 seconds
# TensorRT inference time: 1.7266 seconds
# Total Inference time with Writing 1.846102237701416
#
# Processing image: Granimals_20_Wooden_ABC_Blocks_Wagon.jpg
# Time to get input/output names: 0.0000 seconds
# Time to handle inputs: 0.0003 seconds
# Time to allocate output memory: 0.0004 seconds
# Async inference time: 1.3505 seconds
# Time to copy outputs: 0.3741 seconds
# Time to synchronize: 0.0000 seconds
# Time to free device memory: 0.0003 seconds
# TensorRT inference time: 1.7264 seconds
# Total Inference time with Writing 1.8056635856628418
#
# Processing image: Great_Dinos_Triceratops_Toy.jpg
# Time to get input/output names: 0.0000 seconds
# Time to handle inputs: 0.0003 seconds
# Time to allocate output memory: 0.0004 seconds
# Async inference time: 1.3507 seconds
# Time to copy outputs: 0.3740 seconds
# Time to synchronize: 0.0000 seconds
# Time to free device memory: 0.0003 seconds
# TensorRT inference time: 1.7265 seconds
# Total Inference time with Writing 1.8259589672088623
#
# Processing image: Hefty_Waste_Basket_Decorative_Bronze_85_liter.jpg
# Time to get input/output names: 0.0000 seconds
# Time to handle inputs: 0.0003 seconds
# Time to allocate output memory: 0.0004 seconds
# Async inference time: 1.3504 seconds
# Time to copy outputs: 0.3740 seconds
# Time to synchronize: 0.0000 seconds
# Time to free device memory: 0.0003 seconds
# TensorRT inference time: 1.7262 seconds
# Total Inference time with Writing 1.8883116245269775
#
# Processing image: INTERNATIONAL_PAPER_Willamette_4_Brown_Bag_500Count.jpg
# Time to get input/output names: 0.0000 seconds
# Time to handle inputs: 0.0003 seconds
# Time to allocate output memory: 0.0004 seconds
# Async inference time: 1.3516 seconds
# Time to copy outputs: 0.3744 seconds
# Time to synchronize: 0.0000 seconds
# Time to free device memory: 0.0003 seconds
# TensorRT inference time: 1.7277 seconds
# Total Inference time with Writing 1.8357110023498535
#
# Processing image: KS_Chocolate_Cube_Box_Assortment_By_Neuhaus_2010_Ounces.jpg
# Time to get input/output names: 0.0000 seconds
# Time to handle inputs: 0.0003 seconds
# Time to allocate output memory: 0.0004 seconds
# Async inference time: 1.3507 seconds
# Time to copy outputs: 0.3739 seconds
# Time to synchronize: 0.0000 seconds
# Time to free device memory: 0.0003 seconds
# TensorRT inference time: 1.7264 seconds
# Total Inference time with Writing 1.8557641506195068
#
# Processing image: Neat_Solutions_Character_Bib_2_pack.jpg
# Time to get input/output names: 0.0000 seconds
# Time to handle inputs: 0.0003 seconds
# Time to allocate output memory: 0.0004 seconds
# Async inference time: 1.3504 seconds
# Time to copy outputs: 0.3740 seconds
# Time to synchronize: 0.0000 seconds
# Time to free device memory: 0.0003 seconds
# TensorRT inference time: 1.7261 seconds
# Total Inference time with Writing 1.8528008460998535
#
# Processing image: Now_Designs_Bowl_Akita_Black.jpg
# Time to get input/output names: 0.0000 seconds
# Time to handle inputs: 0.0003 seconds
# Time to allocate output memory: 0.0004 seconds
# Async inference time: 1.3517 seconds
# Time to copy outputs: 0.3742 seconds
# Time to synchronize: 0.0000 seconds
# Time to free device memory: 0.0003 seconds
# TensorRT inference time: 1.7276 seconds
# Total Inference time with Writing 1.847761869430542
#
# Processing image: Ortho_Forward_Facing_3Q6J2oKJD92.jpg
# Time to get input/output names: 0.0000 seconds
# Time to handle inputs: 0.0003 seconds
# Time to allocate output memory: 0.0004 seconds
# Async inference time: 1.3526 seconds
# Time to copy outputs: 0.3743 seconds
# Time to synchronize: 0.0000 seconds
# Time to free device memory: 0.0003 seconds
# TensorRT inference time: 1.7287 seconds
# Total Inference time with Writing 1.8321208953857422
#
# Processing image: PEPSI_NEXT_CACRV.jpg
# Time to get input/output names: 0.0000 seconds
# Time to handle inputs: 0.0003 seconds
# Time to allocate output memory: 0.0004 seconds
# Async inference time: 1.3527 seconds
# Time to copy outputs: 0.3743 seconds
# Time to synchronize: 0.0000 seconds
# Time to free device memory: 0.0003 seconds
# TensorRT inference time: 1.7288 seconds
# Total Inference time with Writing 1.8103182315826416
#
# Processing image: POUNDING_MUSHROOMS.jpg
# Time to get input/output names: 0.0000 seconds
# Time to handle inputs: 0.0003 seconds
# Time to allocate output memory: 0.0004 seconds
# Async inference time: 1.3516 seconds
# Time to copy outputs: 0.3744 seconds
# Time to synchronize: 0.0000 seconds
# Time to free device memory: 0.0003 seconds
# TensorRT inference time: 1.7278 seconds
# Total Inference time with Writing 1.8195405006408691
#
# Processing image: PUNCH_DROP_TjicLPMqLvz.jpg
# Time to get input/output names: 0.0000 seconds
# Time to handle inputs: 0.0003 seconds
# Time to allocate output memory: 0.0004 seconds
# Async inference time: 1.3518 seconds
# Time to copy outputs: 0.3744 seconds
# Time to synchronize: 0.0000 seconds
# Time to free device memory: 0.0003 seconds
# TensorRT inference time: 1.7280 seconds
# Total Inference time with Writing 1.8526813983917236
#
# Processing image: Pepsi_Max_Cola_Zero_Calorie_12_12_fl_oz_355_ml_cans_144_fl_oz_426_lt.jpg
# Time to get input/output names: 0.0000 seconds
# Time to handle inputs: 0.0003 seconds
# Time to allocate output memory: 0.0004 seconds
# Async inference time: 1.3514 seconds
# Time to copy outputs: 0.3744 seconds
# Time to synchronize: 0.0000 seconds
# Time to free device memory: 0.0003 seconds
# TensorRT inference time: 1.7276 seconds
# Total Inference time with Writing 1.8099870681762695
#
# Processing image: Perricone_MD_AcylGlutathione_Eye_Lid_Serum.jpg
# Time to get input/output names: 0.0000 seconds
# Time to handle inputs: 0.0003 seconds
# Time to allocate output memory: 0.0004 seconds
# Async inference time: 1.3515 seconds
# Time to copy outputs: 0.3743 seconds
# Time to synchronize: 0.0000 seconds
# Time to free device memory: 0.0003 seconds
# TensorRT inference time: 1.7276 seconds
# Total Inference time with Writing 1.865321397781372
#
# Processing image: Perricone_MD_Face_Finishing_Moisturizer.jpg
# Time to get input/output names: 0.0000 seconds
# Time to handle inputs: 0.0003 seconds
# Time to allocate output memory: 0.0004 seconds
# Async inference time: 1.3516 seconds
# Time to copy outputs: 0.3742 seconds
# Time to synchronize: 0.0000 seconds
# Time to free device memory: 0.0003 seconds
# TensorRT inference time: 1.7275 seconds
# Total Inference time with Writing 1.859663963317871
#
# Processing image: Perricone_MD_Hypoallergenic_Firming_Eye_Cream_05_oz.jpg
# Time to get input/output names: 0.0000 seconds
# Time to handle inputs: 0.0003 seconds
# Time to allocate output memory: 0.0004 seconds
# Async inference time: 1.3509 seconds
# Time to copy outputs: 0.3742 seconds
# Time to synchronize: 0.0000 seconds
# Time to free device memory: 0.0003 seconds
# TensorRT inference time: 1.7268 seconds
# Total Inference time with Writing 1.857564926147461
#
# Processing image: Perricone_MD_No_Foundation_Foundation_No_1.jpg
# Time to get input/output names: 0.0000 seconds
# Time to handle inputs: 0.0003 seconds
# Time to allocate output memory: 0.0004 seconds
# Async inference time: 1.3506 seconds
# Time to copy outputs: 0.3741 seconds
# Time to synchronize: 0.0000 seconds
# Time to free device memory: 0.0003 seconds
# TensorRT inference time: 1.7262 seconds
# Total Inference time with Writing 1.8446285724639893
#
# Processing image: Perricone_MD_Photo_Plasma.jpg
# Time to get input/output names: 0.0000 seconds
# Time to handle inputs: 0.0003 seconds
# Time to allocate output memory: 0.0004 seconds
# Async inference time: 1.3525 seconds
# Time to copy outputs: 0.3744 seconds
# Time to synchronize: 0.0000 seconds
# Time to free device memory: 0.0003 seconds
# TensorRT inference time: 1.7287 seconds
# Total Inference time with Writing 1.8527770042419434
#
# Processing image: Perricone_MD_Skin_Total_Body_Supplements.jpg
# Time to get input/output names: 0.0000 seconds
# Time to handle inputs: 0.0003 seconds
# Time to allocate output memory: 0.0004 seconds
# Async inference time: 1.3527 seconds
# Time to copy outputs: 0.3744 seconds
# Time to synchronize: 0.0000 seconds
# Time to free device memory: 0.0003 seconds
# TensorRT inference time: 1.7289 seconds
# Total Inference time with Writing 1.8649766445159912
#
# Processing image: Perricone_MD_Super_Berry_Powder_with_Acai_Supplements.jpg
# Time to get input/output names: 0.0000 seconds
# Time to handle inputs: 0.0003 seconds
# Time to allocate output memory: 0.0004 seconds
# Async inference time: 1.3517 seconds
# Time to copy outputs: 0.3744 seconds
# Time to synchronize: 0.0000 seconds
# Time to free device memory: 0.0003 seconds
# TensorRT inference time: 1.7279 seconds
# Total Inference time with Writing 1.8552157878875732
#
# Processing image: Perricone_MD_Vitamin_C_Ester_Serum.jpg
# Time to get input/output names: 0.0000 seconds
# Time to handle inputs: 0.0003 seconds
# Time to allocate output memory: 0.0004 seconds
# Async inference time: 1.3518 seconds
# Time to copy outputs: 0.3744 seconds
# Time to synchronize: 0.0000 seconds
# Time to free device memory: 0.0003 seconds
# TensorRT inference time: 1.7279 seconds
# Total Inference time with Writing 1.8605539798736572
#
# Processing image: Pony_C_Clamp_1440.jpg
# Time to get input/output names: 0.0000 seconds
# Time to handle inputs: 0.0003 seconds
# Time to allocate output memory: 0.0004 seconds
# Async inference time: 1.3518 seconds
# Time to copy outputs: 0.3744 seconds
# Time to synchronize: 0.0000 seconds
# Time to free device memory: 0.0003 seconds
# TensorRT inference time: 1.7279 seconds
# Total Inference time with Writing 1.7790777683258057
#
# Processing image: Poppin_File_Sorter_Blue.jpg
# Time to get input/output names: 0.0000 seconds
# Time to handle inputs: 0.0003 seconds
# Time to allocate output memory: 0.0004 seconds
# Async inference time: 1.3515 seconds
# Time to copy outputs: 0.3743 seconds
# Time to synchronize: 0.0000 seconds
# Time to free device memory: 0.0003 seconds
# TensorRT inference time: 1.7274 seconds
# Total Inference time with Writing 1.8244152069091797
#
# Processing image: Razer_BlackWidow_Stealth_2014_Keyboard_07VFzIVabgh.jpg
# Time to get input/output names: 0.0000 seconds
# Time to handle inputs: 0.0003 seconds
# Time to allocate output memory: 0.0004 seconds
# Async inference time: 1.3528 seconds
# Time to copy outputs: 0.3746 seconds
# Time to synchronize: 0.0000 seconds
# Time to free device memory: 0.0003 seconds
# TensorRT inference time: 1.7290 seconds
# Total Inference time with Writing 1.7765305042266846
#
# Processing image: Razer_Kraken_Pro_headset_Full_size_Black.jpg
# Time to get input/output names: 0.0000 seconds
# Time to handle inputs: 0.0003 seconds
# Time to allocate output memory: 0.0004 seconds
# Async inference time: 1.3518 seconds
# Time to copy outputs: 0.3744 seconds
# Time to synchronize: 0.0000 seconds
# Time to free device memory: 0.0003 seconds
# TensorRT inference time: 1.7280 seconds
# Total Inference time with Writing 1.793346643447876
#
# Processing image: Reef_Star_Cushion_Flipflops_Size_8_Black.jpg
# Time to get input/output names: 0.0000 seconds
# Time to handle inputs: 0.0003 seconds
# Time to allocate output memory: 0.0004 seconds
# Async inference time: 1.3516 seconds
# Time to copy outputs: 0.3745 seconds
# Time to synchronize: 0.0000 seconds
# Time to free device memory: 0.0003 seconds
# TensorRT inference time: 1.7277 seconds
# Total Inference time with Writing 1.790341854095459
#
# Processing image: Retail_Leadership_Summit.jpg
# Time to get input/output names: 0.0000 seconds
# Time to handle inputs: 0.0003 seconds
# Time to allocate output memory: 0.0004 seconds
# Async inference time: 1.3519 seconds
# Time to copy outputs: 0.3743 seconds
# Time to synchronize: 0.0000 seconds
# Time to free device memory: 0.0003 seconds
# TensorRT inference time: 1.7278 seconds
# Total Inference time with Writing 1.8516595363616943
#
# Processing image: Retail_Leadership_Summit_eCT3zqHYIkX.jpg
# Time to get input/output names: 0.0000 seconds
# Time to handle inputs: 0.0003 seconds
# Time to allocate output memory: 0.0004 seconds
# Async inference time: 1.3519 seconds
# Time to copy outputs: 0.3746 seconds
# Time to synchronize: 0.0000 seconds
# Time to free device memory: 0.0003 seconds
# TensorRT inference time: 1.7282 seconds
# Total Inference time with Writing 1.8637123107910156
#
# Processing image: Rexy_Glove_Heavy_Duty_Gloves_Medium.jpg
# Time to get input/output names: 0.0000 seconds
# Time to handle inputs: 0.0003 seconds
# Time to allocate output memory: 0.0004 seconds
# Async inference time: 1.3518 seconds
# Time to copy outputs: 0.3744 seconds
# Time to synchronize: 0.0000 seconds
# Time to free device memory: 0.0003 seconds
# TensorRT inference time: 1.7280 seconds
# Total Inference time with Writing 1.7962291240692139
#
# Processing image: Room_Essentials_Fabric_Cube_Lavender.jpg
# Time to get input/output names: 0.0000 seconds
# Time to handle inputs: 0.0003 seconds
# Time to allocate output memory: 0.0003 seconds
# Async inference time: 1.3517 seconds
# Time to copy outputs: 0.3742 seconds
# Time to synchronize: 0.0000 seconds
# Time to free device memory: 0.0003 seconds
# TensorRT inference time: 1.7277 seconds
# Total Inference time with Writing 1.920480489730835
#
# Processing image: Room_Essentials_Kitchen_Towels_16_x_26_2_count.jpg
# Time to get input/output names: 0.0000 seconds
# Time to handle inputs: 0.0003 seconds
# Time to allocate output memory: 0.0004 seconds
# Async inference time: 1.3527 seconds
# Time to copy outputs: 0.3743 seconds
# Time to synchronize: 0.0000 seconds
# Time to free device memory: 0.0003 seconds
# TensorRT inference time: 1.7288 seconds
# Total Inference time with Writing 1.8380184173583984
#
# Processing image: Sea_to_Summit_Xl_Bowl.jpg
# Time to get input/output names: 0.0000 seconds
# Time to handle inputs: 0.0020 seconds
# Time to allocate output memory: 0.0004 seconds
# Async inference time: 1.3517 seconds
# Time to copy outputs: 0.3739 seconds
# Time to synchronize: 0.0000 seconds
# Time to free device memory: 0.0003 seconds
# TensorRT inference time: 1.7292 seconds
# Total Inference time with Writing 1.828742504119873
#
# Processing image: Shurtape_Gaffers_Tape_Silver_2_x_60_yd.jpg
# Time to get input/output names: 0.0000 seconds
# Time to handle inputs: 0.0003 seconds
# Time to allocate output memory: 0.0004 seconds
# Async inference time: 1.3507 seconds
# Time to copy outputs: 0.3740 seconds
# Time to synchronize: 0.0000 seconds
# Time to free device memory: 0.0003 seconds
# TensorRT inference time: 1.7265 seconds
# Total Inference time with Writing 1.8304815292358398
#
# Processing image: Threshold_Performance_Bath_Sheet_Sandoval_Blue_33_x_63.jpg
# Time to get input/output names: 0.0000 seconds
# Time to handle inputs: 0.0003 seconds
# Time to allocate output memory: 0.0004 seconds
# Async inference time: 1.3519 seconds
# Time to copy outputs: 0.3740 seconds
# Time to synchronize: 0.0000 seconds
# Time to free device memory: 0.0003 seconds
# TensorRT inference time: 1.7277 seconds
# Total Inference time with Writing 1.81032133102417
#
# Processing image: Threshold_Porcelain_Serving_Bowl_Coupe_White.jpg
# Time to get input/output names: 0.0000 seconds
# Time to handle inputs: 0.0003 seconds
# Time to allocate output memory: 0.0004 seconds
# Async inference time: 1.3508 seconds
# Time to copy outputs: 0.3741 seconds
# Time to synchronize: 0.0000 seconds
# Time to free device memory: 0.0003 seconds
# TensorRT inference time: 1.7267 seconds
# Total Inference time with Writing 1.8336422443389893
#
# Processing image: Threshold_Porcelain_Spoon_Rest_White.jpg
# Time to get input/output names: 0.0000 seconds
# Time to handle inputs: 0.0003 seconds
# Time to allocate output memory: 0.0004 seconds
# Async inference time: 1.3506 seconds
# Time to copy outputs: 0.3739 seconds
# Time to synchronize: 0.0000 seconds
# Time to free device memory: 0.0003 seconds
# TensorRT inference time: 1.7261 seconds
# Total Inference time with Writing 1.8026180267333984
#
# Processing image: Top_Paw_Dog_Bowl_Blue_Paw_Bone_Ceramic_25_fl_oz_total.jpg
# Time to get input/output names: 0.0000 seconds
# Time to handle inputs: 0.0003 seconds
# Time to allocate output memory: 0.0004 seconds
# Async inference time: 1.3507 seconds
# Time to copy outputs: 0.3742 seconds
# Time to synchronize: 0.0000 seconds
# Time to free device memory: 0.0003 seconds
# TensorRT inference time: 1.7265 seconds
# Total Inference time with Writing 1.8559370040893555
#
# Processing image: Vtech_Cruise_Learn_Car_25_Years.jpg
# Time to get input/output names: 0.0000 seconds
# Time to handle inputs: 0.0003 seconds
# Time to allocate output memory: 0.0004 seconds
# Async inference time: 1.3507 seconds
# Time to copy outputs: 0.3739 seconds
# Time to synchronize: 0.0001 seconds
# Time to free device memory: 0.0003 seconds
# TensorRT inference time: 1.7264 seconds
# Total Inference time with Writing 1.7836527824401855
#
# Processing image: Animal_Crossing_New_Leaf_Nintendo_3DS_Game.jpg
# Time to get input/output names: 0.0000 seconds
# Time to handle inputs: 0.0003 seconds
# Time to allocate output memory: 0.0004 seconds
# Async inference time: 1.3506 seconds
# Time to copy outputs: 0.3740 seconds
# Time to synchronize: 0.0000 seconds
# Time to free device memory: 0.0003 seconds
# TensorRT inference time: 1.7264 seconds
# Total Inference time with Writing 1.8044555187225342
#
# Processing image: BUNNY_RATTLE.jpg
# Time to get input/output names: 0.0000 seconds
# Time to handle inputs: 0.0003 seconds
# Time to allocate output memory: 0.0004 seconds
# Async inference time: 1.3505 seconds
# Time to copy outputs: 0.3740 seconds
# Time to synchronize: 0.0000 seconds
# Time to free device memory: 0.0003 seconds
# TensorRT inference time: 1.7263 seconds
# Total Inference time with Writing 1.7968111038208008
#
# Processing image: Crayola_Crayons_24_count.jpg
# Time to get input/output names: 0.0000 seconds
# Time to handle inputs: 0.0003 seconds
# Time to allocate output memory: 0.0004 seconds
# Async inference time: 1.3508 seconds
# Time to copy outputs: 0.3741 seconds
# Time to synchronize: 0.0000 seconds
# Time to free device memory: 0.0003 seconds
# TensorRT inference time: 1.7267 seconds
# Total Inference time with Writing 1.8157484531402588
#
# Processing image: Crayola_Model_Magic_Modeling_Material_White_3_oz.jpg
# Time to get input/output names: 0.0000 seconds
# Time to handle inputs: 0.0003 seconds
# Time to allocate output memory: 0.0004 seconds
# Async inference time: 1.3508 seconds
# Time to copy outputs: 0.3740 seconds
# Time to synchronize: 0.0000 seconds
# Time to free device memory: 0.0003 seconds
# TensorRT inference time: 1.7264 seconds
# Total Inference time with Writing 1.8273327350616455
#
# Processing image: Crayola_Washable_Sidewalk_Chalk_16_pack.jpg
# Time to get input/output names: 0.0000 seconds
# Time to handle inputs: 0.0003 seconds
# Time to allocate output memory: 0.0004 seconds
# Async inference time: 1.3508 seconds
# Time to copy outputs: 0.3740 seconds
# Time to synchronize: 0.0000 seconds
# Time to free device memory: 0.0003 seconds
# TensorRT inference time: 1.7265 seconds
# Total Inference time with Writing 1.8497319221496582
#
# Processing image: D_ROSE_773_II_hvInJwJ5HUD.jpg
# Time to get input/output names: 0.0000 seconds
# Time to handle inputs: 0.0004 seconds
# Time to allocate output memory: 0.0004 seconds
# Async inference time: 1.3507 seconds
# Time to copy outputs: 0.3741 seconds
# Time to synchronize: 0.0000 seconds
# Time to free device memory: 0.0003 seconds
# TensorRT inference time: 1.7267 seconds
# Total Inference time with Writing 1.823580265045166
#
# Processing image: Fisher_price_Classic_Toys_Buzzy_Bee.jpg
# Time to get input/output names: 0.0000 seconds
# Time to handle inputs: 0.0003 seconds
# Time to allocate output memory: 0.0004 seconds
# Async inference time: 1.3507 seconds
# Time to copy outputs: 0.3741 seconds
# Time to synchronize: 0.0000 seconds
# Time to free device memory: 0.0003 seconds
# TensorRT inference time: 1.7266 seconds
# Total Inference time with Writing 1.790207862854004
#
# Processing image: Germanium_GE132.jpg
# Time to get input/output names: 0.0000 seconds
# Time to handle inputs: 0.0003 seconds
# Time to allocate output memory: 0.0004 seconds
# Async inference time: 1.3515 seconds
# Time to copy outputs: 0.3739 seconds
# Time to synchronize: 0.0000 seconds
# Time to free device memory: 0.0003 seconds
# TensorRT inference time: 1.7273 seconds
# Total Inference time with Writing 1.8490469455718994
#
# Processing image: GoPro_HERO3_Composite_Cable.jpg
# Time to get input/output names: 0.0000 seconds
# Time to handle inputs: 0.0003 seconds
# Time to allocate output memory: 0.0004 seconds
# Async inference time: 1.3519 seconds
# Time to copy outputs: 0.3743 seconds
# Time to synchronize: 0.0000 seconds
# Time to free device memory: 0.0003 seconds
# TensorRT inference time: 1.7279 seconds
# Total Inference time with Writing 1.780073642730713
#
# Processing image: Horses_in_Pink_Pencil_Case.jpg
# Time to get input/output names: 0.0000 seconds
# Time to handle inputs: 0.0003 seconds
# Time to allocate output memory: 0.0004 seconds
# Async inference time: 1.3515 seconds
# Time to copy outputs: 0.3743 seconds
# Time to synchronize: 0.0000 seconds
# Time to free device memory: 0.0003 seconds
# TensorRT inference time: 1.7276 seconds
# ...
# Total Inference time with Writing 1.8535130023956299
#
# Processing image: Olive_Kids_Butterfly_Garden_Pencil_Case.jpg
# Time to get input/output names: 0.0000 seconds
# Time to handle inputs: 0.0003 seconds
# Time to allocate output memory: 0.0004 seconds
# Async inference time: 1.3507 seconds
# Time to copy outputs: 0.3742 seconds
# Time to synchronize: 0.0000 seconds
# Time to free device memory: 0.0003 seconds
# TensorRT inference time: 1.7267 seconds
# Total Inference time with Writing 1.8192944526672363
#
# Processing image: Olive_Kids_Dinosaur_Land_Lunch_Box.jpg
# Time to get input/output names: 0.0000 seconds
# Time to handle inputs: 0.0003 seconds
# Time to allocate output memory: 0.0004 seconds
# Async inference time: 1.3506 seconds
# Time to copy outputs: 0.3740 seconds
# Time to synchronize: 0.0000 seconds
# Time to free device memory: 0.0003 seconds
# TensorRT inference time: 1.7264 seconds
# Total Inference time with Writing 1.841324806213379
#
# Processing image: Olive_Kids_Paisley_Pencil_Case.jpg
# Time to get input/output names: 0.0000 seconds
# Time to handle inputs: 0.0003 seconds
# Time to allocate output memory: 0.0004 seconds
# Async inference time: 1.3507 seconds
# Time to copy outputs: 0.3742 seconds
# Time to synchronize: 0.0000 seconds
# Time to free device memory: 0.0003 seconds
# TensorRT inference time: 1.7267 seconds
# Total Inference time with Writing 1.8153884410858154
#
# Processing image: Phillips_Caplets_Size_24.jpg
# Time to get input/output names: 0.0000 seconds
# Time to handle inputs: 0.0003 seconds
# Time to allocate output memory: 0.0004 seconds
# Async inference time: 1.3504 seconds
# Time to copy outputs: 0.3739 seconds
# Time to synchronize: 0.0000 seconds
# Time to free device memory: 0.0003 seconds
# TensorRT inference time: 1.7259 seconds
# Total Inference time with Writing 1.8541088104248047
#
# Processing image: Phillips_Stool_Softener_Liquid_Gels_30_liquid_gels.jpg
# Time to get input/output names: 0.0000 seconds
# Time to handle inputs: 0.0003 seconds
# Time to allocate output memory: 0.0004 seconds
# Async inference time: 1.3514 seconds
# Time to copy outputs: 0.3743 seconds
# Time to synchronize: 0.0000 seconds
# Time to free device memory: 0.0003 seconds
# TensorRT inference time: 1.7273 seconds
# Total Inference time with Writing 1.862318992614746
#
# Processing image: Pokmon_Conquest_Nintendo_DS_Game.jpg
# Time to get input/output names: 0.0000 seconds
# Time to handle inputs: 0.0003 seconds
# Time to allocate output memory: 0.0004 seconds
# Async inference time: 1.3506 seconds
# Time to copy outputs: 0.3740 seconds
# Time to synchronize: 0.0000 seconds
# Time to free device memory: 0.0003 seconds
# TensorRT inference time: 1.7263 seconds
# Total Inference time with Writing 1.8037660121917725
#
# Processing image: Reebok_ALLYLYNN.jpg
# Time to get input/output names: 0.0000 seconds
# Time to handle inputs: 0.0003 seconds
# Time to allocate output memory: 0.0004 seconds
# Async inference time: 1.3507 seconds
# Time to copy outputs: 0.3740 seconds
# Time to synchronize: 0.0000 seconds
# Time to free device memory: 0.0003 seconds
# TensorRT inference time: 1.7263 seconds
# Total Inference time with Writing 1.816326379776001
#
# Processing image: Reebok_CLASSIC_LEGACY_II.jpg
# Time to get input/output names: 0.0000 seconds
# Time to handle inputs: 0.0003 seconds
# Time to allocate output memory: 0.0004 seconds
# Async inference time: 1.3506 seconds
# Time to copy outputs: 0.3741 seconds
# Time to synchronize: 0.0000 seconds
# Time to free device memory: 0.0003 seconds
# TensorRT inference time: 1.7265 seconds
# Total Inference time with Writing 1.8130381107330322
#
# Processing image: Reebok_EASYTONE_CL_LEATHER.jpg
# Time to get input/output names: 0.0000 seconds
# Time to handle inputs: 0.0003 seconds
# Time to allocate output memory: 0.0004 seconds
# Async inference time: 1.3508 seconds
# Time to copy outputs: 0.3742 seconds
# Time to synchronize: 0.0000 seconds
# Time to free device memory: 0.0003 seconds
# TensorRT inference time: 1.7268 seconds
# Total Inference time with Writing 1.7997839450836182
#
# Processing image: Reebok_PUMP_OMNI_LITE_HLS.jpg
# Time to get input/output names: 0.0000 seconds
# Time to handle inputs: 0.0003 seconds
# Time to allocate output memory: 0.0004 seconds
# Async inference time: 1.3507 seconds
# Time to copy outputs: 0.3740 seconds
# Time to synchronize: 0.0000 seconds
# Time to free device memory: 0.0003 seconds
# TensorRT inference time: 1.7264 seconds
# Total Inference time with Writing 1.8096363544464111
#
# Processing image: Reebok_REALFLEX_SELECT.jpg
# Time to get input/output names: 0.0000 seconds
# Time to handle inputs: 0.0003 seconds
# Time to allocate output memory: 0.0004 seconds
# Async inference time: 1.3505 seconds
# Time to copy outputs: 0.3740 seconds
# Time to synchronize: 0.0000 seconds
# Time to free device memory: 0.0003 seconds
# TensorRT inference time: 1.7263 seconds
# Total Inference time with Writing 1.8077490329742432
#
# Processing image: Reebok_R_CROSSFIT_OLY_UFORM.jpg
# Time to get input/output names: 0.0000 seconds
# Time to handle inputs: 0.0003 seconds
# Time to allocate output memory: 0.0004 seconds
# Async inference time: 1.3506 seconds
# Time to copy outputs: 0.3740 seconds
# Time to synchronize: 0.0000 seconds
# Time to free device memory: 0.0003 seconds
# TensorRT inference time: 1.7264 seconds
# Total Inference time with Writing 1.8087453842163086
#
# Processing image: Reebok_SOMERSET_RUN.jpg
# Time to get input/output names: 0.0000 seconds
# Time to handle inputs: 0.0003 seconds
# Time to allocate output memory: 0.0004 seconds
# Async inference time: 1.3506 seconds
# Time to copy outputs: 0.3742 seconds
# Time to synchronize: 0.0000 seconds
# Time to free device memory: 0.0003 seconds
# TensorRT inference time: 1.7265 seconds
# Total Inference time with Writing 1.8205530643463135
#
# Processing image: Reebok_TURBO_RC.jpg
# Time to get input/output names: 0.0000 seconds
# Time to handle inputs: 0.0003 seconds
# Time to allocate output memory: 0.0004 seconds
# Async inference time: 1.3505 seconds
# Time to copy outputs: 0.3741 seconds
# Time to synchronize: 0.0000 seconds
# Time to free device memory: 0.0003 seconds
# TensorRT inference time: 1.7262 seconds
# Total Inference time with Writing 1.7947394847869873
#
# Processing image: Remington_TStudio_Silk_Ceramic_Hair_Straightener_2_Inch_Floating_Plates.jpg
# Time to get input/output names: 0.0000 seconds
# Time to handle inputs: 0.0003 seconds
# Time to allocate output memory: 0.0004 seconds
# Async inference time: 1.3508 seconds
# Time to copy outputs: 0.3741 seconds
# Time to synchronize: 0.0000 seconds
# Time to free device memory: 0.0003 seconds
# TensorRT inference time: 1.7266 seconds
# Total Inference time with Writing 1.7610020637512207
#
# Processing image: Seagate_Archive_HDD_8_TB_Internal_hard_drive_SATA_6Gbs_35_ST8000AS0002.jpg
# Time to get input/output names: 0.0000 seconds
# Time to handle inputs: 0.0003 seconds
# Time to allocate output memory: 0.0004 seconds
# Async inference time: 1.3506 seconds
# Time to copy outputs: 0.3741 seconds
# Time to synchronize: 0.0000 seconds
# Time to free device memory: 0.0003 seconds
# TensorRT inference time: 1.7263 seconds
# Total Inference time with Writing 1.8545951843261719
#
# Processing image: SpiderMan_Titan_Hero_12Inch_Action_Figure_5Hnn4mtkFsP.jpg
# Time to get input/output names: 0.0000 seconds
# Time to handle inputs: 0.0003 seconds
# Time to allocate output memory: 0.0004 seconds
# Async inference time: 1.3508 seconds
# Time to copy outputs: 0.3740 seconds
# Time to synchronize: 0.0000 seconds
# Time to free device memory: 0.0003 seconds
# TensorRT inference time: 1.7265 seconds
# Total Inference time with Writing 1.7662591934204102
#
# Processing image: SpiderMan_Titan_Hero_12Inch_Action_Figure_oo1qph4wwiW.jpg
# Time to get input/output names: 0.0000 seconds
# Time to handle inputs: 0.0003 seconds
# Time to allocate output memory: 0.0004 seconds
# Async inference time: 1.3507 seconds
# Time to copy outputs: 0.3740 seconds
# Time to synchronize: 0.0000 seconds
# Time to free device memory: 0.0003 seconds
# TensorRT inference time: 1.7264 seconds
# Total Inference time with Writing 1.7595939636230469
#
# Processing image: TOOL_BELT.jpg
# Time to get input/output names: 0.0000 seconds
# Time to handle inputs: 0.0003 seconds
# Time to allocate output memory: 0.0004 seconds
# Async inference time: 1.3503 seconds
# Time to copy outputs: 0.3740 seconds
# Time to synchronize: 0.0000 seconds
# Time to free device memory: 0.0003 seconds
# TensorRT inference time: 1.7260 seconds
# Total Inference time with Writing 1.8262715339660645
#
# Processing image: TOWER_TUMBLING.jpg
# Time to get input/output names: 0.0000 seconds
# Time to handle inputs: 0.0003 seconds
# Time to allocate output memory: 0.0004 seconds
# Async inference time: 1.3505 seconds
# Time to copy outputs: 0.3741 seconds
# Time to synchronize: 0.0000 seconds
# Time to free device memory: 0.0003 seconds
# TensorRT inference time: 1.7264 seconds
# Total Inference time with Writing 1.8442294597625732
#
# Processing image: Tena_Pads_Heavy_Long_42_pads.jpg
# Time to get input/output names: 0.0000 seconds
# Time to handle inputs: 0.0003 seconds
# Time to allocate output memory: 0.0003 seconds
# Async inference time: 1.3507 seconds
# Time to copy outputs: 0.3740 seconds
# Time to synchronize: 0.0000 seconds
# Time to free device memory: 0.0003 seconds
# TensorRT inference time: 1.7263 seconds
# Total Inference time with Writing 1.845757007598877
#
# Processing image: UGG_Bailey_Bow_Womens_Clogs_Black_7.jpg
# Time to get input/output names: 0.0000 seconds
# Time to handle inputs: 0.0003 seconds
# Time to allocate output memory: 0.0004 seconds
# Async inference time: 1.3505 seconds
# Time to copy outputs: 0.3741 seconds
# Time to synchronize: 0.0000 seconds
# Time to free device memory: 0.0003 seconds
# TensorRT inference time: 1.7263 seconds
# Total Inference time with Writing 1.8299133777618408
#
# Processing image: Ultra_JarroDophilus.jpg
# Time to get input/output names: 0.0000 seconds
# Time to handle inputs: 0.0003 seconds
# Time to allocate output memory: 0.0004 seconds
# Async inference time: 1.3504 seconds
# Time to copy outputs: 0.3741 seconds
# Time to synchronize: 0.0000 seconds
# Time to free device memory: 0.0003 seconds
# TensorRT inference time: 1.7263 seconds
# Total Inference time with Writing 1.8601312637329102
#
# Processing image: WATER_LANDING_NET.jpg
# Time to get input/output names: 0.0000 seconds
# Time to handle inputs: 0.0003 seconds
# Time to allocate output memory: 0.0004 seconds
# Async inference time: 1.3517 seconds
# Time to copy outputs: 0.3744 seconds
# Time to synchronize: 0.0000 seconds
# Time to free device memory: 0.0003 seconds
# TensorRT inference time: 1.7278 seconds
# Total Inference time with Writing 1.7749872207641602
#
# Processing image: Wild_Copper_Tieks_Metallic_Italian_Leather_Ballet_Flats.jpg
# Time to get input/output names: 0.0000 seconds
# Time to handle inputs: 0.0003 seconds
# Time to allocate output memory: 0.0004 seconds
# Async inference time: 1.3514 seconds
# Time to copy outputs: 0.3743 seconds
# Time to synchronize: 0.0000 seconds
# Time to free device memory: 0.0003 seconds
# TensorRT inference time: 1.7273 seconds
# Total Inference time with Writing 1.8586459159851074
#
# Processing image: Wilton_Easy_Layers_Cake_Pan_Set.jpg
# Time to get input/output names: 0.0000 seconds
# Time to handle inputs: 0.0003 seconds
# Time to allocate output memory: 0.0004 seconds
# Async inference time: 1.3515 seconds
# Time to copy outputs: 0.3745 seconds
# Time to synchronize: 0.0000 seconds
# Time to free device memory: 0.0003 seconds
# TensorRT inference time: 1.7276 seconds
# Total Inference time with Writing 1.8463091850280762
#
# Processing image: Wilton_PreCut_Parchment_Sheets_10_x_15_24_sheets.jpg
# Time to get input/output names: 0.0000 seconds
# Time to handle inputs: 0.0003 seconds
# Time to allocate output memory: 0.0004 seconds
# Async inference time: 1.3516 seconds
# Time to copy outputs: 0.3744 seconds
# Time to synchronize: 0.0000 seconds
# Time to free device memory: 0.0003 seconds
# TensorRT inference time: 1.7277 seconds
# Total Inference time with Writing 1.7876641750335693
#
# Processing image: Womens_Sparkle_Suede_Angelfish_in_Grey_Sparkle_Suede_Silver.jpg
# Time to get input/output names: 0.0000 seconds
# Time to handle inputs: 0.0003 seconds
# Time to allocate output memory: 0.0004 seconds
# Async inference time: 1.3518 seconds
# Time to copy outputs: 0.3742 seconds
# Time to synchronize: 0.0000 seconds
# Time to free device memory: 0.0003 seconds
# TensorRT inference time: 1.7277 seconds
# Total Inference time with Writing 1.8070871829986572
#
# Processing image: Womens_Suede_Bahama_in_Graphite_Suede_t22AJSRjBOX.jpg
# Time to get input/output names: 0.0000 seconds
# Time to handle inputs: 0.0003 seconds
# Time to allocate output memory: 0.0004 seconds
# Async inference time: 1.3519 seconds
# Time to copy outputs: 0.3744 seconds
# Time to synchronize: 0.0000 seconds
# Time to free device memory: 0.0003 seconds
# TensorRT inference time: 1.7280 seconds
# Total Inference time with Writing 1.810835838317871
#
# Processing image: ZigKick_Hoops.jpg
# Time to get input/output names: 0.0000 seconds
# Time to handle inputs: 0.0003 seconds
# Time to allocate output memory: 0.0004 seconds
# Async inference time: 1.3516 seconds
# Time to copy outputs: 0.3743 seconds
# Time to synchronize: 0.0000 seconds
# Time to free device memory: 0.0003 seconds
# TensorRT inference time: 1.7276 seconds
# Total Inference time with Writing 1.8118810653686523
#
# Processing image: adistar_boost_m.jpg
# Time to get input/output names: 0.0000 seconds
# Time to handle inputs: 0.0003 seconds
# Time to allocate output memory: 0.0004 seconds
# Async inference time: 1.3520 seconds
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO: Comet.ml Experiment Summary
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO:   Data:
# COMET INFO:     display_summary_level : 1
# COMET INFO:     name                  : sensitive_lodge_3633
# COMET INFO:     url                   : https://comet.dev.cloudos.autodesk.com/alessandro-giuliano/wala-time-checks/2ac87d530c3d4b36b3589f4c601c30ce
# COMET INFO:   Metrics [count] (min, max):
# COMET INFO:     Average TensorRT Inference Time      : 1.7274238674251645
# COMET INFO:     Default Delta [4]                    : (0.04102778434753418, 2.1540329456329346)
# COMET INFO:     TensorRT Inference Time [1004]       : (0.00704193115234375, 1.7427480220794678)
# COMET INFO:     Time to create CUDA stream [2]       : (0.0001614093780517578, 0.00016832351684570312)
# COMET INFO:     Time to create execution context [2] : (1.3490054607391357, 1.4447193145751953)
# COMET INFO:   Parameters:
# COMET INFO:     Mcubes-Optimized           : True
# COMET INFO:     Object-3D_simplified_mesh  : None
# COMET INFO:     TRT Model                  : model.trt
# COMET INFO:     TRT Optimization           : Base
# COMET INFO:     diffusion_rescale_timestep : 5
# COMET INFO:     model_name                 : ADSKAILab/WaLa-SV-1B
# COMET INFO:     output_format              : obj
# COMET INFO:     scale                      : 1.8
# COMET INFO:     seed                       : 42
# COMET INFO:     target_num_faces           : None
# COMET INFO:   Uploads:
# COMET INFO:     conda-environment-definition : 1
# COMET INFO:     conda-info                   : 1
# COMET INFO:     conda-specification          : 1
# COMET INFO:     environment details          : 1
# COMET INFO:     filename                     : 1
# COMET INFO:     git metadata                 : 1
# COMET INFO:     git-patch (uncompressed)     : 1 (35.41 MB)
# COMET INFO:     installed packages           : 1
# COMET INFO:     notebook                     : 1
# COMET INFO:     os packages                  : 1
# COMET INFO:     source_code                  : 1
# COMET INFO:
# COMET WARNING: To get all data logged automatically, import comet_ml before the following modules: torch, sklearn.
# Time to copy outputs: 0.3744 seconds
# Time to synchronize: 0.0000 seconds
# Time to free device memory: 0.0003 seconds
# TensorRT inference time: 1.7281 seconds
# Total Inference time with Writing 1.7923624515533447
#
# Average TensorRT inference time: 1.7274 seconds
# COMET INFO: Please wait for metadata to finish uploading (timeout is 3600 seconds)
# COMET INFO: Uploading 2 metrics, params and output messages
